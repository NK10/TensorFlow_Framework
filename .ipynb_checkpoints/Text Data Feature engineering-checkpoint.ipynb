# %%
import pandas as pd
import numpy as np
import re
import nltk
import matplotlib.pyplot as plt
pd.options.display.max_colwidth = 200
# %matplotlib inline

# %%
corpus = ['The sky is blue and beautiful.',
          'Love this blue and beautiful sky!',
          'The quick brown fox jumps over the lazy dog.',
          "A king's breakfast has sausages, ham, bacon, eggs, toast and beans",
          'I love green eggs, ham, sausages and bacon!',
          'The brown fox is quick and the blue dog is lazy!',
          'The sky is very blue and the sky is very beautiful today',
          'The dog is lazy but the brown fox is quick!'    
          #https://towardsdatascience.com/understanding-feature-engineering-part-3-traditional-methods-for-text-data-f6f7d70acd41
]
labels = ['weather', 'weather', 'animals', 'food', 'food', 'animals', 'weather', 'animals']
corpus = np.array(corpus)
corpus_df = pd.DataFrame({'Document': corpus, 
                          'Category': labels})
#corpus_df = corpus_df[['Document', 'Category']]
corpus_df

# %%
type(corpus_df)

# %%
wpt = nltk.WordPunctTokenizer()
stop_words = nltk.corpus.stopwords.words('english')

def normalize_document(doc):
    # lower case and remove special characters\whitespaces
    doc = re.sub(r'[^a-zA-Z\s]', '', doc, re.I|re.A)
    doc = doc.lower()
    doc = doc.strip()
    # tokenize document
    tokens = wpt.tokenize(doc)
    # filter stopwords out of document
    filtered_tokens = [token for token in tokens if token not in stop_words]
    # re-create document from filtered tokens
    doc = ' '.join(filtered_tokens)
    return doc

normalize_corpus = np.vectorize(normalize_document)

# %%
norm_corpus = normalize_corpus(corpus)
norm_corpus

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(min_df=0., max_df=1.)
cv_matrix = cv.fit_transform(norm_corpus)
cv_matrix = cv_matrix.toarray()

# %%
a = cv.fit_transform(norm_corpus)

# %%
# get all unique words in the corpus
vocab = cv.get_feature_names()
# show document feature vectors
pd.DataFrame(cv_matrix, columns=vocab)

# %%
# you can set the n-gram range to 1,2 to get unigrams as well as bigrams
bv = CountVectorizer(ngram_range=(2,2))
# ngram_range is to tell the combination of word gram, so 2,2 means only pairs of word, if its 1,2 then it will 
# start the single word combinations and then 2 words
bv_matrix = bv.fit_transform(norm_corpus)

bv_matrix = bv_matrix.toarray()
vocab = bv.get_feature_names()
pd.DataFrame(bv_matrix, columns=vocab)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tv = TfidfVectorizer(min_df=0., max_df=1., use_idf=True)
tv_matrix = tv.fit_transform(norm_corpus)
tv_matrix = tv_matrix.toarray()

vocab = tv.get_feature_names()
pd.DataFrame(np.round(tv_matrix, 2), columns=vocab)

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity_matrix = cosine_similarity(tv_matrix)
similarity_df = pd.DataFrame(similarity_matrix)
similarity_df

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

Z = linkage(similarity_matrix, 'ward')
pd.DataFrame(Z, columns=['Document\Cluster 1', 'Document\Cluster 2', 
                         'Distance', 'Cluster Size'], dtype='object')

# %%
plt.figure(figsize=(8, 3))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Data point')
plt.ylabel('Distance')
dendrogram(Z)
plt.axhline(y=1.0, c='k', ls='--', lw=0.5)

# %%
from scipy.cluster.hierarchy import fcluster
max_dist = 1.0

cluster_labels = fcluster(Z, max_dist, criterion='distance')
cluster_labels = pd.DataFrame(cluster_labels, columns=['ClusterLabel'])
pd.concat([corpus_df, cluster_labels], axis=1)

# %%
from sklearn.decomposition import LatentDirichletAllocation

lda = LatentDirichletAllocation(n_components=3, max_iter=10000, random_state=0)
dt_matrix = lda.fit_transform(cv_matrix)
features = pd.DataFrame(dt_matrix, columns=['T1', 'T2', 'T3'])
features

# %%
tt_matrix = lda.components_
for topic_weights in tt_matrix:
    topic = [(token, weight) for token, weight in zip(vocab, topic_weights)]
    topic = sorted(topic, key=lambda x: -x[1])
    topic = [item for item in topic if item[1] > 0.6]
    print(topic)
    print()

# %%
from sklearn.cluster import KMeans

km = KMeans(n_clusters=3, random_state=0)
km.fit_transform(features)
cluster_labels = km.labels_
cluster_labels = pd.DataFrame(cluster_labels, columns=['ClusterLabel'])
pd.concat([corpus_df, cluster_labels], axis=1)

# %% [markdown]
# # A hands-on intuitive approach to Deep Learning Methods for Text Data — Word2Vec, GloVe and FastText - Word Embedding

# %%
import pandas as pd
import numpy as np
import re
import nltk
import matplotlib.pyplot as plt
pd.options.display.max_colwidth = 200
# %matplotlib inline

# %%
corpus = ['The sky is blue and beautiful.',
          'Love this blue and beautiful sky!',
          'The quick brown fox jumps over the lazy dog.',
          "A king's breakfast has sausages, ham, bacon, eggs, toast and beans",
          'I love green eggs, ham, sausages and bacon!',
          'The brown fox is quick and the blue dog is lazy!',
          'The sky is very blue and the sky is very beautiful today',
          'The dog is lazy but the brown fox is quick!'  ]
labels = ['weather', 'weather', 'animals', 'food', 'food', 'animals', 'weather', 'animals']

corpus = np.array(corpus)
corpus_df = pd.DataFrame({'Document': corpus, 
                          'Category': labels})
corpus_df = corpus_df[['Document', 'Category']]
corpus_df
# Out:
#                                                              Document Category
# 0                                      The sky is blue and beautiful.  weather
# 1                                   Love this blue and beautiful sky!  weather
# 2                        The quick brown fox jumps over the lazy dog.  animals
# 3  A king's breakfast has sausages, ham, bacon, eggs, toast and beans     food
# 4                         I love green eggs, ham, sausages and bacon!     food
# 5                    The brown fox is quick and the blue dog is lazy!  animals
# 6            The sky is very blue and the sky is very beautiful today  weather
# 7                         The dog is lazy but the brown fox is quick!  animals

# %%
wpt = nltk.WordPunctTokenizer()
stop_words = nltk.corpus.stopwords.words('english')

def normalize_document(doc):
    # lower case and remove special characters\whitespaces
    doc = re.sub(r'[^a-zA-Z\s]', '', doc, re.I|re.A)
    doc = doc.lower()
    doc = doc.strip()
    # tokenize document
    tokens = wpt.tokenize(doc)
    # filter stopwords out of document
    filtered_tokens = [token for token in tokens if token not in stop_words]
    # re-create document from filtered tokens
    doc = ' '.join(filtered_tokens)
    return doc

normalize_corpus = np.vectorize(normalize_document)

# %%
norm_corpus = normalize_corpus(corpus)
norm_corpus
# Out:
# array(['sky blue beautiful', 'love blue beautiful sky',
#        'quick brown fox jumps lazy dog',
#        'kings breakfast sausages ham bacon eggs toast beans',
#        'love green eggs ham sausages bacon',
#        'brown fox quick blue dog lazy', 'sky blue sky beautiful today',
#        'dog lazy brown fox quick'], dtype='<U51')

# %%
from nltk.corpus import gutenberg
from string import punctuation

bible = gutenberg.sents('bible-kjv.txt') 
remove_terms = punctuation + '0123456789'

norm_bible = [[word.lower() for word in sent if word not in remove_terms] for sent in bible]
norm_bible = [' '.join(tok_sent) for tok_sent in norm_bible]
norm_bible = filter(None, normalize_corpus(norm_bible))
norm_bible = [tok_sent for tok_sent in norm_bible if len(tok_sent.split()) > 2]

print('Total lines:', len(bible))
print('\nSample line:', bible[10])
print('\nProcessed line:', norm_bible[10])
# Out:
# Total lines: 30103
#
# Sample line: ['1', ':', '6', 'And', 'God', 'said', ',', 'Let', 'there', 'be', 'a', 'firmament', 'in', 'the', 'midst', 'of', 'the', 'waters', ',', 'and', 'let', 'it', 'divide', 'the', 'waters', 'from', 'the', 'waters', '.']
#
# Processed line: god said let firmament midst waters let divide waters waters

# %% [markdown]
# # Skip-Gram Model

# %%
from keras.preprocessing import text

tokenizer = text.Tokenizer()
tokenizer.fit_on_texts(norm_bible)

word2id = tokenizer.word_index
#id2word = {v:k for k, v in word2id.items()}
id2word = tokenizer.index_word
vocab_size = len(word2id) + 1 
embed_size = 100

wids = [[word2id[w] for w in text.text_to_word_sequence(doc)] for doc in norm_bible]
print('Vocabulary Size:', vocab_size)
print('Vocabulary Sample:', list(word2id.items())[:10])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Vocabulary Size: 12425
# Vocabulary Sample: [('shall', 1), ('unto', 2), ('lord', 3), ('thou', 4), ('thy', 5), ('god', 6), ('ye', 7), ('said', 8), ('thee', 9), ('upon', 10)]

# %%
from keras.preprocessing.sequence import skipgrams

# generate skip-grams
skip_grams = [skipgrams(wid, vocabulary_size=vocab_size, window_size=10) for wid in wids]

# view sample skip-grams
pairs, labels = skip_grams[0][0], skip_grams[0][1]
for i in range(10):
    print("({:s} ({:d}), {:s} ({:d})) -> {:d}".format(
          id2word[pairs[i][0]], pairs[i][0], 
          id2word[pairs[i][1]], pairs[i][1], 
          labels[i]))
# Out:
# (james (1154), drinkers (11266)) -> 0
# (james (1154), clearing (7011)) -> 0
# (james (1154), bible (5766)) -> 1
# (james (1154), king (13)) -> 1
# (king (13), eshtemoh (9071)) -> 0
# (bible (5766), james (1154)) -> 1
# (bible (5766), bribery (10348)) -> 0
# (king (13), bible (5766)) -> 1
# (king (13), sabtecha (9587)) -> 0
# (bible (5766), king (13)) -> 1

# %%
from keras.layers import dot
from keras.layers import Dense, Input
from keras.layers.core import Reshape
from keras.layers import Embedding
from keras.models import  Model
from keras.backend import reshape

# build skip-gram architecture
inp = Input(shape=(1,),name = "first_input")
word_model22 = Embedding(input_dim=vocab_size, output_dim=embed_size,
                         embeddings_initializer="glorot_uniform",
                         input_length=1)
emb  = word_model22(inp)
word_model22 = Reshape(target_shape= (embed_size,))(emb)

inp1 = Input(shape=(1,),name = "2nd_input")
context_model = Embedding(input_dim=vocab_size, output_dim=embed_size,
                         embeddings_initializer="glorot_uniform",
                         input_length=1)
emb1  = context_model(inp1)
context_model = Reshape(target_shape= (embed_size,))(emb1)

mo = (dot([word_model22, context_model],axes=-1))
mo = (Dense(1, kernel_initializer="glorot_uniform", activation="sigmoid"))(mo)
model = Model(inputs = (inp, inp1), outputs =mo)
model.compile(loss="mean_squared_error", optimizer="rmsprop")

# view model summary
print(model.summary())

# visualize model structure
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

SVG(model_to_dot(model, show_shapes=True, show_layer_names=False, 
                 rankdir='TB').create(prog='dot', format='svg'))
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# first_input (InputLayer)        (None, 1)            0
# __________________________________________________________________________________________________
# 2nd_input (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 1, 100)       1242500     first_input[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 1, 100)       1242500     2nd_input[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 100)          0           embedding_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 100)          0           embedding_2[0][0]
# __________________________________________________________________________________________________
# dot_1 (Dot)                     (None, 1)            0           reshape_1[0][0]
#                                                                  reshape_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            2           dot_1[0][0]
# ==================================================================================================
# Total params: 2,485,002
# Trainable params: 2,485,002
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
for epoch in range(1, 6):
    loss = 0
    for i, elem in enumerate(skip_grams):
        pair_first_elem = np.array(list(zip(*elem[0]))[0], dtype='int32')
        pair_second_elem = np.array(list(zip(*elem[0]))[1], dtype='int32')
        print(pair_first_elem,"        " ,pair_second_elem)
        print(nitin)
        labels = np.array(elem[1], dtype='int32')
        X = [pair_first_elem, pair_second_elem]
        Y = labels
        if i % 10000 == 0:
            print('Processed {} (skip_first, skip_second, relevance) pairs'.format(i))
        loss += model.train_on_batch(X,Y)  

    print('Epoch:', epoch, 'Loss:', loss)
# Out:
# [1154 1154 1154 1154   13 5766 5766   13   13 5766   13 5766]          [11266  7011  5766    13  9071  1154 10348  5766  9587    13  1154  1042]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-a0a6ef96470e> in <module>()
#       5         pair_second_elem = np.array(list(zip(*elem[0]))[1], dtype='int32')
#       6         print(pair_first_elem,"        " ,pair_second_elem)
# ----> 7         print(nitin)
#       8         labels = np.array(elem[1], dtype='int32')
#       9         X = [pair_first_elem, pair_second_elem]
#
# NameError: name 'nitin' is not defined

# %%
merge_layer = model.get_layer("embedding_1")
weights = merge_layer.get_weights()[0][1:]
print(weights.shape)
pd.DataFrame(weights, index=id2word.values()).head()
# Out:
# (12424, 100)
#              0         1         2         3         4         5         6   \
# shall -0.185909 -0.007064 -0.200767 -0.070342  0.064441  0.022130  0.050596
# unto  -0.109269 -0.065269 -0.038226 -0.170088 -0.004057  0.128751  0.108440
# lord  -0.032950 -0.060431 -0.206802 -0.184230  0.232002 -0.008878  0.135026
# thou  -0.095718  0.042413 -0.164412 -0.087832  0.036848  0.125596  0.081640
# thy   -0.071616 -0.005229 -0.178873 -0.157992  0.185674  0.086809  0.076878
#
#              7         8         9     ...           90        91        92  \
# shall  0.002693 -0.039826 -0.043733    ...    -0.098163  0.045730 -0.086447
# unto  -0.015469 -0.252670 -0.007242    ...    -0.079985  0.060652 -0.051012
# lord   0.083021 -0.070132 -0.125167    ...    -0.078757  0.160018 -0.024425
# thou   0.095143 -0.093825  0.029934    ...    -0.034496  0.255490 -0.008177
# thy    0.105395 -0.033716  0.113165    ...    -0.033819  0.047482 -0.052520
#
#              93        94        95        96        97        98        99
# shall  0.020480  0.145054 -0.122845  0.044849  0.047141  0.060302  0.150995
# unto  -0.064303  0.158642 -0.168495 -0.082792  0.029083  0.114688 -0.067638
# lord   0.000500  0.171920 -0.108917 -0.057519  0.019073  0.075326  0.034292
# thou   0.073916  0.098388  0.041292 -0.205769  0.007649  0.051077  0.033638
# thy   -0.027008  0.116943 -0.019108 -0.178131 -0.024887  0.210328  0.157060
#
# [5 rows x 100 columns]

# %%
from sklearn.metrics.pairwise import euclidean_distances

distance_matrix = euclidean_distances(weights)
print(distance_matrix.shape)

similar_words = {search_term: [id2word[idx] for idx in distance_matrix[word2id[search_term]-1].argsort()[1:6]+1] 
                   for search_term in ['god', 'jesus', 'noah', 'egypt', 'john', 'gospel', 'moses','famine']}

similar_words
# Out:
# (12424, 12424)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:257: RuntimeWarning: invalid value encountered in sqrt
#   return distances if squared else np.sqrt(distances, out=distances)
# {'god': ['thou', 'said', 'thy', 'ye', 'man'],
#  'jesus': ['many', 'time', 'see', 'called', 'know'],
#  'noah': ['tried', 'reckon', 'elon', 'prospered', 'leap'],
#  'egypt': ['high', 'servant', 'servants', 'commanded', 'midst'],
#  'john': ['prison', 'whence', 'riches', 'peter', 'everlasting'],
#  'gospel': ['indeed', 'whence', 'doeth', 'beloved', 'fallen'],
#  'moses': ['spake', 'fathers', 'gave', 'commanded', 'servant'],
#  'famine': ['remain', 'possession', 'edom', 'reproach', 'reason']}

# %%
from sklearn.manifold import TSNE

words = sum([[k] + v for k, v in similar_words.items()], [])
words_ids = [word2id[w] for w in words]
word_vectors = np.array([weights[idx] for idx in words_ids])
print('Total words:', len(words), '\tWord Embedding shapes:', word_vectors.shape)

tsne = TSNE(n_components=2, random_state=0, n_iter=10000, perplexity=3)
np.set_printoptions(suppress=True)
T = tsne.fit_transform(word_vectors)
labels = words

plt.figure(figsize=(14, 8))
plt.scatter(T[:, 0], T[:, 1], c='steelblue', edgecolors='k')
for label, x, y in zip(labels, T[:, 0], T[:, 1]):
    plt.annotate(label, xy=(x+1, y+1), xytext=(0, 0), textcoords='offset points')
# Out:
# Total words: 48 	Word Embedding shapes: (48, 100)

# %%
from gensim.models import word2vec

# tokenize sentences in corpus
wpt = nltk.WordPunctTokenizer()
tokenized_corpus = [wpt.tokenize(document) for document in norm_bible]

# Set values for various parameters
feature_size = 100    # Word vector dimensionality  
window_context = 30          # Context window size                                                                                    
min_word_count = 1   # Minimum word count                        
sample = 1e-3   # Downsample setting for frequent words

w2v_model = word2vec.Word2Vec(tokenized_corpus, size=feature_size, 
                          window=window_context, min_count=min_word_count,
                          sample=sample, iter=100)

# view similar words based on gensim's model
similar_words = {search_term: [item[0] for item in w2v_model.wv.most_similar([search_term], topn=5)]
                  for search_term in ['god', 'jesus', 'noah', 'egypt', 'john', 'gospel', 'moses','famine']}
similar_words
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# {'god': ['lord', 'sworn', 'fewest', 'salvation', 'us'],
#  'jesus': ['messias', 'apostles', 'waterpot', 'immediately', 'peter'],
#  'noah': ['shem', 'japheth', 'enosh', 'kenan', 'henoch'],
#  'egypt': ['egyptians', 'bondage', 'lice', 'flowing', 'pharaoh'],
#  'john': ['baptist', 'james', 'baptize', 'devine', 'unloose'],
#  'gospel': ['christ', 'faith', 'hope', 'epaphras', 'sufferings'],
#  'moses': ['congregation', 'children', 'joshua', 'canaan', 'doctor'],
#  'famine': ['pestilence', 'peril', 'sojourn', 'consumed', 'mildew']}

# %%
from sklearn.manifold import TSNE

words = sum([[k] + v for k, v in similar_words.items()], [])
wvs = w2v_model.wv[words]

tsne = TSNE(n_components=2, random_state=0, n_iter=10000, perplexity=2)
np.set_printoptions(suppress=True)
T = tsne.fit_transform(wvs)
labels = words

plt.figure(figsize=(14, 8))
plt.scatter(T[:, 0], T[:, 1], c='orange', edgecolors='r')
for label, x, y in zip(labels, T[:, 0], T[:, 1]):
    plt.annotate(label, xy=(x+1, y+1), xytext=(0, 0), textcoords='offset points')

# %%
wpt = nltk.WordPunctTokenizer()
tokenized_corpus = [wpt.tokenize(document) for document in norm_bible]
tokenized_corpus[:10]
# Out:
# [['king', 'james', 'bible'],
#  ['old', 'testament', 'king', 'james', 'bible'],
#  ['first', 'book', 'moses', 'called', 'genesis'],
#  ['beginning', 'god', 'created', 'heaven', 'earth'],
#  ['earth', 'without', 'form', 'void', 'darkness', 'upon', 'face', 'deep'],
#  ['spirit', 'god', 'moved', 'upon', 'face', 'waters'],
#  ['god', 'said', 'let', 'light', 'light'],
#  ['god', 'saw', 'light', 'good', 'god', 'divided', 'light', 'darkness'],
#  ['god', 'called', 'light', 'day', 'darkness', 'called', 'night'],
#  ['evening', 'morning', 'first', 'day']]

# %%
norm_bible
# Out:
# ['king james bible',
#  'old testament king james bible',
#  'first book moses called genesis',
#  'beginning god created heaven earth',
#  'earth without form void darkness upon face deep',
#  'spirit god moved upon face waters',
#  'god said let light light',
#  'god saw light good god divided light darkness',
#  'god called light day darkness called night',
#  'evening morning first day',
#  'god said let firmament midst waters let divide waters waters',
#  'god made firmament divided waters firmament waters firmament',
#  'god called firmament heaven',
#  'evening morning second day',
#  'god said let waters heaven gathered together unto one place let dry land appear',
#  'god called dry land earth gathering together waters called seas god saw good',
#  'god said let earth bring forth grass herb yielding seed fruit tree yielding fruit kind whose seed upon earth',
#  'earth brought forth grass herb yielding seed kind tree yielding fruit whose seed kind god saw good',
#  'evening morning third day',
#  'jacob pitched tent mount laban brethren pitched mount gilead',
#  'laban said jacob hast thou done thou hast stolen away unawares carried away daughters captives taken sword',
#  'wherefore didst thou flee away secretly steal away didst tell might sent thee away mirth songs tabret harp',
#  'hast suffered kiss sons daughters',
#  'thou hast done foolishly',
#  'power hand hurt god father spake unto yesternight saying take thou heed thou speak jacob either good bad',
#  'though thou wouldest needs gone thou sore longedst thy father house yet wherefore hast thou stolen gods',
#  'jacob answered said laban afraid said peradventure thou wouldest take force thy daughters',
#  'whomsoever thou findest thy gods let live brethren discern thou thine take thee',
#  'jacob knew rachel stolen',
#  'laban went jacob tent leah tent two maidservants tents found',
#  'went leah tent entered rachel tent',
#  'rachel taken images put camel furniture sat upon',
#  'laban searched tent found',
#  'said father let displease lord cannot rise thee custom women upon',
#  'searched found images',
#  'jacob wroth chode laban jacob answered said laban trespass',
#  'sin thou hast hotly pursued',
#  'whereas thou hast searched stuff hast thou found thy household stuff',
#  'set brethren thy brethren may judge betwixt us',
#  'twenty years thee thy ewes thy goats cast young rams thy flock eaten',
#  'torn beasts brought unto thee bare loss hand didst thou require whether stolen day stolen night',
#  'thus day drought consumed frost night sleep departed mine eyes',
#  'thus twenty years thy house served thee fourteen years thy two daughters six years thy cattle thou hast changed wages ten times',
#  'except god father god abraham fear isaac surely thou hadst sent away empty',
#  'god hath seen mine affliction labour hands rebuked thee yesternight',
#  'laban answered said unto jacob daughters daughters children children cattle cattle thou seest mine day unto daughters unto children born',
#  'therefore come thou let us make covenant thou let witness thee',
#  'jacob took stone set pillar',
#  'jacob said unto brethren gather stones took stones made heap eat upon heap',
#  'laban called jegarsahadutha jacob called galeed',
#  'laban said heap witness thee day',
#  'therefore name called galeed mizpah said lord watch thee absent one another',
#  'thou shalt afflict daughters thou shalt take wives beside daughters man us see god witness betwixt thee',
#  'laban said jacob behold heap behold pillar cast betwixt thee heap witness pillar witness pass heap thee thou shalt pass heap pillar unto harm',
#  'god abraham god nahor god father judge betwixt us',
#  'jacob sware fear father isaac',
#  'jacob offered sacrifice upon mount called brethren eat bread eat bread tarried night mount',
#  'early morning laban rose kissed sons daughters blessed laban departed returned unto place',
#  'jacob went way angels god met',
#  'jacob saw said god host called name place mahanaim',
#  'jacob sent messengers esau brother unto land seir country edom',
#  'commanded saying thus shall ye speak unto lord esau thy servant jacob saith thus sojourned laban stayed oxen asses flocks menservants womenservants sent tell lord may find grace thy sight',
#  'messengers returned jacob saying came thy brother esau also cometh meet thee four hundred men',
#  'jacob greatly afraid distressed divided people flocks herds camels two bands said esau come one company smite company left shall escape',
#  'jacob said god father abraham god father isaac lord saidst unto return unto thy country thy kindred deal well thee worthy least mercies truth thou hast shewed unto thy servant staff passed jordan become two bands',
#  'deliver pray thee hand brother hand esau fear lest come smite mother children',
#  'thou saidst surely thee good make thy seed sand sea cannot numbered multitude',
#  'lodged night took came hand present esau brother two hundred goats twenty goats two hundred ewes twenty rams thirty milch camels colts forty kine ten bulls twenty asses ten foals',
#  'delivered hand servants every drove said unto servants pass put space betwixt drove drove',
#  'commanded foremost saying esau brother meeteth thee asketh thee saying whose art thou',
#  'sons reuel esau son duke nahath duke zerah duke shammah duke mizzah dukes came reuel land edom sons bashemath esau wife',
#  'sons aholibamah esau wife duke jeush duke jaalam duke korah dukes came aholibamah daughter anah esau wife',
#  'sons esau edom dukes',
#  'sons seir horite inhabited land lotan shobal zibeon anah dishon ezer dishan dukes horites children seir land edom',
#  'children lotan hori hemam lotan sister timna',
#  'children shobal alvan manahath ebal shepho onam',
#  'children zibeon ajah anah anah found mules wilderness fed asses zibeon father',
#  'children anah dishon aholibamah daughter anah',
#  'children dishon hemdan eshban ithran cheran',
#  'children ezer bilhan zaavan akan',
#  'children dishan uz aran',
#  ...]

# %%
target_input = Input(shape=(1,),name = "11_input")
context_input = Input(shape=(1,),name = "12_input")

#inp = Input(shape=(1,),name = "first_input")
word_model22 = Embedding(input_dim=vocab_size, output_dim=embed_size,
                         embeddings_initializer="glorot_uniform",
                         input_length=1)(target_input)
#emb  = word_model22(target_input)
word_model22 = Reshape(target_shape= (embed_size,))(word_model22)

#inp1 = Input(shape=(1,),name = "2nd_input")
context_model = Embedding(input_dim=vocab_size, output_dim=embed_size,
                         embeddings_initializer="glorot_uniform",
                         input_length=1)(context_input)
#emb1  = context_model(context_input)
context_model = Reshape(target_shape= (embed_size,))(context_model)

mo = (dot([word_model22, context_model],axes=-1))
mo = (Dense(1, kernel_initializer="glorot_uniform", activation="sigmoid"))(mo)
model = Model(inputs = (target_input, context_input), outputs =mo)
model.compile(loss="mean_squared_error", optimizer="rmsprop")

# view model summary
print(model.summary())

# visualize model structure
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

SVG(model_to_dot(model, show_shapes=True, show_layer_names=False, 
                 rankdir='TB').create(prog='dot', format='svg'))

# %%
from keras.layers import Merge

# %%
corpus =  ["this is good"]

# %%
from keras.preprocessing import text
tokenizer = text.Tokenizer()
tokenizer.fit_on_texts(corpus)

word2id = tokenizer.word_index
id2word = {v:k for k, v in word2id.items()}
id2word_new =  tokenizer.index_word
vocab_size = len(word2id) + 1 
embed_size = 100
wids = [[word2id[w] for w in text.text_to_word_sequence(doc)] for doc in corpus]
# generate skip-grams
skip_grams = [skipgrams(wid, vocabulary_size=vocab_size, window_size=1) for wid in wids]
#print(len(skip_grams), vocab_size, skip_grams[0], "\n\n\n\n")
# view sample skip-grams
pairs, labels = skip_grams[0][0], skip_grams[0][1]
print("values for Pairs are {} \n and \n values for labels are {}".format(pairs,labels))
for i in range(20):
    print(" ({:s} ({:d}), {:s} ({:d})) -> {:d}".format(
          id2word[pairs[i][0]], pairs[i][0], 
          id2word[pairs[i][1]], pairs[i][1], 
          labels[i]))

# %%
corpus

# %%
[6, 3], [4, 3], [2, 4], [1, 4], [3, 11], [1, 3], [5, 2],

# %%
id2word_new

# %%
array(['sky blue beautiful', 'love blue beautiful sky',
       'quick brown fox jumps lazy dog',
       'kings breakfast sausages ham bacon eggs toast beans',
       'love green eggs ham sausages bacon',
       'brown fox quick blue dog lazy', 'sky blue sky beautiful today',
       'dog lazy brown fox quick'], dtype='<U51')

# %%
st = "this is a STRT, 123123123, gooog @gmail.com"

# %%
reg = re.compile([a-z])

# %%
reg.search(st)

# %%
ress = re.fullmatch("is",st)

# %%
print(ress)
