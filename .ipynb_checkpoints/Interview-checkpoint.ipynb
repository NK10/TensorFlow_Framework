# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Python

# %% [markdown]
# List,sets, tuples, dictionary, array

# %%
s = set()
t = tuple()
d = dict()
l=list()
l = [1,11,111,1112,3342]
print(type(s),type(t),type(d), type(l))
# Out:
# <class 'set'> <class 'tuple'> <class 'dict'> <class 'list'>

# %%
for i,j in enumerate(l):
    print(i,j)
# Out:
# 0 1
# 1 11
# 2 111
# 3 1112
# 4 3342

# %% [markdown]
# <b> Continue vs Pass </b>
# continue forces the loop to start at the next iteration while pass means "there is no code to execute here" and will continue through the remainder or the loop body. continue will jump back to the top of the loop. pass will continue processing

# %%
def find_roots(a, b, c):
    r1 = -b-np.sqrt(b**2-(4*a*c))/(2*a)
    r2 = -b+np.sqrt(b**2-(4*a*c))/(2*a)
    return (r1,r2)

print(find_roots(2, 10, 8));
# Out:
# (-11.5, -8.5)

# %% [markdown]
# # Try and except and else

# %% [markdown]
# First, the try clause (the statement(s) between the try and except keywords) is executed.
#
# If no exception occurs, the except clause is skipped and execution of the try statement is finished.
#
# If an exception occurs during execution of the try clause, the rest of the clause is skipped. Then if its type matches the exception named (like RuntimeError,ValueError...) after the except keyword, the except clause is executed, and then execution continues after the try statement.
#
# If an exception occurs which does not match the exception named in the except clause, it is passed on to outer try statements; if no handler is found, it is an unhandled exception and execution stops with a message as shown above
#
# The try … except statement has an optional else clause, which, when present, must follow all except clauses.
# It is useful for code that must be executed if the try clause does not raise an exception.
#
# The except clause may specify a variable after the exception name. The variable is bound to an exception instance with the arguments stored in instance.args. like inst shown below

# %%
import sys
try:
    def add(x,y): return x+y
    reduce(add, range(1, 11))
except (RuntimeError, TypeError):
    print("error found")
except NameError as inst:
    print("error while executing name\n",sys.exc_info()[1])
    print(type(inst))    # the exception instance
    print(inst.args)     # arguments stored in .args
    print(inst)          # __str__ allows args to be printed directly,
                          # but may be overridden in exception subclasses
    x = inst.args     # unpack args
    print('x =', x)
else:
    print("in the else code")
# Out:
# error while executing name
#  name 'reduce' is not defined
# <class 'NameError'>
# ("name 'reduce' is not defined",)
# name 'reduce' is not defined
# x = ("name 'reduce' is not defined",)

# %% [markdown]
# ## Raising Exceptions

# %% [markdown]
# The raise statement allows the programmer to force a specified exception to occur.

# %% [markdown]
# if you need to determine whether an exception was raised but don’t intend to handle it, a simpler form of the raise statement allows you to re-raise the exception:
#
# try commenting the raise command below

# %%
try:
    raise NameError('HiThere')
except NameError:
    print('An exception flew by!')
    raise
# Out:
# An exception flew by!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-114-bf6ef4926f8c> in <module>
#       1 try:
# ----> 2     raise NameError('HiThere')
#       3 except NameError:
#       4     print('An exception flew by!')
#       5     raise
#
# NameError: HiThere

# %% [markdown]
# ## finally

# %% [markdown]
# The try statement has another optional clause which is intended to define clean-up actions that must be executed under all circumstances. For example:
# If a finally clause is present, the finally clause will execute as the last task before the try statement completes. The finally clause runs whether or not the try statement produces an exception. The following points discuss more complex cases when an exception occurs:
#
# If an exception occurs during execution of the try clause, the exception may be handled by an except clause. If the exception is not handled by an except clause, the exception is re-raised after the finally clause has been executed.
#
# An exception could occur during execution of an except or else clause. Again, the exception is re-raised after the finally clause has been executed.
#
# If the try statement reaches a break, continue or return statement, the finally clause will execute just prior to the break, continue or return statement’s execution.
#
# If a finally clause includes a return statement, the finally clause’s return statement will execute before, and instead of, the return statement in a try clause.

# %%
def divide(x, y):
        try:
            result = x / y
        except ZeroDivisionError:
            print("division by zero!")
        else:
            print("result is", result)
        finally:
            print("executing finally clause")

# %%
divide(1,0)
# Out:
# division by zero!
# executing finally clause

# %% [markdown]
# a+=1 means whatever is on the right add it to the left
# a=+1 means what ever is on the right assign it to left

# %%
# can't add the number and str, so to add convert the number to str
a = 63
st = str(a//60)+":"+ str(a%60)
st
# Out:
# '1:3'

# %% [markdown]
# # regular expression

# %% [markdown]
# findall	---Returns a list containing all matches
# search	---Returns a Match object if there is a match anywhere in the string
# split	---Returns a list where the string has been split at each match
# sub	    ---Replaces one or many matches with a string

# %%
a ="nitin@#$"
a.replace("#"," ")
# Out:
# 'nitin@ $'

# %%
import re
a = "f!d t26312imZEe inimfs teim"
re.sub("[i..m]",'', a,2)
# Out:
# 'f!d t26312ZEe'

# %%
a =  "f!d t26312imZEeim"
re.findall("im",a)
# Out:
# ['im', 'im']

# %% [markdown]
# The list contains the matches in the order they are found.
# If no matches are found, an empty list is returned:

# %%
a =  "f!d t26312imZEeima"
re.split("im",a)
# Out:
# ['f!d t26312', 'ZEe', 'a']

# %%
a =  "f!d t26312imZEeima"
re.search("im",a)
# Out:
# <_sre.SRE_Match object; span=(10, 12), match='im'>

# %%
for i in range(10,10):
    print(i)

# %%
a= [12,34,13,4]
for i in range(len(a)):
    for j in range(i+1,len(a)):
        for k in range(j+1,len(a)):
            #print(a[i],a[j],a[k])
            if (a[i]+a[j]+a[k])==468:
                print(a[i],a[j],a[k])

# %%
a = 3456
counter =0
flag = True
while(flag):
    a =a//10
    if a==0: # // is called floor division
        flag= False
    counter+=1
    
print(counter)
# Out:
# 4

# %% [markdown]
# If you do the group and do the head 2 or any number it will bring back that many records for each group not just total

# %%
train.groupby(["LotShape"]).head(2)
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0      1          60       RL         65.0     8450   Pave   NaN      Reg
# 1      2          20       RL         80.0     9600   Pave   NaN      Reg
# 2      3          60       RL         68.0    11250   Pave   NaN      IR1
# 3      4          70       RL         60.0     9550   Pave   NaN      IR1
# 12    13          20       RL          NaN    12968   Pave   NaN      IR2
# 50    51          60       RL          NaN    13869   Pave   NaN      IR2
# 264  265          30       RM         30.0     5232   Pave  Grvl      IR3
# 301  302          60       RL         66.0    16226   Pave   NaN      IR3
#
#     LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0           Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 1           Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# ...

# %% [markdown]
# # Machine Learning

# %%
train = pd.read_csv("C:/Machine Learning/Hackathons/Kaggle/House Price/train_Copy.csv")

# %%
train.shape
# Out:
# (1460, 81)

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
y= train["SalePrice"]
train.drop("SalePrice",inplace=True,axis=1)

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 80 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
pd.set_option("display.max_rows", 84)

# %%
train.isnull().sum().reset_index().sort_values([0], ascending = False)
# Out:
#             index     0
# 72         PoolQC  1453
# 74    MiscFeature  1406
# 6           Alley  1369
# 73          Fence  1179
# 57    FireplaceQu   690
# 3     LotFrontage   259
# 58     GarageType    81
# 59    GarageYrBlt    81
# 63     GarageQual    81
# 64     GarageCond    81
# 60   GarageFinish    81
# 35   BsmtFinType2    38
# 32   BsmtExposure    38
# 31       BsmtCond    37
# 33   BsmtFinType1    37
# 30       BsmtQual    37
# 26     MasVnrArea     8
# 25     MasVnrType     8
# 42     Electrical     1
# 50       HalfBath     0
# 47   BsmtFullBath     0
# 48   BsmtHalfBath     0
# 51   BedroomAbvGr     0
# 49       FullBath     0
# 54   TotRmsAbvGrd     0
# 55     Functional     0
# 52   KitchenAbvGr     0
# 53    KitchenQual     0
# 0              Id     0
# 56     Fireplaces     0
# 45   LowQualFinSF     0
# 61     GarageCars     0
# 62     GarageArea     0
# 65     PavedDrive     0
# 66     WoodDeckSF     0
# 67    OpenPorchSF     0
# 68  EnclosedPorch     0
# ...

# %%
train.isnull().sum().reset_index().sort_values([0], ascending = False).iloc[0:4,0].values
# Out:
# array(['PoolQC', 'MiscFeature', 'Alley', 'Fence'], dtype=object)

# %%
train.drop(train.isnull().sum().reset_index().sort_values([0], ascending = False).iloc[0:4,0].values, inplace=True, axis= 1)

# %%
#use the above way to delete the columns based on the values or hard code the column
train.drop(['PoolQC', 'MiscFeature', 'Alley', 'Fence'], inplace = True, axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-182-bebecb4f63b5> in <module>
#       1 #use the above way to delete the columns based on the values or hard code the column
# ----> 2 train.drop(['PoolQC', 'MiscFeature', 'Alley', 'Fence'], inplace = True, axis = 1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4095             level=level,
#    4096             inplace=inplace,
# -> 4097             errors=errors,
#    4098         )
#    4099
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3913         for axis, labels in axes.items():
#    3914             if labels is not None:
# -> 3915                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# ...

# %%
train.dtypes.value_counts()
# Out:
# object     39
# int64      34
# float64     3
# dtype: int64

# %%
train["MSSubClass"].nunique()
# Out:
# 15

# %%
train.skew()
# Out:
# Id                0.000000
# MSSubClass        1.407657
# LotFrontage       2.163569
# LotArea          12.207688
# OverallQual       0.216944
# OverallCond       0.693067
# YearBuilt        -0.613461
# YearRemodAdd     -0.503562
# MasVnrArea        2.669084
# BsmtFinSF1        1.685503
# BsmtFinSF2        4.255261
# BsmtUnfSF         0.920268
# TotalBsmtSF       1.524255
# 1stFlrSF          1.376757
# 2ndFlrSF          0.813030
# LowQualFinSF      9.011341
# GrLivArea         1.366560
# BsmtFullBath      0.596067
# BsmtHalfBath      4.103403
# FullBath          0.036562
# HalfBath          0.675897
# BedroomAbvGr      0.211790
# KitchenAbvGr      4.488397
# TotRmsAbvGrd      0.676341
# Fireplaces        0.649565
# GarageYrBlt      -0.649415
# GarageCars       -0.342549
# GarageArea        0.179981
# WoodDeckSF        1.541376
# OpenPorchSF       2.364342
# EnclosedPorch     3.089872
# 3SsnPorch        10.304342
# ScreenPorch       4.122214
# PoolArea         14.828374
# ...

# %%
train.kurt()
# Out:
# Id                -1.200000
# MSSubClass         1.580188
# LotFrontage       17.452867
# LotArea          203.243271
# OverallQual        0.096293
# OverallCond        1.106413
# YearBuilt         -0.439552
# YearRemodAdd      -1.272245
# MasVnrArea        10.082417
# BsmtFinSF1        11.118236
# BsmtFinSF2        20.113338
# BsmtUnfSF          0.474994
# TotalBsmtSF       13.250483
# 1stFlrSF           5.745841
# 2ndFlrSF          -0.553464
# LowQualFinSF      83.234817
# GrLivArea          4.895121
# BsmtFullBath      -0.839098
# BsmtHalfBath      16.396642
# FullBath          -0.857043
# HalfBath          -1.076927
# BedroomAbvGr       2.230875
# KitchenAbvGr      21.532404
# TotRmsAbvGrd       0.880762
# Fireplaces        -0.217237
# GarageYrBlt       -0.418341
# GarageCars         0.220998
# GarageArea         0.917067
# WoodDeckSF         2.992951
# OpenPorchSF        8.490336
# EnclosedPorch     10.430766
# 3SsnPorch        123.662379
# ScreenPorch       18.439068
# ...

# %%
train.std()
# Out:
# Id                421.610009
# MSSubClass         42.300571
# LotFrontage        24.284752
# LotArea          9981.264932
# OverallQual         1.382997
# OverallCond         1.112799
# YearBuilt          30.202904
# YearRemodAdd       20.645407
# MasVnrArea        181.066207
# BsmtFinSF1        456.098091
# BsmtFinSF2        161.319273
# BsmtUnfSF         441.866955
# TotalBsmtSF       438.705324
# 1stFlrSF          386.587738
# 2ndFlrSF          436.528436
# LowQualFinSF       48.623081
# GrLivArea         525.480383
# BsmtFullBath        0.518911
# BsmtHalfBath        0.238753
# FullBath            0.550916
# HalfBath            0.502885
# BedroomAbvGr        0.815778
# KitchenAbvGr        0.220338
# TotRmsAbvGrd        1.625393
# Fireplaces          0.644666
# GarageYrBlt        24.689725
# GarageCars          0.747315
# GarageArea        213.804841
# WoodDeckSF        125.338794
# OpenPorchSF        66.256028
# EnclosedPorch      61.119149
# 3SsnPorch          29.317331
# ...

# %%
corr = train.corr()

# %%
corr
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
train["LotArea"].hist()

# %%
y.hist()

# %%
sns.distplot(y)

# %%
sns.distplot(train["LotArea"])

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch ScreenPorch  \
# 0    AllPub    Inside  ...          61             0         0           0
# 1    AllPub       FR2  ...           0             0         0           0
# 2    AllPub    Inside  ...          42             0         0           0
# 3    AllPub    Corner  ...          35           272         0           0
# 4    AllPub       FR2  ...          84             0         0           0
#
# ...

# %%
train.iloc[0:4,0:4]
# Out:
#    Id  MSSubClass MSZoning  LotFrontage
# 0   1          60       RL         65.0
# 1   2          20       RL         80.0
# 2   3          60       RL         68.0
# 3   4          70       RL         60.0

# %%
train[train["MSZoning"]=="RL"]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# ...

# %%
for col in train.columns:
    #get dtype for column
    dt = train[col].dtype 
    #check if it is a number
    if dt == int or dt == float:
        train[col].fillna(0,inplace=True)
    else:
        train[col].fillna(train[col].mode()[0], inplace=True)

# %%
train_dum = pd.get_dummies(train)

# %%
print("shape before dummy is {} and after dummy is {}".format(train.shape,train_dum.shape))
# Out:
# shape before dummy is (1460, 76) and after dummy is (1460, 276)

# %%
train_dum.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLw  SaleType_New  \
# 0          2003       196.0         706  ...               0             0
# 1          1976         0.0         978  ...               0             0
# 2          2002       162.0         486  ...               0             0
# 3          1970         0.0         216  ...               0             0
# 4          2000       350.0         655  ...               0             0
#
# ...

# %%
train_dum_org= train_dum.copy()

# %% [markdown]
# # Dimension Reduction

# %%
from sklearn.decomposition import PCA

# %%
pc = PCA(n_components=205)

# %%
data_dim_red= pc.fit_transform(train_dum.loc[:,"MSSubClass":"SaleCondition_Partial"])

# %%
pc.explained_variance_ratio_
# Out:
# array([9.82802968e-01, 5.08463918e-03, 3.38579565e-03, 2.77709431e-03,
#        2.41016427e-03, 1.96558767e-03, 4.99470302e-04, 3.06751056e-04,
#        2.57223626e-04, 1.83018588e-04, 1.38395781e-04, 4.09895711e-05,
#        3.32777689e-05, 3.02067433e-05, 2.75962727e-05, 1.59433258e-05,
#        1.50589394e-05, 9.29469638e-06, 8.35669917e-06, 5.92640474e-06,
#        2.01572583e-06, 7.16942312e-08, 1.67742430e-08, 1.03433439e-08,
#        9.46522904e-09, 7.66430660e-09, 5.46635193e-09, 4.91092626e-09,
#        4.11088741e-09, 3.65322917e-09, 3.23066463e-09, 3.06496977e-09,
#        2.97459667e-09, 2.74961393e-09, 2.62198356e-09, 2.56000122e-09,
#        2.48733137e-09, 2.26170743e-09, 2.21531950e-09, 2.20791236e-09,
#        2.04232728e-09, 1.94290735e-09, 1.85449544e-09, 1.82445593e-09,
#        1.73675113e-09, 1.68810924e-09, 1.62696477e-09, 1.56174718e-09,
#        1.53448008e-09, 1.48332410e-09, 1.46365542e-09, 1.40123602e-09,
# ...

# %%
train_dum_red.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLw  SaleType_New  \
# 0          2003       196.0         706  ...               0             0
# 1          1976         0.0         978  ...               0             0
# 2          2002       162.0         486  ...               0             0
# 3          1970         0.0         216  ...               0             0
# 4          2000       350.0         655  ...               0             0
#
# ...

# %%
train_dum_red= train_dum_org.copy()

# %% [markdown]
# # model data split and model fit

# %%
from sklearn.model_selection import train_test_split

# %%
#train_x,test_x,train_y, test_y = train_test_split(train_dum_red.loc[:,"MSSubClass":"SaleCondition_Partial"],y,test_size =.3
#                                                  ,random_state=33)
train_x,test_x,train_y, test_y = train_test_split(data_dim_red,y,test_size =.3
                                                  ,random_state=33)

# %%
train_x.shape
# Out:
# (1022, 205)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB

# %%
model = LinearRegression(normalize=False,)

# %%
model.fit(train_x,train_y)
predict= model.predict(test_x)
pred_train= model.predict(train_x)

# %%
print("model score on test",model.score(test_x,test_y))
print("model_r2_score test",r2_score(test_y,predict))
# Out:
# model score on test 0.7710642645723337
# model_r2_score test 0.7710642645723337

# %%
print("model rms on test",mean_squared_error(test_y,predict))
print("model_rms on train",mean_squared_error(train_y,pred_train))
# Out:
# model rms on test 1487741026.3074582
# model_rms on train 481413629.2268348

# %% [markdown]
# --n_component 175
# model score on test 0.7705657445727669
# model_r2_score test 0.7705657445727669
# model rms on test 1490980663.20558
# model_rms on train 504908026.71348727
# -- 200
# model score on test 0.7713087047531301
# model_r2_score test 0.7713087047531301
# model rms on test 1486152529.4973404
# model_rms on train 483878289.1873636

# %%
model.coef_
# Out:
# array([-5.50471370e+01,  2.81675997e+00,  8.14751927e-01,  6.18975456e+03,
#         5.69542068e+03,  2.64360778e+02,  9.08554427e+01,  2.59454064e+01,
#         1.08891413e+01,  7.61488206e+00, -5.41827552e+00,  1.30856995e+01,
#         2.14252812e+01,  3.22022774e+01, -1.95125592e+01,  3.41149866e+01,
#         1.70974973e+03, -1.99211321e+03,  2.89588379e+03,  1.41485365e+03,
#        -7.89346370e+02, -1.44384660e+04,  4.47953137e+02,  3.69433012e+03,
#        -4.52987673e+00,  8.89329816e+03,  3.04824178e+00,  1.15745941e+01,
#         1.09411465e+01, -4.17231293e+00,  1.25171142e+01,  1.03094681e+01,
#         1.02140274e+02, -2.20225648e+00, -1.80067637e+02, -7.76930643e+02,
#        -1.86567886e+04,  1.05280240e+04,  3.50397208e+03,  4.72771953e+03,
#        -1.02927040e+02, -2.45220833e+04,  2.45220833e+04, -4.31662212e+03,
#         3.96112442e+02,  6.99034156e+03, -3.06983188e+03, -6.27747770e+02,
# ...

# %%
model.intercept_
# Out:
# 772438.0129074061

# %%
data =pd.DataFrame({"a":[1,2,None,3],"b":["a",None,"a","c"]})
data.fillna(method ="bfill", inplace=True)
data["b"].mode()[0]
