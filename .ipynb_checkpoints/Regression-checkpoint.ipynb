# %%
import pandas  as pd
import seaborn as sns
import matplotlib as plt

# %%
train_data = pd.read_csv("C:/Machine Learning/Hackathons/Kaggle/House Price/train_Copy.csv")
test_data = pd.read_csv("C:/Machine Learning/Hackathons/Kaggle/House Price/test_Copy.csv")

# %%
response = train_data["SalePrice"].copy()
train_data.drop(columns=["SalePrice"], inplace=True)

# %%
print("Shape for Training Data is {} and Shape for Test data is {}".format(train_data.shape,test_data.shape))
# Out:
# Shape for Training Data is (1460, 80) and Shape for Test data is (1459, 80)

# %%
train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 1         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 2         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 3         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 4         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
def missing_count(df,threshold):
    """ This function takes two arguments:
    input
        df = Dataframe
        threshold= fraction of column data in percent( between 0 and 100) having the missing values
    output
    data frame having the column name as index and missing % as the fraction missing the data"""
    if (isinstance(df, pd.DataFrame)):
        missing_data = pd.DataFrame( (df.isnull().sum().sort_values(ascending= False)/len(df))*100, columns=["Missing %"])
        return (missing_data[missing_data["Missing %"]> threshold])
    else:
        print("Passed data set is not a Dataframe!")

# %%
missing_column = missing_count(train_data,50)
print("Missing Columns are",missing_column.index)
missing_column
# Out:
# Missing Columns are Index(['PoolQC', 'MiscFeature', 'Alley', 'Fence'], dtype='object')
#              Missing %
# PoolQC       99.520548
# MiscFeature  96.301370
# Alley        93.767123
# Fence        80.753425

# %%
#to allow more rows in the output
pd.set_option("display.max_rows",85)

# %%
#above function or for a quick look by using the below one liner:
train_data.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %%
train_data.drop(columns=missing_column.index,axis=1, inplace=True)
test_data.drop(columns=missing_column.index,axis=1, inplace=True)

# %%
print("Shape for Training data after deletion is {} \nShape for Test data after deletion is {}.\nTotal column deleted are {}\nFollowing columns are deleted :  {}  ".format(train_data.shape,test_data.shape, len(missing_column), missing_column.index))
# Out:
# Shape for Training data after deletion is (1460, 76)
# Shape for Test data after deletion is (1459, 76).
# Total column deleted are 4
# Following columns are deleted :  Index(['PoolQC', 'MiscFeature', 'Alley', 'Fence'], dtype='object')

# %%
def datatypes(df):
    '''This function returns the counts of various datatype in a dataframe
    input
        df = dataframe for which to count the datatypes
    output
        obj = datatype of Object type
        nonobj = datatype of Int or Float type
        unknown = datatype other than Object or Int or Float
    '''
    obj = []
    nonobj = []
    unknown = []
    if(isinstance(df, pd.DataFrame)):
        tpe = df.dtypes
        for i in range(len(tpe)):
            if tpe[i] =="object":
                obj.append(tpe.index[i])
            elif (tpe[i] =="int64" or tpe[i] =="float64"):
                nonobj.append(tpe.index[i])
            else:
                unknown.append(tpe.index[i])
        print("Total Object Type is {}\nTotal Float or Int is {}\nTotal unknown type is {}".format(len(obj),len(nonobj),len(unknown)))
        return obj, nonobj,unknown
    else:
        print("Passed dataframe is not a Dataframe")
        return obj, nonobj, unknown

# %%
obj, nonobj, unknown = datatypes(train_data)
# Out:
# Total Object Type is 39
# Total Float or Int is 37
# Total unknown type is 0

# %%
# use the custom function or use the below python function for the same
train_data.dtypes.value_counts()
# Out:
# object     39
# int64      34
# float64     3
# dtype: int64

# %%
#sns.pairplot(data=train_data,y_vars=response, x_vars=nonobj )

# %%
from  scipy import stats

# %%
#The top level container for all the plot elements.
fig = plt.pyplot.figure(figsize=(21,15)) # its width and height in the figsize 
#Specifies the geometry of the grid that a subplot can be placed in.
grid = plt.gridspec.GridSpec(3,4,figure=fig)
#location on the grid where the plot will visible
ax1 = fig.add_subplot(grid[0, 0:2])
ax1.set_title('boxplot')
sns.boxplot(train_data.SalePrice,)
ax2 = fig.add_subplot(grid[1:, 0:2])
ax2.set_title('Histogram/DistributionPlot')
sns.distplot(train_data.SalePrice,)
ax3 = fig.add_subplot(grid[0:33,2:4])
t =stats.probplot(train_data.SalePrice, plot=sns.mpl.pyplot)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-0537f00462a0> in <module>
#       6 ax1 = fig.add_subplot(grid[0, 0:2])
#       7 ax1.set_title('boxplot')
# ----> 8 sns.boxplot(train_data.SalePrice,)
#       9 ax2 = fig.add_subplot(grid[1:, 0:2])
#      10 ax2.set_title('Histogram/DistributionPlot')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5178             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5179                 return self[name]
# -> 5180             return object.__getattribute__(self, name)
#    5181
#    5182     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'SalePrice'

# %%
def skew_kurtosis(df):
    '''This function returns the kurtosis, skewness and std of a dataframe
    input
        df = dataframe for which to count the datatypes
    output
        dataframe having three columns as skewness, kurtosis and std along with the column name.
    '''
    if(isinstance(df, pd.DataFrame)):
        _, nobj,_  = datatypes(df)
        dictionary ={"Skewness":df[nobj].skew(), "Kurtosis":df[nobj].kurt(), "Std":df[nobj].std()}
        return (pd.DataFrame(dictionary))

    else:
        print("Passed dataframe is not a Dataframe")

# %%
skew_kurtosis(train_data)
# Out:
# Total Object Type is 39
# Total Float or Int is 37
# Total unknown type is 0
#                 Skewness    Kurtosis          Std
# Id              0.000000   -1.200000   421.610009
# MSSubClass      1.407657    1.580188    42.300571
# LotFrontage     2.163569   17.452867    24.284752
# LotArea        12.207688  203.243271  9981.264932
# OverallQual     0.216944    0.096293     1.382997
# OverallCond     0.693067    1.106413     1.112799
# YearBuilt      -0.613461   -0.439552    30.202904
# YearRemodAdd   -0.503562   -1.272245    20.645407
# MasVnrArea      2.669084   10.082417   181.066207
# BsmtFinSF1      1.685503   11.118236   456.098091
# BsmtFinSF2      4.255261   20.113338   161.319273
# BsmtUnfSF       0.920268    0.474994   441.866955
# TotalBsmtSF     1.524255   13.250483   438.705324
# 1stFlrSF        1.376757    5.745841   386.587738
# 2ndFlrSF        0.813030   -0.553464   436.528436
# LowQualFinSF    9.011341   83.234817    48.623081
# ...

# %%
#Use the above function or below single python function along with sorting of values:
train_data[nonobj].kurt().sort_values(ascending= False)
# Out:
# MiscVal          701.003342
# PoolArea         223.268499
# LotArea          203.243271
# 3SsnPorch        123.662379
# LowQualFinSF      83.234817
# KitchenAbvGr      21.532404
# BsmtFinSF2        20.113338
# ScreenPorch       18.439068
# LotFrontage       17.452867
# BsmtHalfBath      16.396642
# TotalBsmtSF       13.250483
# BsmtFinSF1        11.118236
# EnclosedPorch     10.430766
# MasVnrArea        10.082417
# OpenPorchSF        8.490336
# 1stFlrSF           5.745841
# GrLivArea          4.895121
# WoodDeckSF         2.992951
# BedroomAbvGr       2.230875
# MSSubClass         1.580188
# OverallCond        1.106413
# GarageArea         0.917067
# TotRmsAbvGrd       0.880762
# BsmtUnfSF          0.474994
# GarageCars         0.220998
# OverallQual        0.096293
# Fireplaces        -0.217237
# MoSold            -0.404109
# GarageYrBlt       -0.418341
# YearBuilt         -0.439552
# 2ndFlrSF          -0.553464
# BsmtFullBath      -0.839098
# FullBath          -0.857043
# ...

# %%
#Use the above function or below single python function along with sorting of values:
train_data[nonobj].skew().sort_values(ascending= False)
# Out:
# MiscVal          24.476794
# PoolArea         14.828374
# LotArea          12.207688
# 3SsnPorch        10.304342
# LowQualFinSF      9.011341
# KitchenAbvGr      4.488397
# BsmtFinSF2        4.255261
# ScreenPorch       4.122214
# BsmtHalfBath      4.103403
# EnclosedPorch     3.089872
# MasVnrArea        2.669084
# OpenPorchSF       2.364342
# LotFrontage       2.163569
# BsmtFinSF1        1.685503
# WoodDeckSF        1.541376
# TotalBsmtSF       1.524255
# MSSubClass        1.407657
# 1stFlrSF          1.376757
# GrLivArea         1.366560
# BsmtUnfSF         0.920268
# 2ndFlrSF          0.813030
# OverallCond       0.693067
# TotRmsAbvGrd      0.676341
# HalfBath          0.675897
# Fireplaces        0.649565
# BsmtFullBath      0.596067
# OverallQual       0.216944
# MoSold            0.212053
# BedroomAbvGr      0.211790
# GarageArea        0.179981
# YrSold            0.096269
# FullBath          0.036562
# Id                0.000000
# GarageCars       -0.342549
# ...

# %%
#Use the above function or below single python function along with sorting of values:
train_data[nonobj].std().sort_values(ascending= False)

# %%
missing_count(train_data,0)

# %%
train_data[missing_count(train_data,0.001).index].head()
# Out:
#   FireplaceQu  LotFrontage GarageCond GarageQual GarageType  GarageYrBlt  \
# 0         NaN         65.0         TA         TA     Attchd       2003.0
# 1          TA         80.0         TA         TA     Attchd       1976.0
# 2          TA         68.0         TA         TA     Attchd       2001.0
# 3          Gd         60.0         TA         TA     Detchd       1998.0
# 4          TA         84.0         TA         TA     Attchd       2000.0
#
#   GarageFinish BsmtFinType2 BsmtExposure BsmtQual BsmtCond BsmtFinType1  \
# 0          RFn          Unf           No       Gd       TA          GLQ
# 1          RFn          Unf           Gd       Gd       TA          ALQ
# 2          RFn          Unf           Mn       Gd       TA          GLQ
# 3          Unf          Unf           No       TA       Gd          ALQ
# 4          RFn          Unf           Av       Gd       TA          GLQ
#
#    MasVnrArea MasVnrType Electrical
# 0       196.0    BrkFace      SBrkr
# ...

# %%
def fill_missing(df,threshold):
    '''This function returns the dataframe with no missing values
    input
        df = dataframe for which to fill the missing values
    output
        dataframe with filled missing values.
    '''
    if(isinstance(df,pd.DataFrame)):
        if(threshold >=0 and threshold <= 100):
            col = missing_count(df,threshold).index
            for i in col:
                if ((df[i].dtypes == "float64") or (df[i].dtypes == "int64") ):
                    df[i].fillna(df[i].mean(), inplace = True)
                else:
        # always be cautious with Mode, as The problem here is that mode returns a series and 
        #this is causing the fillna to faill, as mode returns a series so you have to access 
        #the first element as shown below with [0]
                    df[i].fillna(df[i].mode()[0], inplace = True)
                    #print(df[i].unique())
            return df
        else:
            print("Threshold should be in between 0-100")
    else:
        print("Passed dataframe is not a Dataframe")

# %%
fill_missing(train_data,0)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# ...

# %%
def unique_values(df):
    '''This function returns the unique values in a dataframe
    input
        df = dataframe for which to find the unique values
    output
        dataframe with the details of each object column, total_unique_count for that column
        , total_unique_values_for_that_column, unique_value, unique_value_record_counts.
    '''
    if(isinstance(df, pd.DataFrame)):
        obj,_,_ = datatypes(df)
        items = []
        for i in obj:
            g = df.groupby(df[i])
            for ke,val in g.groups.items():
                values =[]
                values.append(i)
                values.append(len(g.groups.keys()))
                values.append(g.groups.keys())
                values.append(ke)
                values.append(len(val))
                items.append(values)
            q = pd.DataFrame(items,columns=["col_name","col_unq_val_count",
                                            "col_total_unq_val",
                                            "col_unq_val",
                                            "unq_val_count"])
        return(q)
    else:
        print("Passed dataframe is not a Dataframe")

# %%
unq = unique_values(train_data)
# Out:
# Total Object Type is 39
# Total Float or Int is 37
# Total unknown type is 0

# %%
unq.sort_values(["col_unq_val_count","col_name"],ascending = False)
# Out:
#          col_name  col_unq_val_count  \
# 25   Neighborhood                 25
# 26   Neighborhood                 25
# 27   Neighborhood                 25
# 28   Neighborhood                 25
# 29   Neighborhood                 25
# ..            ...                ...
# 16      Utilities                  2
# 5          Street                  2
# 6          Street                  2
# 179    CentralAir                  2
# 180    CentralAir                  2
#
#                                      col_total_unq_val col_unq_val  \
# 25   (Blmngtn, Blueste, BrDale, BrkSide, ClearCr, C...     Blmngtn
# 26   (Blmngtn, Blueste, BrDale, BrkSide, ClearCr, C...     Blueste
# 27   (Blmngtn, Blueste, BrDale, BrkSide, ClearCr, C...      BrDale
# 28   (Blmngtn, Blueste, BrDale, BrkSide, ClearCr, C...     BrkSide
# 29   (Blmngtn, Blueste, BrDale, BrkSide, ClearCr, C...     ClearCr
# ..                                                 ...         ...
# ...

# %%
train_data_dum = pd.get_dummies(train_data)
print("shape of the data changed from {} to {}".format(train_data.shape, train_data_dum.shape))
# Out:
# shape of the data changed from (1460, 76) to (1460, 276)

# %%
train_data_dum.head()

# %%
train_data.nunique().sort_values(ascending = False)
# Out:
# Id               1460
# LotArea          1073
# GrLivArea         861
# BsmtUnfSF         780
# 1stFlrSF          753
# TotalBsmtSF       721
# BsmtFinSF1        637
# GarageArea        441
# 2ndFlrSF          417
# MasVnrArea        328
# WoodDeckSF        274
# OpenPorchSF       202
# BsmtFinSF2        144
# EnclosedPorch     120
# YearBuilt         112
# LotFrontage       111
# GarageYrBlt        98
# ScreenPorch        76
# YearRemodAdd       61
# Neighborhood       25
# LowQualFinSF       24
# MiscVal            21
# 3SsnPorch          20
# Exterior2nd        16
# MSSubClass         15
# Exterior1st        15
# TotRmsAbvGrd       12
# MoSold             12
# OverallQual        10
# OverallCond         9
# SaleType            9
# Condition1          9
# RoofMatl            8
# Condition2          8
# BedroomAbvGr        8
# PoolArea            8
# HouseStyle          8
# Functional          7
# RoofStyle           6
# Foundation          6
# BsmtFinType1        6
# ...

# %% [markdown]
# # Dimension Reduction

# %%
from sklearn.decomposition import PCA, SparsePCA,KernelPCA

# %%
train_data_dum_copy = train_data_dum.copy()

# %%
pc = PCA(n_components=210)
#pc = KernelPCA(n_components=50)
#pc = SparsePCA(n_components=50)

# %%
train_data_dum_copy.head()

# %%
train_data_dum_copy = pc.fit_transform(train_data_dum_copy)

# %%
train_data_dum_copy.head()

# %%
train_data_dum_copy[0:1,]

# %%
train_data_dum_copy.shape

# %% [markdown]
# # Multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
train_data_dum.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        ...
#        'SaleType_ConLw', 'SaleType_New', 'SaleType_Oth', 'SaleType_WD',
#        'SaleCondition_Abnorml', 'SaleCondition_AdjLand',
#        'SaleCondition_Alloca', 'SaleCondition_Family', 'SaleCondition_Normal',
#        'SaleCondition_Partial'],
#       dtype='object', length=276)

# %%
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(train_data[nonobj].values, i) for i in range(train_data[nonobj].shape[1])]
vif["features"] = train_data[nonobj].columns
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:185: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)

# %%
vif

# %%
train_data_dum["GrLivArea"].unique

# %% [markdown]
# # Data Split

# %%
from sklearn.model_selection import train_test_split

# %%
train_x, test_x, train_y, test_y = train_test_split(
    train_data_dum, 
    response,test_size=0.30, random_state=42)

# %%
print("shape for split trainx is {} and split testx is {}".format(train_x.shape, test_x.shape))
print("shape for split trainy is {} and splity test is {}".format(train_y.shape, test_y.shape))
# Out:
# shape for split trainx is (1022, 276) and split testx is (438, 276)
# shape for split trainy is (1022,) and splity test is (438,)

# %%
from sklearn.linear_model import (LinearRegression, Lasso,Ridge,SGDRegressor
                                  ,ElasticNet)
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import GridSearchCV, cross_val_score , KFold
import matplotlib as plt
import seaborn as sns

# %%
def model_output(mod, tr_x,te_x,tr_y,te_y):
    mod.fit(tr_x,tr_y)
    pred_test = mod.predict(te_x)
    pred_train = mod.predict(tr_x)
    error_test = mean_squared_error(te_y,pred_test)
    error_train = mean_squared_error(tr_y,pred_train)
    r_squared_train = mod.score(tr_x,tr_y)
    r_squared_test = mod.score(te_x,te_y)
    adj_r_sqr_train = 1 - (1-r_squared_train)*(len(tr_y)-1)/(len(tr_y)-tr_x.shape[1]-1)
    adj_r_sqr_test = 1 - (1-r_squared_test)*(len(te_y)-1)/(len(te_y)-tr_x.shape[1]-1)
    print("Train score is: {}\ntest score is: {}".format(r_squared_train,r_squared_test))
    print("adj r2 train is : {}\nadj r2 test is : {} ".format(adj_r_sqr_train,adj_r_sqr_test ))
    print("Train error is:{}\ntest error is: {}".format(error_train,error_test))
    
    
    #The top level container for all the plot elements.
    fig = plt.pyplot.figure(figsize=(8,10)) # its width and height in the figsize 
    #Specifies the geometry of the grid that a subplot can be placed in.
    grid = plt.gridspec.GridSpec(2,1,figure=fig)
    #location on the grid where the plot will visible
    ax1 = fig.add_subplot(grid[0, 0])
    ax1.set_title('Train Residual Plot')
    sns.residplot(tr_y, pred_train)
    ax2 = fig.add_subplot(grid[1:, 0])
    ax2.set_title('Test Residual Plot')
    sns.residplot(te_y,pred_test)

# %%
mod = LinearRegression(normalize=True)
model_output(mod, train_x,test_x,train_y,test_y)
# Out:
# Train score is: 0.9339161552890259
# test score is: -1.757650782843102e+20
# adj r2 train is : 0.9094340866444235
# adj r2 test is : -4.770766410574134e+20
# Train error is:397730606.60273975
# test error is: 1.2265051961667535e+30

# %%
k = KFold(n_splits=4, shuffle=True)

# %%
k
# Out:
# KFold(n_splits=4, random_state=None, shuffle=True)

# %%
mod = SGDRegressor(loss="squared_loss",penalty="none",max_iter=5000,tol= 1e-3,
                   random_state=44, learning_rate = "invscaling",eta0=.01,alpha=1000
                   )
model_output(mod, train_x,test_x,train_y,test_y)

# %%
mod = Lasso(max_iter=5000, random_state = 40)
model_output(mod, train_x,test_x,train_y,test_y)

# %%
mod = Ridge(random_state = 40)
model_output(mod, train_x,test_x,train_y,test_y)

# %%
mod= ElasticNet(random_state = 40,max_iter=6000)
model_output(mod, train_x,test_x,train_y,test_y)

# %%
from sklearn.tree import DecisionTreeRegressor,ExtraTreeRegressor
from sklearn.ensemble import RandomForestRegressor
#mod = ExtraTreeRegressor(max_depth=7,max_features="sqrt",random_state = 48)
#mod = DecisionTreeRegressor(max_depth=8,max_features="sqrt",random_state = 48)
mod = RandomForestRegressor(n_estimators=3000,max_depth=3,max_features="auto")

# %%
model_output(mod, train_x,test_x,train_y,test_y)

# %%
train_data[nonobj].shape

# %%
np.cov(train_data[nonobj].values,rowvar = False)

# %%
train_data.corr().head()
