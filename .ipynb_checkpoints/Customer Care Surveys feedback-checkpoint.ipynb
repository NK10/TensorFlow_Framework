# %%
import numpy as np
import nltk as nl
from gensim.models import Word2Vec
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import os
from nltk.corpus import stopwords
import string
from collections import Counter
from gensim.parsing.porter import PorterStemmer
from gensim.utils import lemmatize
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\utils.py:1212: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Embedding
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.layers import LSTM
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from numpy import array
# Out:
# Using TensorFlow backend.

# %%
surveys = pd.read_excel("C:\\Machine Learning\\Hackathons\\Xerox\\customer_Care_Survey_Refined.XLSX",header=0,sheet_name="Sheet2")

# %%
surveys.shape
# Out:
# (2315, 31)

# %%
surveys.head()
# Out:
#     Month  RespondentID  CollectorID           StartDate             EndDate  \
# 0  201812    5576030682     39775725 2018-12-31 14:41:01 2018-12-31 14:42:00
# 1  201812    5576020478     39775725 2018-12-31 13:29:57 2018-12-31 13:30:27
# 2  201812    5576004947     39775725 2018-12-31 11:52:58 2018-12-31 11:57:57
# 3  201812    5575981269     39775725 2018-12-31 09:47:29 2018-12-31 09:48:44
# 4  201812    5575964427     39775725 2018-12-31 08:17:20 2018-12-31 08:17:58
#
#         IP Address  Email Address  First Name  LastName  Custom Data  ...  \
# 0       13.13.16.1            NaN         NaN       NaN          NaN  ...
# 1      13.8.125.11            NaN         NaN       NaN          NaN  ...
# 2    96.61.151.223            NaN         NaN       NaN          NaN  ...
# 3    173.161.54.97            NaN         NaN       NaN          NaN  ...
# 4  172.100.193.136            NaN         NaN       NaN          NaN  ...
#
#              REASON_CODE                    ROUTING_CODE          CLOSE_DATE  \
# 0    Equip Billing Dates                          Meters 2018-12-31 15:08:42
# 1  Equip Billing Pricing                            Base 2018-12-31 10:36:25
# 2           Late Charges  Late Charge Incorrectly Billed 2018-12-31 13:51:43
# 3             Web Issues                      EIPP Issue 2018-12-26 14:10:52
# 4      Equip Performance                 Downtime Credit 2018-12-26 09:32:29
#
#                        ROOTCAUSE                      Rep Name  \
# 0           Customer Explanation   Manzo Navas, Jose Alejandro
# 1  OTI Edit Defect / VQUIX Issue                 Mancil, David
# 2                            NaN             Revolorio, Yanira
# 3                          Other              Pinot, Stephanie
# 4                Equipment Issue  Ramirez Moreira, Cesar Mario
#
#                    Mgr Name  Disposition                      eMail Count1  \
# 0                Jose Rubio   Resolution                  na@na.com    NaN
# 1  Elizabeth Campbell-Moore   Resolution  eriban.arenales@xerox.com    NaN
# 2              Mario Pineda          POC    pam@windsormountain.org    NaN
# 3             Maria Acevedo   Resolution       renee@busybeaver.net    NaN
# 4                Jose Rubio   Resolution     keith.koster@xerox.com    NaN
#
#   Count2
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
#
# [5 rows x 31 columns]

# %%
surveys_comments = pd.DataFrame({"SR#":surveys["SR#"],
                                 "Comments":surveys["Do you have any other details you want to share regarding the ha"],
                                 "Additional_Comments":surveys["Please provide details#"],
                                 "Full_Comments":surveys["Full_Comments"],
                                 "Customer_SAT_Score":surveys["How satisfied are you with the way your issue was resolved?"]})

# %%
surveys_comments.shape
# Out:
# (2315, 5)

# %%
surveys_comments.head()
# Out:
#               SR#                                           Comments  \
# 0  1-101526171125  Many thanks for understanding this issue and r...
# 1  1-101320199441                   Thank you for everything David!
# 2  1-101571535327  We have been a customer of yours for many many...
# 3  1-101428425708  It doesn't feel like a person helped me at all...
# 4  1-101292413714                                               none
#
#                                  Additional_Comments  \
# 0                                                NaN
# 1                                                NaN
# 2  No one wants to resolve this issue.  Everyone ...
# 3  I needed information on a recurring bill we're...
# 4                                                NaN
#
#                                        Full_Comments  Customer_SAT_Score
# 0  Many thanks for understanding this issue and r...                  10
# 1                  Thank you for everything David!                    10
# 2  We have been a customer of yours for many many...                   1
# 3  It doesn't feel like a person helped me at all...                   1
# 4                                              none                   10

# %%
surveys_comments["Full_Comments"][3], surveys_comments["Customer_SAT_Score"][3]
# Out:
# ("It doesn't feel like a person helped me at all.  It felt like an automated response. I needed information on a recurring bill we're paying and did not receive an answer.  Instead, I was pointed to log into the website to review - but it only has 1 of 2 of our bills on the website portal.",
#  1)

# %%
surveys_comments.groupby(["Customer_SAT_Score"])["Customer_SAT_Score"].count()
# Out:
# Customer_SAT_Score
# 0       72
# 1      792
# 2       85
# 3       39
# 4       22
# 5       65
# 6       24
# 7       36
# 8       70
# 9      107
# 10    1003
# Name: Customer_SAT_Score, dtype: int64

# %%
surveys_comments.loc[surveys_comments["Customer_SAT_Score"]<8,"Customer_SAT_Score"] = 0
surveys_comments.loc[surveys_comments["Customer_SAT_Score"]>=8,"Customer_SAT_Score"] = 1

# %%
surveys_comments.head()
# Out:
#               SR#                                           Comments  \
# 0  1-101526171125  Many thanks for understanding this issue and r...
# 1  1-101320199441                   Thank you for everything David!
# 2  1-101571535327  We have been a customer of yours for many many...
# 3  1-101428425708  It doesn't feel like a person helped me at all...
# 4  1-101292413714                                               none
#
#                                  Additional_Comments  \
# 0                                                NaN
# 1                                                NaN
# 2  No one wants to resolve this issue.  Everyone ...
# 3  I needed information on a recurring bill we're...
# 4                                                NaN
#
#                                        Full_Comments  Customer_SAT_Score
# 0  Many thanks for understanding this issue and r...                   1
# 1                  Thank you for everything David!                     1
# 2  We have been a customer of yours for many many...                   0
# 3  It doesn't feel like a person helped me at all...                   0
# 4                                              none                    1

# %%
len(surveys_comments)
# Out:
# 2315

# %%
surveys_comments.loc[1]
# Out:
# SR#                                       1-101320199441
# Comments                Thank you for everything David!
# Additional_Comments                                  NaN
# Full_Comments          Thank you for everything David!
# Customer_SAT_Score                                     1
# Name: 1, dtype: object

# %% [markdown]
# ## K-mean clustering of text

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd

# %%
vocab = []
for i in range(10):
    tokens = clean_doc(surveys_comments["Full_Comments"].iloc[i])
    #print(tokens)
    vocab.append(tokens)
    #docss= clean_doc(surveys_comments["Full_Comments"])

# %%
vectorizer = TfidfVectorizer(stop_words='english')
XX = vectorizer.fit_transform(surveys_comments["Full_Comments"])

# %%
xx = CountVectorizer(lowercase=True)

# %%
true_k = 3
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=50, n_init=3)
model.fit(XX)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=50,
#        n_clusters=3, n_init=3, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
model.inertia_
# Out:
# 2125.654114994202

# %%
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()

# %%
order_centroids
# Out:
# array([[2312, 2718, 4282, ..., 3428, 3429,    0],
#        [4680, 4684, 2071, ..., 3412, 3413,    0],
#        [2681, 5135, 1540, ..., 2686, 2138, 4121]], dtype=int64)

# %%
for i in range(true_k):
     print("Cluster %d:" % i),
     for ind in order_centroids[i, :11]: # change 11 to see less or more cluster words
         print("%s" % terms[ind])
# Out:
# Cluster 0:
# thank
# thanks
# fast
# quick
# response
# prompt
# great
# service
# request
# excellent
# turnaround
# Cluster 1:
# issue
# xerox
# great
# customer
# service
# time
# job
# resolved
# request
# received
# invoice

# %% [markdown]
# ## end Clustering

# %%
from sklearn.model_selection import train_test_split
import os
from nltk.corpus import stopwords
import string
from collections import Counter

# %%
trainx_outer, testx_outer,trainy_outer, testy_outer = train_test_split(surveys_comments,
                                                                       surveys_comments["Customer_SAT_Score"],test_size=0.30,random_state =10,
                                                                       stratify = surveys_comments["Customer_SAT_Score"])

# %%
trainx_outer.shape, testx_outer.shape,trainy_outer.shape, testy_outer.shape
# Out:
# ((1620, 5), (695, 5), (1620,), (695,))

# %%
def clean_doc(doc):
    # split into tokens by white space
    tokens = doc.split()
    # remove punctuation from each token
    table = str.maketrans('', '', string.punctuation)
    #print("table values are :\n")
    tokens = [w.translate(table) for w in tokens]
    # remove remaining tokens that are not alphabetic
    tokens = [word for word in tokens if word.isalpha()]
    # filter out stop words
    stop_words = set(stopwords.words('english'))
    tokens = [w for w in tokens if not w in stop_words]
    # filter out short tokens
    tokens = [word for word in tokens if len(word) > 1]
    return tokens

# %%
trainx_outer.head()
# Out:
#                  SR#                                           Comments  \
# 496    1-99913066561                                                NaN
# 55    1-101376461717  Just because one order was changed for billing...
# 1055   1-98812644668       Susan provides efficient and timely service!
# 2056   1-95393097403  It is not the reps fault - he did nothing.  It...
# 2212   1-94645384791  The request to update the bill to address was ...
#
#                                     Additional_Comments  \
# 496   The issue was not resolved correctly. It took ...
# 55                                                  NaN
# 1055                                                NaN
# 2056  Xerox has not yet completed fixing the invoice...
# 2212                                                NaN
#
#                                           Full_Comments  Customer_SAT_Score
# 496    The issue was not resolved correctly. It took...                   0
# 55    Just because one order was changed for billing...                   1
# 1055      Susan provides efficient and timely service!                    1
# 2056  It is not the reps fault - he did nothing.  It...                   0
# 2212  The request to update the bill to address was ...                   1

# %%
testx_outer.head()
# Out:
#                 SR#                                           Comments  \
# 1870  1-95729377061                                             thanks
# 1243  1-98294230571                         Super detailed and helpful
# 1535  1-97220593657                           great service  thank you
# 1851  1-96315095579  Received invoice copies in a few days apprecia...
# 2113  1-95335731026  This request was handled very quickly!  Thank ...
#
#      Additional_Comments                                      Full_Comments  \
# 1870                 NaN                                            thanks
# 1243                 NaN                        Super detailed and helpful
# 1535                 NaN                          great service  thank you
# 1851                 NaN  Received invoice copies in a few days apprecia...
# 2113                 NaN  This request was handled very quickly!  Thank ...
#
#       Customer_SAT_Score
# 1870                   1
# 1243                   1
# 1535                   1
# 1851                   1
# 2113                   1

# %%
trainx_outer.iloc[3,3]
# Out:
# 'It is not the reps fault - he did nothing.  It is not in his hands to fix the issues. Xerox has not yet completed fixing the invoice issues that started in June.'

# %%
vocab = Counter()
for i in range(len(trainx_outer)):
    #pass the Full_comment column for each row in the train_outer
    tokens = clean_doc(trainx_outer.iloc[i,3])
    vocab.update(tokens)

# %%
vocab
# Out:
# Counter({'The': 346,
#          'issue': 321,
#          'resolved': 207,
#          'correctly': 28,
#          'It': 149,
#          'took': 100,
#          'research': 14,
#          'end': 38,
#          'discover': 1,
#          'still': 194,
#          'billed': 51,
#          'incorrectly': 11,
#          'Just': 9,
#          'one': 155,
#          'order': 97,
#          'changed': 39,
#          'billing': 110,
#          'without': 41,
#          'authorization': 2,
#          'main': 4,
#          'entity': 3,
#          'nothing': 28,
#          'customer': 266,
#          'service': 233,
#          'person': 86,
#          'way': 52,
#          'managed': 3,
#          'Susan': 17,
#          'provides': 7,
#          'efficient': 22,
#          'timely': 40,
#          'reps': 22,
#          'fault': 18,
#          'hands': 3,
#          'fix': 19,
#          'issues': 52,
#          'Xerox': 425,
#          'yet': 44,
#          'completed': 42,
#          'fixing': 2,
#          'invoice': 208,
#          'started': 8,
#          'June': 26,
#          'request': 226,
#          'update': 32,
#          'bill': 61,
#          'address': 128,
#          'see': 51,
#          'prior': 14,
#          'comment': 6,
#          'Can': 10,
#          'split': 2,
#          'difference': 4,
#          'since': 76,
#          'readings': 5,
#          'taken': 31,
#          'guys': 8,
#          'notes': 6,
#          'really': 34,
#          'use': 26,
#          'machine': 147,
#          'Demo': 1,
#          'clicks': 6,
#          'charging': 6,
#          'states': 9,
#          'reading': 4,
#          'moved': 6,
#          'facility': 5,
#          'continued': 4,
#          'fact': 17,
#          'testing': 2,
#          'etc': 10,
#          'get': 233,
#          'us': 96,
#          'set': 23,
#          'We': 166,
#          'could': 79,
#          'print': 16,
#          'projects': 1,
#          'due': 46,
#          'printing': 4,
#          'used': 19,
#          'another': 68,
#          'AG': 1,
#          'finally': 27,
#          'Jon': 1,
#          'Tinnel': 1,
#          'Thursday': 1,
#          'July': 26,
#          'pm': 4,
#          'reinstall': 1,
#          'programs': 1,
#          'server': 1,
#          'correct': 69,
#          'colorusage': 1,
#          'press': 2,
#          'afternoon': 5,
#          'That': 35,
#          'done': 62,
#          'starting': 3,
#          'number': 118,
#          'month': 59,
#          'sign': 5,
#          'sheet': 3,
#          'collaborates': 1,
#          'infoPlease': 1,
#          'adjust': 2,
#          'accordingly': 1,
#          'log': 12,
#          'For': 12,
#          'large': 5,
#          'color': 9,
#          'know': 102,
#          'include': 1,
#          'previous': 20,
#          'separated': 1,
#          'written': 10,
#          'charge': 53,
#          'never': 98,
#          'received': 192,
#          'quote': 23,
#          'hate': 3,
#          'dealing': 15,
#          'emails': 49,
#          'phone': 93,
#          'call': 182,
#          'menu': 2,
#          'hell': 2,
#          'giant': 2,
#          'turn': 15,
#          'want': 34,
#          'company': 68,
#          'This': 159,
#          'whole': 17,
#          'thing': 10,
#          'explosion': 1,
#          'problem': 84,
#          'needed': 77,
#          'developer': 1,
#          'sent': 171,
#          'po': 1,
#          'provided': 78,
#          'arrived': 5,
#          'given': 32,
#          'approval': 1,
#          'send': 62,
#          'back': 113,
#          'No': 71,
#          'ever': 23,
#          'able': 62,
#          'explain': 10,
#          'many': 31,
#          'ordered': 12,
#          'give': 23,
#          'refund': 14,
#          'developers': 1,
#          'Overall': 2,
#          'positive': 2,
#          'experience': 22,
#          'trying': 49,
#          'resolve': 81,
#          'February': 5,
#          'hence': 2,
#          'final': 17,
#          'question': 34,
#          'spoken': 4,
#          'multiple': 26,
#          'individuals': 2,
#          'Ms': 11,
#          'Ronal': 2,
#          'Vinicio': 1,
#          'Nitch': 1,
#          'Teque': 1,
#          'ownership': 24,
#          'investigated': 3,
#          'situation': 33,
#          'accurately': 6,
#          'pleasure': 9,
#          'deal': 14,
#          'HELPFUL': 1,
#          'AND': 12,
#          'PLEASANT': 1,
#          'TO': 27,
#          'SPEAK': 1,
#          'WITH': 12,
#          'THANK': 9,
#          'YOU': 12,
#          'like': 76,
#          'last': 36,
#          'week': 30,
#          'department': 48,
#          'messed': 3,
#          'Your': 28,
#          'first': 54,
#          'representative': 83,
#          'spoke': 42,
#          'subject': 1,
#          'polite': 17,
#          'helpful': 62,
#          'amazing': 4,
#          'practices': 1,
#          'concerns': 6,
#          'credit': 108,
#          'cause': 3,
#          'concern': 12,
#          'active': 2,
#          'level': 9,
#          'upsetting': 3,
#          'However': 21,
#          'Sarah': 5,
#          'Monterroso': 1,
#          'de': 3,
#          'Melgar': 1,
#          'astonishingly': 1,
#          'job': 85,
#          'cleaning': 2,
#          'long': 61,
#          'standing': 4,
#          'mess': 3,
#          'Her': 6,
#          'follow': 28,
#          'impressive': 1,
#          'well': 35,
#          'Dealt': 1,
#          'unprofessional': 4,
#          'Need': 7,
#          'talk': 21,
#          'someone': 84,
#          'supervisory': 1,
#          'position': 4,
#          'Please': 72,
#          'provide': 41,
#          'contact': 87,
#          'terrible': 7,
#          'already': 29,
#          'wasted': 4,
#          'much': 71,
#          'time': 252,
#          'providing': 13,
#          'details': 17,
#          'review': 8,
#          'requested': 110,
#          'serial': 30,
#          'realigned': 1,
#          'new': 77,
#          'email': 200,
#          'Pushed': 1,
#          'else': 24,
#          'called': 95,
#          'help': 74,
#          'whats': 4,
#          'unhelpful': 2,
#          'dealt': 10,
#          'business': 29,
#          'comments': 6,
#          'supplying': 1,
#          'endless': 3,
#          'paperwork': 9,
#          'years': 35,
#          'change': 52,
#          'WorkCentre': 2,
#          'Pro': 1,
#          'And': 9,
#          'seems': 23,
#          'accomplished': 2,
#          'even': 77,
#          'though': 23,
#          'told': 118,
#          'repairs': 2,
#          'keeps': 4,
#          'getting': 60,
#          'owner': 5,
#          'haggle': 1,
#          'late': 94,
#          'charges': 44,
#          'When': 33,
#          'representatives': 22,
#          'discus': 1,
#          'doesnt': 21,
#          'actually': 26,
#          'work': 74,
#          'latest': 1,
#          'response': 125,
#          'got': 71,
#          'changing': 3,
#          'makes': 8,
#          'absolutely': 9,
#          'ZERO': 1,
#          'sense': 12,
#          'cant': 31,
#          'anyone': 32,
#          'tell': 22,
#          'supposed': 12,
#          'mean': 4,
#          'per': 14,
#          'conversation': 9,
#          'cannot': 24,
#          'account': 134,
#          'two': 46,
#          'different': 46,
#          'legal': 4,
#          'entities': 1,
#          'however': 15,
#          'past': 17,
#          'effective': 7,
#          'UHREALLY': 1,
#          'plain': 1,
#          'STUPID': 1,
#          'wish': 15,
#          'equipment': 42,
#          'wasnt': 24,
#          'good': 48,
#          'Im': 47,
#          'tired': 3,
#          'horrible': 11,
#          'feel': 22,
#          'check': 25,
#          'recheck': 1,
#          'every': 33,
#          'dealings': 2,
#          'made': 48,
#          'wonder': 2,
#          'run': 13,
#          'bunch': 2,
#          'crooks': 1,
#          'My': 73,
#          'inquiry': 71,
#          'regarding': 33,
#          'sales': 48,
#          'tax': 37,
#          'invoices': 203,
#          'agreements': 14,
#          'click': 5,
#          'came': 24,
#          'said': 53,
#          'OK': 1,
#          'mandatory': 2,
#          'Ill': 3,
#          'BOE': 1,
#          'lawyer': 1,
#          'interim': 1,
#          'perhaps': 2,
#          'somebody': 5,
#          'leases': 6,
#          'NOT': 43,
#          'charged': 35,
#          'FAST': 1,
#          'waiting': 38,
#          'report': 8,
#          'need': 126,
#          'important': 4,
#          'receive': 71,
#          'would': 222,
#          'preferred': 2,
#          'day': 34,
#          'ok': 5,
#          'Without': 3,
#          'instructions': 13,
#          'located': 7,
#          'add': 6,
#          'information': 131,
#          'easy': 7,
#          'find': 34,
#          'Thank': 149,
#          'Initially': 2,
#          'believe': 14,
#          'addressed': 24,
#          'contacted': 32,
#          'sure': 62,
#          'She': 53,
#          'screen': 8,
#          'shot': 1,
#          'changes': 6,
#          'assure': 4,
#          'Very': 53,
#          'happy': 18,
#          'effort': 9,
#          'case': 44,
#          'closed': 57,
#          'Great': 41,
#          'Job': 9,
#          'days': 48,
#          'longer': 28,
#          'hoped': 1,
#          'satisfactorily': 1,
#          'professional': 50,
#          'policies': 3,
#          'Ive': 30,
#          'always': 49,
#          'part': 33,
#          'sudden': 2,
#          'going': 39,
#          'techs': 5,
#          'Once': 10,
#          'limited': 2,
#          'nice': 12,
#          'letter': 21,
#          'asking': 23,
#          'terms': 8,
#          'buy': 6,
#          'lease': 46,
#          'second': 23,
#          'typical': 1,
#          'weve': 2,
#          'reason': 17,
#          'gone': 7,
#          'Support': 2,
#          'Service': 31,
#          'Thanks': 56,
#          'enough': 11,
#          'You': 49,
#          'folks': 2,
#          'cease': 1,
#          'astound': 1,
#          'CANCELLED': 1,
#          'contract': 107,
#          'lady': 7,
#          'Giselle': 1,
#          'Bruce': 1,
#          'ext': 4,
#          'assured': 5,
#          'care': 72,
#          'bills': 11,
#          'inquiries': 13,
#          'Then': 11,
#          'January': 14,
#          'meter': 27,
#          'reads': 9,
#          'Get': 3,
#          'act': 4,
#          'together': 7,
#          'stop': 4,
#          'hoping': 3,
#          'wont': 8,
#          'pay': 57,
#          'attention': 14,
#          'mountain': 1,
#          'guessing': 2,
#          'hope': 10,
#          'miss': 1,
#          'something': 24,
#          'owe': 13,
#          'money': 13,
#          'Terri': 2,
#          'excellent': 25,
#          'resolving': 19,
#          'thanks': 19,
#          'quickly': 42,
#          'pushed': 3,
#          'rep': 126,
#          'responsibility': 5,
#          'agreement': 24,
#          'support': 32,
#          'extremely': 19,
#          'understanding': 10,
#          'Resolved': 2,
#          'logged': 12,
#          'closure': 14,
#          'notification': 14,
#          'included': 16,
#          'There': 37,
#          'needing': 2,
#          'credits': 16,
#          'In': 24,
#          'addition': 5,
#          'applied': 21,
#          'open': 23,
#          'great': 70,
#          'quick': 47,
#          'resolution': 91,
#          'copy': 51,
#          'Purchase': 3,
#          'Order': 5,
#          'All': 17,
#          'communication': 33,
#          'via': 25,
#          'Email': 1,
#          'Would': 5,
#          'faster': 10,
#          'around': 38,
#          'submitting': 7,
#          'requests': 26,
#          'Jose': 19,
#          'David': 19,
#          'working': 40,
#          'Billing': 4,
#          'nearly': 7,
#          'impossible': 4,
#          'understand': 46,
#          'explained': 20,
#          'story': 2,
#          'TWICE': 2,
#          'Second': 2,
#          'pretty': 9,
#          'idea': 14,
#          'talking': 6,
#          'build': 1,
#          'confidence': 3,
#          'team': 34,
#          'basically': 5,
#          'wrong': 35,
#          'paying': 17,
#          'based': 4,
#          'Invoice': 12,
#          'Customer': 59,
#          'Which': 2,
#          'far': 13,
#          'NO': 21,
#          'AP': 2,
#          'Specialist': 3,
#          'numbers': 22,
#          'feeling': 2,
#          'ran': 2,
#          'asked': 59,
#          'dispute': 29,
#          'fee': 51,
#          'speak': 23,
#          'ANOTHER': 1,
#          'decided': 3,
#          'line': 14,
#          'SAME': 1,
#          'EXACT': 2,
#          'gain': 5,
#          'obviously': 6,
#          'broken': 6,
#          'process': 51,
#          'Ashley': 1,
#          'promptly': 11,
#          'looks': 7,
#          'double': 2,
#          'taxed': 2,
#          'non': 3,
#          'memo': 2,
#          'original': 21,
#          'revised': 12,
#          'price': 7,
#          'addressing': 5,
#          'expeditious': 2,
#          'manner': 28,
#          'Still': 18,
#          'recredit': 1,
#          'toner': 21,
#          'cartridge': 2,
#          'purchased': 6,
#          'online': 36,
#          'supply': 9,
#          'store': 4,
#          'defective': 5,
#          'After': 26,
#          'calls': 30,
#          'advised': 17,
#          'solution': 7,
#          'recredited': 1,
#          'card': 11,
#          'weeks': 32,
#          'appeared': 4,
#          'difficult': 17,
#          'impressed': 9,
#          'accepted': 3,
#          'less': 15,
#          'hours': 22,
#          'Keep': 7,
#          'appears': 5,
#          'xerox': 19,
#          'Employment': 1,
#          'Training': 1,
#          'PropertySupply': 1,
#          'inform': 6,
#          'onely': 1,
#          'make': 46,
#          'invoicing': 5,
#          'early': 11,
#          'termination': 10,
#          'type': 3,
#          'refers': 2,
#          'term': 6,
#          'agreed': 4,
#          'removed': 20,
#          'hard': 14,
#          'certainly': 2,
#          'answers': 10,
#          'drive': 1,
#          'local': 20,
#          'dealer': 3,
#          'buyout': 34,
#          'considered': 2,
#          'matter': 32,
#          'Tues': 1,
#          'saying': 29,
#          'answer': 47,
#          'pastor': 1,
#          'go': 34,
#          'ask': 22,
#          'sr': 2,
#          'Ds': 1,
#          'invs': 1,
#          'cust': 1,
#          'handled': 55,
#          'efficiently': 7,
#          'Fast': 3,
#          'Appreciate': 5,
#          'supporting': 3,
#          'Chubb': 1,
#          'Insurance': 1,
#          'Thankyou': 2,
#          'take': 54,
#          'bit': 8,
#          'passing': 4,
#          'buck': 3,
#          'Greatly': 1,
#          'appreciate': 57,
#          'speedy': 2,
#          'prompted': 1,
#          'claim': 9,
#          'National': 2,
#          'Park': 2,
#          'staples': 22,
#          'claiming': 4,
#          'connected': 2,
#          'exempt': 7,
#          'supplies': 44,
#          'involved': 11,
#          'issued': 13,
#          'Adversary': 1,
#          'condescending': 2,
#          'antagonizing': 1,
#          'responses': 9,
#          'severe': 2,
#          'inability': 1,
#          'communicate': 6,
#          'effectively': 1,
#          'Guatemala': 3,
#          'Theres': 1,
#          'verbally': 1,
#          'simple': 22,
#          'explanation': 14,
#          'proper': 11,
#          'procedure': 4,
#          'put': 22,
#          'ignored': 8,
#          'Now': 17,
#          'state': 10,
#          'Illinois': 1,
#          'reference': 8,
#          'instance': 1,
#          'dont': 69,
#          'referenced': 2,
#          'stated': 20,
#          'monthly': 20,
#          'annual': 3,
#          'maintenance': 25,
#          'English': 4,
#          'Queens': 1,
#          'offense': 1,
#          'clearly': 11,
#          'Regarding': 3,
#          'Fisher': 4,
#          'name': 76,
#          'Faber': 1,
#          'Everything': 9,
#          'fine': 8,
#          'Credit': 3,
#          'processed': 12,
#          'Inquiry': 9,
#          'ETA': 2,
#          'pleased': 10,
#          'remove': 16,
#          'orders': 3,
#          'placed': 14,
#          'Sales': 10,
#          'Use': 1,
#          'sending': 21,
#          'Form': 3,
#          'submitted': 8,
#          'isnt': 3,
#          'mine': 5,
#          'Have': 10,
#          'corrections': 2,
#          'twice': 19,
#          'corrected': 21,
#          'Too': 1,
#          'solved': 13,
#          'Requested': 9,
#          'appreciated': 33,
#          'patience': 1,
#          'helpfulness': 1,
#          'Barbara': 5,
#          'Lang': 2,
#          'Services': 5,
#          'skills': 2,
#          'parties': 1,
#          'signed': 15,
#          'returned': 14,
#          'clue': 2,
#          'engaged': 5,
#          'incorrect': 26,
#          'dept': 14,
#          'forwarded': 14,
#          'Closure': 4,
#          'Notification': 4,
#          'Request': 16,
#          'mailed': 12,
#          'stating': 16,
#          'assignment': 3,
#          'By': 2,
#          'Another': 3,
#          'rebill': 6,
#          'SR': 19,
#          'date': 41,
#          'promised': 13,
#          'wait': 23,
#          'If': 26,
#          'close': 21,
#          'transparent': 1,
#          'Luisa': 10,
#          'amount': 31,
#          'spent': 11,
#          'countless': 1,
#          'duplicated': 1,
#          'unable': 23,
#          'UPS': 17,
#          'pickup': 7,
#          'items': 15,
#          'overshipped': 1,
#          'credited': 12,
#          'Joanna': 1,
#          'reaching': 3,
#          'clarification': 7,
#          'worked': 27,
#          'correction': 9,
#          'thinks': 1,
#          'differently': 1,
#          'havent': 10,
#          'shipping': 23,
#          'label': 6,
#          'return': 39,
#          'within': 21,
#          'seen': 3,
#          'Melinda': 1,
#          'went': 22,
#          'beyond': 12,
#          'lucky': 1,
#          'picked': 26,
#          'agent': 13,
#          'professionally': 10,
#          'thank': 41,
#          'problems': 15,
#          'handling': 19,
#          'cancelation': 2,
#          'expire': 3,
#          'thought': 8,
#          'continue': 8,
#          'program': 1,
#          'copier': 37,
#          'turnaround': 12,
#          'prompt': 23,
#          'assistance': 19,
#          'greatly': 8,
#          'CN': 8,
#          'Took': 4,
#          'facilities': 1,
#          'names': 2,
#          'tried': 24,
#          'emailed': 32,
#          'metered': 8,
#          'Our': 24,
#          'install': 8,
#          'seem': 18,
#          'recall': 2,
#          'please': 35,
#          'considering': 5,
#          'caused': 12,
#          'settled': 6,
#          'attachments': 1,
#          'reply': 26,
#          'Lynne': 15,
#          'fiscal': 2,
#          'year': 33,
#          'fabulous': 1,
#          'Allan': 4,
#          'hes': 1,
#          'diligent': 1,
#          'Speak': 1,
#          'PO': 19,
#          'Accounts': 2,
#          'Payable': 1,
#          'wants': 6,
#          'paid': 44,
#          'exist': 4,
#          'system': 26,
#          'First': 8,
#          'KAREN': 1,
#          'JEANNETTE': 1,
#          'ÁLVAREZ': 1,
#          'ARENS': 1,
#          'AGUILAR': 2,
#          'AARON': 1,
#          'STEPHEN': 1,
#          'looking': 19,
#          'status': 16,
#          'LYNARD': 1,
#          'MIRANDA': 1,
#          'list': 14,
#          'gentlemen': 1,
#          'copies': 35,
#          'Rhodes': 3,
#          'payment': 67,
#          'also': 45,
#          'future': 7,
#          'forward': 11,
#          'Pharmaceuticals': 2,
#          'individual': 7,
#          'deals': 2,
#          'Tough': 1,
#          'reached': 11,
#          'although': 4,
#          'Lynard': 1,
#          'hear': 18,
#          'everyone': 7,
#          'Is': 8,
#          'whisper': 1,
#          'willing': 4,
#          'invoicespharmacom': 1,
#          'continues': 2,
#          'POs': 5,
#          'causes': 3,
#          'delay': 11,
#          'seeking': 4,
#          'originally': 12,
#          'Ceasers': 1,
#          'Problem': 3,
#          'exists': 1,
#          'fully': 3,
#          'functional': 1,
#          'seemed': 7,
#          'found': 7,
#          'today': 20,
#          'downtime': 3,
#          'amounts': 6,
#          'arise': 1,
#          'prioritized': 1,
#          'City': 5,
#          'Alexandria': 1,
#          'MN': 1,
#          'Trying': 3,
#          'place': 18,
#          'showing': 13,
#          'helped': 17,
#          'replacement': 9,
#          'heads': 1,
#          'Wide': 1,
#          'Format': 2,
#          'Printer': 2,
#          'Mr': 7,
#          'Morales': 7,
#          'calling': 15,
#          'questions': 45,
#          'temporally': 1,
#          'submits': 1,
#          'cancellation': 22,
#          'pick': 26,
#          'try': 20,
#          'extra': 9,
#          'rent': 6,
#          'awaiting': 7,
#          'pickupremoval': 1,
#          'clarify': 6,
#          'recent': 5,
#          'concerning': 5,
#          'EXPIRED': 1,
#          'Davison': 1,
#          'renewing': 4,
#          'numerous': 11,
#          'period': 12,
#          'thru': 8,
#          'come': 25,
#          'sitting': 5,
#          'hallway': 3,
#          'MDOT': 1,
#          'everything': 16,
#          'BEFORE': 1,
#          'dragged': 1,
#          'feet': 2,
#          'picking': 6,
#          'To': 15,
#          'valid': 11,
#          'agency': 7,
#          'owes': 1,
#          'unacceptable': 9,
#          'ready': 3,
#          'removal': 4,
#          'As': 23,
#          'say': 24,
#          'expired': 6,
#          'JUNE': 1,
#          'preceded': 1,
#          'justify': 2,
#          'uninstalled': 1,
#          'Procurement': 4,
#          'Group': 3,
#          'understands': 2,
#          'honor': 1,
#          'expiration': 7,
#          'dates': 11,
#          'instead': 27,
#          'prefer': 4,
#          'extend': 2,
#          'regardless': 3,
#          'client': 19,
#          'contracts': 24,
#          'repeated': 1,
#          'attempts': 4,
#          'nonuse': 1,
#          'needs': 36,
#          'cancelled': 14,
#          'resubmitted': 2,
#          'count': 10,
#          'Sincerely': 3,
#          'Marci': 1,
#          'McCollum': 1,
#          'CPPB': 1,
#          'CMPA': 1,
#          'Special': 1,
#          'Projects': 1,
#          'Officer': 5,
#          'III': 2,
#          'Mississippi': 1,
#          'Dept': 1,
#          'Transportation': 1,
#          'FIX': 2,
#          'YOUR': 3,
#          'EMAIL': 1,
#          'PROGRAM': 1,
#          'misspelled': 2,
#          'acknowledge': 4,
#          'Wolford': 1,
#          'DID': 4,
#          'spell': 1,
#          'several': 42,
#          'times': 61,
#          'giving': 5,
#          'ALWAYS': 2,
#          'known': 2,
#          'spelled': 9,
#          'people': 37,
#          'think': 32,
#          'nobody': 6,
#          'Both': 4,
#          'keep': 20,
#          'months': 70,
#          'satisfied': 24,
#          'results': 12,
#          'Be': 2,
#          'kind': 6,
#          'clients': 4,
#          'offer': 4,
#          'viables': 1,
#          'alternatives': 3,
#          'Good': 15,
#          'Superintendence': 1,
#          'San': 4,
#          'Juan': 3,
#          'haber': 1,
#          'serious': 4,
#          'complaint': 5,
#          'management': 12,
#          'viable': 1,
#          'responded': 22,
#          'pass': 5,
#          'message': 14,
#          'Taheras': 1,
#          'passed': 12,
#          'noted': 2,
#          'Tahera': 1,
#          'Khuku': 1,
#          'beginning': 4,
#          'December': 15,
#          'NOPE': 1,
#          'Ask': 1,
#          'kept': 10,
#          'hold': 14,
#          'signing': 1,
#          'triciaxminccom': 1,
#          'communications': 6,
#          'Javier': 3,
#          'Carlos': 11,
#          'base': 3,
#          'August': 16,
#          'usehave': 1,
#          'excess': 3,
#          'rigging': 2,
#          'Nothing': 9,
#          'Super': 4,
#          'fast': 32,
#          'MrHector': 1,
#          'Arevalo': 1,
#          'courteous': 17,
#          'balance': 14,
#          'services': 5,
#          'small': 6,
#          ...})

# %%
vocab.items()
# Out:
# dict_items([('The', 346), ('issue', 321), ('resolved', 207), ('correctly', 28), ('It', 149), ('took', 100), ('research', 14), ('end', 38), ('discover', 1), ('still', 194), ('billed', 51), ('incorrectly', 11), ('Just', 9), ('one', 155), ('order', 97), ('changed', 39), ('billing', 110), ('without', 41), ('authorization', 2), ('main', 4), ('entity', 3), ('nothing', 28), ('customer', 266), ('service', 233), ('person', 86), ('way', 52), ('managed', 3), ('Susan', 17), ('provides', 7), ('efficient', 22), ('timely', 40), ('reps', 22), ('fault', 18), ('hands', 3), ('fix', 19), ('issues', 52), ('Xerox', 425), ('yet', 44), ('completed', 42), ('fixing', 2), ('invoice', 208), ('started', 8), ('June', 26), ('request', 226), ('update', 32), ('bill', 61), ('address', 128), ('see', 51), ('prior', 14), ('comment', 6), ('Can', 10), ('split', 2), ('difference', 4), ('since', 76), ('readings', 5), ('taken', 31), ('guys', 8), ('notes', 6), ('really', 34), ('use', 26), ('machine', 147), ('Demo', 1), ('clicks', 6), ('charging', 6), ('states', 9), ('reading', 4), ('moved', 6), ('facility', 5), ('continued', 4), ('fact', 17), ('testing', 2), ('etc', 10), ('get', 233), ('us', 96), ('set', 23), ('We', 166), ('could', 79), ('print', 16), ('projects', 1), ('due', 46), ('printing', 4), ('used', 19), ('another', 68), ('AG', 1), ('finally', 27), ('Jon', 1), ('Tinnel', 1), ('Thursday', 1), ('July', 26), ('pm', 4), ('reinstall', 1), ('programs', 1), ('server', 1), ('correct', 69), ('colorusage', 1), ('press', 2), ('afternoon', 5), ('That', 35), ('done', 62), ('starting', 3), ('number', 118), ('month', 59), ('sign', 5), ('sheet', 3), ('collaborates', 1), ('infoPlease', 1), ('adjust', 2), ('accordingly', 1), ('log', 12), ('For', 12), ('large', 5), ('color', 9), ('know', 102), ('include', 1), ('previous', 20), ('separated', 1), ('written', 10), ('charge', 53), ('never', 98), ('received', 192), ('quote', 23), ('hate', 3), ('dealing', 15), ('emails', 49), ('phone', 93), ('call', 182), ('menu', 2), ('hell', 2), ('giant', 2), ('turn', 15), ('want', 34), ('company', 68), ('This', 159), ('whole', 17), ('thing', 10), ('explosion', 1), ('problem', 84), ('needed', 77), ('developer', 1), ('sent', 171), ('po', 1), ('provided', 78), ('arrived', 5), ('given', 32), ('approval', 1), ('send', 62), ('back', 113), ('No', 71), ('ever', 23), ('able', 62), ('explain', 10), ('many', 31), ('ordered', 12), ('give', 23), ('refund', 14), ('developers', 1), ('Overall', 2), ('positive', 2), ('experience', 22), ('trying', 49), ('resolve', 81), ('February', 5), ('hence', 2), ('final', 17), ('question', 34), ('spoken', 4), ('multiple', 26), ('individuals', 2), ('Ms', 11), ('Ronal', 2), ('Vinicio', 1), ('Nitch', 1), ('Teque', 1), ('ownership', 24), ('investigated', 3), ('situation', 33), ('accurately', 6), ('pleasure', 9), ('deal', 14), ('HELPFUL', 1), ('AND', 12), ('PLEASANT', 1), ('TO', 27), ('SPEAK', 1), ('WITH', 12), ('THANK', 9), ('YOU', 12), ('like', 76), ('last', 36), ('week', 30), ('department', 48), ('messed', 3), ('Your', 28), ('first', 54), ('representative', 83), ('spoke', 42), ('subject', 1), ('polite', 17), ('helpful', 62), ('amazing', 4), ('practices', 1), ('concerns', 6), ('credit', 108), ('cause', 3), ('concern', 12), ('active', 2), ('level', 9), ('upsetting', 3), ('However', 21), ('Sarah', 5), ('Monterroso', 1), ('de', 3), ('Melgar', 1), ('astonishingly', 1), ('job', 85), ('cleaning', 2), ('long', 61), ('standing', 4), ('mess', 3), ('Her', 6), ('follow', 28), ('impressive', 1), ('well', 35), ('Dealt', 1), ('unprofessional', 4), ('Need', 7), ('talk', 21), ('someone', 84), ('supervisory', 1), ('position', 4), ('Please', 72), ('provide', 41), ('contact', 87), ('terrible', 7), ('already', 29), ('wasted', 4), ('much', 71), ('time', 252), ('providing', 13), ('details', 17), ('review', 8), ('requested', 110), ('serial', 30), ('realigned', 1), ('new', 77), ('email', 200), ('Pushed', 1), ('else', 24), ('called', 95), ('help', 74), ('whats', 4), ('unhelpful', 2), ('dealt', 10), ('busines ...

# %%
min_occurance = 2
tokens = [k for k,c in vocab.items() if c >= min_occurance]
print(len(tokens))
# Out:
# 2402

# %%
def save_list(lines, filename):
    # convert lines to a single blob of text
    data = '\n'.join(lines)
    # open file
    file = open(filename, 'w')
    # write text
    file.write(data)
    # close file
    file.close()
save_list(tokens, 'vocab_CCO.txt')

# %%
def load_doc(filename):
    # open the file as read only
    file = open(filename, 'r')
    # read all text
    text = file.read()
    # close the file
    file.close()
    return text

# %%
# load the vocabulary
vocab_filename = 'vocab_CCO.txt'
vocab = load_doc(vocab_filename)
vocab = vocab.split()
vocab = set(vocab)
print(len(vocab))
# Out:
# 2402

# %%
def clean_doc_emb(doc, vocab):
    # split into tokens by white space
    tokens = doc.split()
    # remove punctuation from each token
    table = str.maketrans('', '', string.punctuation)
    tokens = [w.translate(table) for w in tokens]
    # filter out tokens not in vocab
    tokens = [w for w in tokens if w in vocab]
    tokens = ' '.join(tokens)
    return tokens

# %%
records = list()
for i in range(len(trainx_outer)):
    tokens = clean_doc_emb(trainx_outer["Full_Comments"].iloc[i], vocab)
    records.append(tokens)

# %%
records
# Out:
# ['The issue resolved correctly It took research end still billed incorrectly',
#  'Just one order changed billing billing changed without authorization main entity nothing customer service person way billing managed',
#  'Susan provides efficient timely service',
#  'It reps fault nothing It hands fix issues Xerox yet completed fixing invoice issues started June',
#  'The request update bill address completed correctly',
#  'see prior comment Can split difference since readings taken guys notes really use machine It Xerox clicks charging It states Xerox reading machine moved facility Xerox continued fact testing etc get us set We could use machine print due printing correctly issues We used another print We finally July pm get correct etc press We started printing afternoon That reading clicks done pm starting number end month July sign sheet adjust log sheet states starting number end month For large color know number previous machine number written Can split difference charge',
#  'never received quote',
#  'hate Xerox dealing emails phone call menu hell giant turn want use another company This whole thing giant problem needed sent provided another way arrived given send back sent back needed one No one ever able explain billed many ordered give refund',
#  'Overall positive experience',
#  'trying resolve issue since February hence final question sent emails spoken multiple individuals Ms Ronal person took ownership investigated situation resolved accurately It pleasure deal',
#  'AND TO WITH THANK YOU',
#  'like know last bill week billing billing department messed Your billing department messed',
#  'The first representative spoke polite helpful The last amazing That situation billing Xerox concerns customer credit cause concern That situation still active another level upsetting However last representative Sarah de efficient job cleaning long standing mess Her follow well',
#  'unprofessional person Need talk someone position Please provide contact',
#  'Your company terrible already wasted much time providing details',
#  'The update completed Please review requested The serial number new customer number sent The update completed Please review email',
#  'someone else called help whats ever This unhelpful company dealt business',
#  'see previous comments Xerox endless paperwork years change ownership WorkCentre And never seems get accomplished even though told time accomplished The invoice repairs keeps getting sent previous owner machine long business late charges invoice never sent When call phone number provided Xerox representatives bill phone number doesnt actually work This response got changing ownership makes absolutely sense cant get anyone tell supposed mean per email conversation address cannot changed account two different legal however ownership change completed past effective That',
#  'wish equipment wasnt good Im really tired dealing horrible customer service company feel like check every bill dealings Xerox made wonder company run bunch My inquiry regarding getting sales tax invoices service agreements click charges came back said charge sales tax mandatory service agreements Ill check perhaps somebody Xerox explain leases NOT charged sales tax service agreements',
#  '',
#  'still waiting report need report important receive',
#  'would preferred response day ok Without instructions sent would never located add account information easy find Thank',
#  'Initially believe issue addressed correctly Your representative contacted made sure issue resolved She even sent screen changes assure correct Very happy effort get resolved',
#  'No one even contacted addressed issue sent email case closed',
#  'Great Job',
#  'No',
#  'It took days longer problem resolved',
#  'The person spoke professional The problem Xerox policies Ive always able order part last two years sudden cant get without going techs Once person spoke helpful limited She nice professional',
#  'Please previous comment We sent letter asking terms buy lease quote buy equipment We sent second request yet get response This service weve Xerox reason want machine gone',
#  'Great Support Service provided',
#  'Thanks',
#  'enough said You folks never service contract question lady ext assured taken care would get bills inquiries Then get phone call January asking meter reads Get act together stop hoping wont pay attention paperwork send Im guessing hope something owe money',
#  'Terri excellent resolving inquiries',
#  'thanks getting resolved quickly',
#  'My request pushed sales rep responsibility customer number agreement support',
#  'Terri extremely helpful understanding Xerox issues',
#  'Resolved quickly',
#  'logged inquiry The closure notification included one invoice resolved There two invoices needing credits In addition credit invoices applied open invoices',
#  'great service quick resolution',
#  'copy Purchase Order requested All communication done via',
#  'Would like faster turn around time submitting requests Jose David still working request sure great job',
#  'Billing nearly impossible understand got run around billing explained told one thing many customer got one else story changed changed end call TWICE Second person spoke pretty much told first person spoke idea talking way confidence team basically told job wrong paying invoices based Invoice Customer serial number machine Which far know NO AP Specialist would pay invoice based serial numbers Billing makes absolutely sense get feeling even reps spoke understand billing got ran around much asked dispute late fee told would speak yet department decided would dispute line This first time EXACT problem Xerox billing run around Xerox reps trying gain understanding obviously broken process billing',
#  'No',
#  'promptly provided copy credit invoice',
#  'It looks like double charges account taxed non taxed invoices used different numbers need tax credit memo original invoice new invoice revised price',
#  'Thank much addressing request expeditious manner',
#  'Still waiting The toner cartridge purchased online supply store defective After much time multiple calls finally advised solution would charge would credit card After two weeks credit yet appeared still waiting',
#  'The issue resolved Xerox customer service difficult work',
#  'Im impressed request accepted completed less hours Keep good work',
#  'It appears issues sales rep xerox',
#  'We trying inform equipment two want make sure paying one equipment',
#  'Xerox invoicing us early termination fee purchased new machine service Xerox still No one provide type contract refers term agreed charge wont removed account',
#  'The representatives nice hard time getting information needed It certainly timely manner No email answers No phone calls We local dealer given buyout quote see considered closed received response We receive resolution information sent email matter saying received answer inquiry information The go local Xerox dealer ask',
#  'sr closed removed',
#  'My request handled quickly efficiently',
#  'Fast efficient',
#  'Appreciate help supporting Thankyou',
#  'called correct told needed call different called told call original Your reps take bit time understand concern passing buck',
#  'appreciate speedy response resolution received inquiry',
#  'The inquiry customer claim National Park Service order staples The inquiry closed claiming serial number connected account exempt billing supplies issue involved The customer claiming another Xerox customer get invoice issued credit',
#  'condescending responses There seems severe communicate representatives Guatemala way talk anyone cant give simple explanation requests proper procedure put request new customer numbers request ignored Now told',
#  'This contract state The contract provided reference issue In dont believe contract referenced since rep stated billed monthly charge annual maintenance fee',
#  'English speak English take asked speak clearly',
#  'Regarding email communication rep addressed Sarah Fisher name Sarah Everything else fine',
#  'Credit processed week Inquiry ETA pleased Thank',
#  'Please remove sales use tax account orders placed Sales tax removed account even sending Form',
#  'never submitted account isnt mine',
#  'Have requested corrections twice still corrected long get problem solved Requested correct invoices corrected',
#  'appreciated received',
#  'Barbara Lang professional polite Great Customer Services skills',
#  'We sent paperwork back per request case closed phone call good customer service All signed returned clue Xerox',
#  'engaged incorrect dept forwarded proper dept',
#  'Closure Notification Service Request mailed customer stating assignment completed By customer understand able provide invoices new customer name Another inquiry open credit rebill new customer name new SR done date promised customer wait If going close SR tell customer one part process done provide new SR part This process customer',
#  'Luisa great helpful The amount time spent fix issue hours still resolved Xerox order unable stop order You sent UPS pickup items credited us back',
#  'appreciate reaching clarification worked inquiry Thanks fine job every time',
#  'believe correction still made Xerox',
#  'still havent received shipping label return staples told would receive within days still havent seen email department',
#  'extremely helpful went beyond help us We picked phone',
#  'The representative job issue resolved The customer service agent nice handled request professionally She stated request processed resolved However issue resolved',
#  'Please thank Jose quick response',
#  'problems handling credit account concerns regarding cancelation contract We received letter stating service contract expire thought would receive something continue maintenance Xerox copier',
#  'quick turnaround',
#  'Your prompt attention assistance always greatly appreciated',
#  'My CN returned within hours sending request Thanks much',
#  'Took call never received call back promised names one invoice',
#  'My issue resolved tried call representative call would go emailed representative asking issue corrected requested change shipping address metered supplies Our install address changed shipping',
#  'Thank',
#  'seem recall response',
#  'please quickly problem resolved considering caused problem',
#  'No information provided',
#  'No issue settled receive reply',
#  'Lynne great got invoices needed fiscal year end June She',
#  'Great work Allan always requests appreciate support',
#  'reference correct PO get invoices Accounts Xerox wants paid AP pay invoices dont exist system First far know involved phone call AGUILAR AGUILAR called looking status February invoices called back spoke provided list invoices question email returned request copies invoices Rhodes system payment also future forward Rhodes Pharmaceuticals requests payment Rhodes Pharmaceuticals last issue every time call placed Xerox different individual deals call follow call original individual called cant reached although nice AND hard hear everyone Xerox Is everyone asked phone No happy Xerox willing forward invoices payment happy Xerox continues reference incorrect POs invoices causes delay payment',
#  'billing address update completed correctly',
#  'Still seeking information originally requested received closure notification absolutely information resolution question',
#  'appreciate expeditious response',
#  'Problem still response issue',
#  'We without fully copier month first weeks one Xerox seemed even care working copier found today downtime credit amounts',
#  'customer issue asked able It made customer difference case greatly appreciated',
#  'please get sales use tax issue exempt City Trying place order still sales use tax showing order place order issue resolved',
#  'This issue resolved The person helped get credit started however received replacement part We need contact Xerox help us defective print Format Printer',
#  'impressed Mr Morales took time help first time calling sure needing questions ask Im new put position',
#  'When customer cancellation contract take month pick equipment try charge extra month rent machine used awaiting Just clarify recent response inquiry concerning July invoice copier contract Xerox June contacted representative David June inform would renewing contract requested please machine picked June This June July stated email Your company pick machine July sent numerous emails reached representative time period June thru July trying get someone Xerox come remove machine This copier sitting hallway nearly month waiting someone Xerox come pick This fault everything supposed submitting cancellation request end contract June Xerox one feet picking machine To tell invoice month July valid agency month company decided pick equipment end contract June unacceptable unprofessional The cancellation request made June machine ready removal time As much want say owe month July impossible since contract expired cancellation request June Just Xerox took time picking machine justify trying tell customer owe month service valid since contract expired June machine awaiting pick make sure Procurement Group understands Xerox contract expiration dates instead prefer extend contract machine picked regardless client submitting cancellation requests end contracts attempts someone Xerox come pick equipment We going pay month Xerox took time picking copier effort charging us another month rent Invoice amount billing period July thru July needs cancelled new corrected invoice resubmitted amount final copy count end June Sincerely Officer III',
#  'FIX YOUR My name misspelled since Xerox system set acknowledge emails sent NOT received never got answer Susan took care today DID name several times giving information since ALWAYS known name NOT spelled people think',
#  'You never solved problem My request closed nobody ever contacted resolve matter',
#  'Thankyou',
#  'Both rep keep sending information get resolved took months Im satisfied results',
#  'Be kind clients offer alternatives In way think clients Good afternoon We San Juan serious complaint management case As client needed help Xerox offer alternatives us concern would able business Xerox',
#  'When service rep responded give name contact would pass message replacement person took position tired getting passed one answer Xerox customer service noted passed issue person took That beginning December yet hear response anyone',
#  'someone call kept getting email hold lease sending PO hear someone',
#  'Thank',
#  'Please email send communications Javier Carlos Thank The main issue needed addressed incorrect monthly base charge August getting final revised bill removed machine August Xerox Carlos addressed excess rigging charges meter reads recent dispute inquiry still waiting get resolved',
#  'Nothing done The representative understand complaint',
#  'Super fast Thank',
#  'Thanks',
#  'courteous professional handling inquiry regarding credit balance',
#  'thought Susan helpful appreciated services We small customer means dont always resources focus service contracts like',
#  'new CN Thanks Manuel responsive able give good customer County quickly There several customers tool able find one purchase order really appreciated fact got one quickly Thanks',
#  'first called tell behind paying invoice person talked many many company told insurance least times copies sent',
#  'It wasnt resolved Im still waiting receive invoices asked invoices mailed address mailed July It August yet receive doubt really sent Now call Xerox request copies emailed Why cant emailed every month without making special request really dont understand This Xerox needs move age',
#  'didnt get clear answer issue apply work home couldnt apply call phone couldnt get anybody help getting website trying apply job couldnt apply online would take password',
#  'still received signed work agreement',
#  'THE ISSUE HAS NOT BEEN RESOLVED requested shipping address updated still happened When log metered supplies account shipping address shows address placed call get changed',
#  'The person got info situation wrong reach clarification closed inquiry Totally waste time',
#  'would appreciate future invoices sent Business Administration Ave Suite San Juan Puerto Rico Attn Jose Rodriguez',
#  'We received invoice Xerox month March received letter January telling us contract would renewed disputed charge Xerox website received email saying cancel agreement therefore automatically renewed months',
#  'The techs great This issue caused management Xerox cost sourcing cheaper parts must get reliability back otherwise need look alternatives two Both poor uptime last months The technician coming onsite great believe parts like getting Xerox defective downtime us feel bad techs Xerox appears sourcing cheaper parts breaking high rate maybe resulting log service calls machine nearly months believe Xerox know problem wont recall parts cost money Xerox problems result customer uptime currently impact directly leave Xerox another better reliability fixed soon',
#  'none time',
#  'No',
#  'reps good sent cancellation twice already still get billed unit pay part',
#  'Susan great work requires information provides detail needed always available help clarify questions might',
#  'asked buyout quote contract got run around person responding Apparently system sent blank email format didnt record notes When forwarded email brought attention nothing told sent information rep responded stated email rude response',
#  'Good afternoon The main issue resolved incorrect increase Although invoices keep coming PO instead This one thing fix left Thanks',
#  'The process needs changed The report states invoice serial number Customer Number Obviously would thats whats system It still doesnt belong It would make sense sales representative consulted He confirmed account belong Upon reviewing account able determine invoice correctly generated customer number mentioned The equipment located AVE FL RM The account belong ever contacted representative get resolved',
#  'JOB real quick This urgent matter sent email priority request resolved Thanks much',
#  'local sales contact great job supporting us',
#  'Cesar prompt responses patient us waiting signatures The process took awhile waiting signatures pleased handled us',
#  'needed know sales tax rate charged know part contract maintenance need supplies tax charged invoices question request James Daniel responded needed call someone else find information moment call requested call Monday January',
#  'Appreciate quick response resolution',
#  'Lisa excellent job resolving issue',
#  'Kathy awesome',
#  'Thank everything David',
#  'Luisa professional courteous',
#  'Please cancel metered account effective immediately longer afford getting new machine Thanks Dennis Please cancel metered account effective immediately longer afford getting new machine Thanks Dennis',
#  'think credit file also non clear invoices credit late charges bill Please clear invoices',
#  'pleased received requested copies outstanding invoices within hour call',
#  'Excellent Thank',
#  'She called regarding open invoices account requested copies invoices sent tell needed research called try explain one invoices billing months appeared paid months No one ever waiting return call',
#  'needed address changed occurred timely efficient manner However order name account changed redirected customer service cut several times There seems closed loop sends customers circles customer service line',
#  'dont know two DUNS numbers assigned customer Im disappointed received response Two DUNS assigned customer one needed It delayed order severely Ive tried email Customer Care DUNS Resolution Team Ive copied Ana Barrios get resolved yet hear anything My Order continues delayed',
#  'Ericka awesome She handled everything perfectly',
#  'Very needed problem fixed Tuesday called problem didnt get taken care',
#  'Great customer service',
#  'get right',
#  'He courteous helpful',
#  'Receiving Invoices timely matter would great normally receive credit card charged thats stopped automatic payments',
#  'All received email stating sr closed nothing tell worked',
#  'Still resolved changing name group taking physical ownership machine leave name',
#  'spoken via phone several different representatives asking issue resolved avail It looks like name changed one copiers We copier needs name corrected also Also go Supplies page Is possible copiers input supplies hand asked done happened yet',
#  'Really fast',
#  'handle problem quickly great job wish problems company invoices would handle quickly',
#  'received email stating address change completed equipment serial When received invoice dated install address updated The problem wrong address taxes accurately',
#  'The rep spoke extremely helpful fixed every part problems dealing',
#  'dont understand takes longer pull invoices Managed Services Accounts If requesting regular basis access need pull quickly It takes much time customers usually upset us pull information Now longer wait get right information asked invoices specific serial number March April May received summary invoices months serial numbers associate So cant use send takes long get first place Now waste time trying get need Totally frustrating',
#  'Jossy extremely thorough accurate resolutions simply best Glad team Jossy',
#  'It supply issue church days week UPS returning supplies Hopefully supply shipping address changed service billing',
#  'Could please respond status inquiry first heard nothing else printer picked Thanks Carol Road fax',
#  'prefer use online ordering phone communication timeconsuming frustrating system doesnt allow information Shipping billing addresses needed changed sent notice showing changes log old address still spelled',
#  'thank much creating customer number customer order supplies State',
#  'little money obviously important Xerox customer relations The information provided shows fact machines installed date state You therefore error charging lease time period There obviously communication Image Xerox But fault You year relationship good customer couple dollars sense You provided resolution zero',
#  'Please come pick machine You get handing back department ignoring Please come pick machine ASAP',
#  'The issue pass many owned managed',
#  'hung It took three calls pay bill The first one lady said used live She hung The call disconnect finally call got someone service great used work Xerox years would recommend anyone getting Xerox machine',
#  'The address different information provided',
#  'requested copy contract agreement get The request closed task completed resubmit',
#  'didnt reply',
#  'It STILL taken care still charges account attached PO machine department months call email request charges moved appropriate customer even provided information person created PO person works University another location another department way tried get Xerox paid outstanding invoices longer worth time want follow several requests help',
#  'pleasure work',
#  'Allan great work thanks support',
#  'After months dealing wish could resolved thought issue closed yet getting phone calls pertaining Each time assured taking care',
#  'lease machine replace newer model It took little Xerox pick old machine new one installed',
#  'The original order started around It either mailed Xerox wrong address always receive toner address mail carrier made told would wait situation investigated could reorder It could take days In meantime staples machine Why could place order offered pay investigated lost order Terrible idea sense made us want recommend company anyone else Finally order mailed',
#  'Thank You address change request The escalation promptly resolved',
#  'Issue hasnt resolved yet',
#  '',
#  'There resolution situation',
#  'No',
#  'Not customer friendly systems Asked addresses invoices told able system',
#  'We want pay remaining rent remaining lease term return copier There mention buyout fee contract wish purchase machine As told persons spoke pay lump sum rent return copier Instead offer apparently pay buyout fee purchase copier If prefer simply store machine pay rent monthly pay lump sum return copier',
#  'This FIRST time spoke someone first language English truly repeat information number times someone around My original request never fulfilled thus today This also telephone system didnt feedback US speak customer service rep within US would delays issues communication',
#  'The XNAC team wonderful always prompt respond enjoy working',
#  'Thanks Gabriela',
#  'submit requests get invoices requested Marvin one took ownership made sure received invoices requested He courteous professional',
#  'None service great',
#  'billing even though machine already Xerox Not sure rebilling took long Would like received credit invoice dispute accounting period',
#  'My issue equipment shown log trying add results serial numbers confirmed The response send list serial numbers supplied originally address question',
#  'wait weeks redirected perhaps way screen requests delays customer reps fault rather process tks Mark customer moved another state point couldnt account deemed lost The customer operation state service trying year status changed engaged team waited weeks told managed services account try fault processes feel free contact want details Mark Customer Relations Representative Customer Xerox Corporation Street Suite ext',
#  'nothing done ignored request',
#  'The rep promptly handled updating address Great service',
#  'You done nothing say meter readings correct meter readings higher month ago In readings STILL',
#  'Extremely fast turn around Thank',
#  'needed CN today urgent order helpful responsive',
#  'Very please outcome',
#  'She prompt professional',
#  'additional comments',
#  'Lynne great thank',
#  'professional',
#  'No',
#  'requesting address change time still isnt changed Xeroxcom',
#  'No requested refund overnight shipping charges boxes toner since wrong toner shipped us followed instructions service rep toner boxes returned via Xerox call tag provided billing dept reference numbers given resolve matter The resolution request tell none ever happened small matter become one pursue file complaint',
#  'satisfied answer received Smith Printing Office Supply Inc Direct Pay paying charged Thank You Smith Smith Printing Office Supply Inc',
#  'still waiting information information provided',
#  'think USA Cust care little ability caused wasted hours time hope gets better Xerox Sales CARE Thank contacting us regarding cancellation request Serial Number Inland Color Please note machines part active lease contracts reached expiration dates We unable cancel maintenance part agreement THIS IS AND NOT OF PLEASE CANCEL THIS WITH ETCs',
#  'Since weve owned machine every time Ive contacted number customer support told NOT would billed maintenance No one ever mentioned one year maintenance service mentioned Mark When told told contact local sales rep However since machine communication sales rep nonexistent tried times Carlos local sales rep never received response When would call number couldnt answer questions would try direct local sales rep It took year put contact someone told sales reps longer Xerox Every time told Mark response back get local sales rep nonexistent Why customer jump hoops figure whats going',
#  'Be specific asked certain machine located took several days someone get back tell located address bill sent That much need know department',
#  'Yes All well',
#  'Was told contract ends also told lease seem right option cancel contract least buyout',
#  'The communication Xerox extremely disappointing requested summary payments made invoices last months never received anything set payment via website never notified payments going got new invoices explanation After phone calls several hours still receive information requested It frustrating working Xerox may renew lease',
#  'got lot information already billed need know billed items sheet',
#  'No Im taken back company still around horrible way company dealing situation think lady dealt nice professional told thank day owe money copiers sitting hallway almost months That wouldnt pick hassle come pick copiers If questions please call Im bothered company far able situation',
#  'The customer service representative spoke spent hour half phone automated menu reach human That incredibly frustrating needed invoices different account numbers automated wasnt working needed talk person wish zero speak representative option',
#  'The issue took way long resolve My one phone days took one phone call weeks',
#  'We charged late fee check delayed mail The representative said could reverse late fee The invoice paid late invoice billed incorrectly twice waited weeks finally get correct invoice Just yesterday received click charge invoice September That invoice issued late took days get us It ok Xerox feet billing correcting mistakes customers pay late Every request make takes minimum weeks get resolved longer Your customer service horrible policies This something discussed every time talk Xerox machine',
#  'For An issue got solved quickly got call someone info email done',
#  'Id like know network controller issue resolved The technician called asked questions problem explained problem She asked still said moment She said since looked like resolved didnt need come call happened would come waited complete survey see machine problems Im trying print every time send job go machine says The job doesnt print This happened times row morning Why network controller Is something fixed set right doesnt happen',
#  'nice Xerox used Xerox phone system mess Was told could call employee reviewed bill telephone part business model billed machine sitting unused weeks Xerox package machine shipment Moving came pick Not fault Xerox Machine could shipped Feb get picked weeks first removed',
#  'turn case local Xerox rep work another Corp Xerox rep resolve receive written email say invoice pay think case still unresolved worked local Xerox rep Corp Xerox rep The price per copy black color reversed',
#  'Silvia provided good service completed request short time performance outstanding',
#  'Thank quick resolution excellent communication throughout This sensitive customer issue quickly resolved',
#  'gave representative Customer number name read back address correctly received NOT account The email received invoices requested company Santa CA Rocks',
#  'The communication offered poorly worded unsure whether XEROX picking package Glad worked',
#  'She finally resolved issue',
#  'Jane pleasure work Amazing requests timely Thank',
#  'none',
#  '',
#  'transferred multiple times customer service representatives',
#  'issues answered resolved issues invoices paid recurring payment instructions',
#  'This fast thanks',
#  'The rep respond explained incorrect spending minutes time highly paid resources Xerox work around issue',
#  'No The helpdesk fantastic job needed call continue process didnt time No fault helpdesk',
#  'The buyout quote confusing needed contact someone Xerox clarify amount paid It would better provide list dates amounts ie paid etc',
#  'Great service',
#  'This horrible year',
#  'completed timely thank',
#  'still waiting correct information',
#  'The handling issue done timely matter',
#  'How guys close account without emailing us final answer whats going case',
#  'would happy copy emails sent try get issue resolved The rep didnt even try resolve issue submitting cancellation paperwork The rep didnt ask send wants start whole new request Xerox needs serious help customer service department This going since October one seems working',
#  'We asking address change since Thanks addressing FOUR YEARS',
#  'really appreciate extra email letting know working Without might call Thank',
#  'Please let technician know use black testing machine instead color since Xerox prints price color black Thanks',
#  'It took long simple request',
#  'David great job',
#  'Sergio friendly However spelled first name wrong didnt tell ended update address wanted update sent Closure Notification Service Request thought update made would confusing So think maybe irritated didnt want anything asked remove line address never heard back done We Center everyone refers Center huge Student Center building lots offices stores connected everyone calls Student Center So updating address wanted remove CENTER RM OF CENTER next line STUDENT SUCCESS enough find us without CENTER RM confusing situation My building called Student Center Sergio said line long So asked delete CENTER RM STUDENT SUCCESS He never let know resolved',
#  'The Sales rep left without solving issue without providing new sale rep contact Im still sure sales rep Ive trying return copier SN PO since June cant get anyone help service one Xerox picked machine still invoice end June need machine picked need credit invoices inv Thanks',
#  'The first adjustment done incorrectly redone',
#  'My request asking removal extended invoice April retention unit purchase agreement signed customer Feb closing notification talking removal unit still lease agreement also CBR processed retention order status received answer yet',
#  'Great job',
#  'We production facility customers If get bad product need replaced nearly month wait acceptable performance',
#  'resolved Was waiting error fixed next billing received billing issue unresolved',
#  'See comments anything add incident This issue resolved placed emergency order previous order received half The toners color machine missing So called agreed Xerox send expedited order one set toners premium freight charge since Xerox would overnight package us NEVER got order called week later order explained never got order We toner stores point advised take issue FedEx Xerox send another order free charge place order compensate stores point They told us received order contact billing department reverse premium freight charge since never got order FedEx investigation driver apparently order said location left door since said place closed show delivery made pm Tuesday Keep mind Office NEVER closed pm Tuesday The FedEx case manager agreed order They provided case number Xerox could file claim missing order FedEx compensate loss In mean time received replacement order replacement order lost The toner MACHINE Since placed order every toner eventually compensate stores hopefully run toner That order received We contacted billing department advised upon delivery toner dispute premium freight charge since never got order Now Xerox telling us reverse charge got report FedEx saying order delivered somewhere despite explaining details multiple representatives including billing department advised Xerox This experience absolute disaster start process We may refer incident corporate office point',
#  'We appreciate complete response issue',
#  'requested invoice emailed allow payment timely manner It mailed The invoice received mail first time requested invoice emailed get paid time The invoice sent mail',
#  'Amanda great Thank much',
#  'new machine already replaced one year due problems required numerous service calls since replaced months ago On top errors made billing cannot seem get anyone properly help Customer service tells issue resolved theres credit account get past due invoices billing department And one responds correspondence My experience Xerox terrible There ongoing issue regarding inaccurate charge Xerox billing errors inadequate follow emailed clarification questions several times gotten response',
#  'Thank taking care',
#  'The issue resolved case closed No one ever got back called sent email letting know need call back discuss never got call back',
#  'Very appreciative action steps Field would need update Customer Tax exemption',
#  'request met thanks',
#  'The representative everything complete request understand party involved resolution process bit Everything Xerox part spot',
#  'documents provided incorrect accurate portion entire contract intentional disconnect call Ms immediate supervisor Mr supposed follow would like customer care rep US contact',
#  '',
#  'Please resolve issue remove late fees called multiple times emailed issue still resolved',
#  'Thanks',
#  'received invoices day',
#  'In years printing never service better',
#  'Thanks',
#  'Fast response like gets orders processed much faster',
#  'Erwin extremely helpful Thank Erwin',
#  'Being fourth representative spoke issue still resolve keep getting run around would say representative helpful Being fourth representative spoke issue still resolve keep getting run around would say representative helpful',
#  'Not sure You sending survey getting work done All asking received request fix issue received note stating got information getting email issue resolved As Xerox representative getting customer sign order year two year process At times feel Xerox takes work sales professional serious billing requirements needs client addressed fully With better',
#  'Im still sure took year Xerox reach us account past due printer location year We still receiving invoices even though contract We dont even printer anymore We want sure billed anymore sent invoices Weve paid bill date',
#  'Who needs contacted regarding credit We needed credit amount charged charged',
#  'On sent documentation Josseline Moreno company name changed ownership changed ALL need mailing address changed moved new office location This email appears asking exact information AGAIN Im gone beyond get fixed get point forwarding order expire longer get maybe pay attention telling Thanks',
#  'requesting immediate Xerox address billing resolution contracts As response Xerox address question generally mark issue addressing question As Government Officer hope never need make another Xerox',
#  'The Xerox Representative fine job clearly none fault My Agreement Xerox clearly states either party provides notice termination least days expiration initial renew automatically monthtomonth basis terms provided written notification Agreement please make sure noted account Xerox notified regardless soon system actually log',
#  'issue provided resale cert completed paperwork lease delivery equipment receive response Press contact leaving voicemail asking resolve called number invoice given issue number waited surprised took long simply contact let know copy resale cert way way much',
#  'The printer work consistently last one We charged training fee Communication poor Danielle',
#  'Thank',
#  'No',
#  'impressed receive document quickly Dan Gilland also followed request made sure received He professional helpful',
#  'invoice charged xerox paying whole issues please check sales person',
#  'Our issue resolved still unable gain invoices account Xerox website Xerox responsive',
#  'You wrong person',
#  'put anyone could error please correct Thank waited says FINANCIAL Maybe error communicating please invoices previously read FCU read new FINANCIAL FCU Thank',
#  'Thank Team',
#  'sure process Xerox lady worked take level The customer wants way purchase billable supplies online using internal purchase dont wish use credit cards online Can help',
#  'requested answer question Can pay lease machine picked received purchase quote answer question',
#  'know request satisfied The machine replaced two months working expectations expect charged lease fee heard billing issue resolved',
#  'issue solved del solved Juan',
#  'The ticket still open There remains discrepancy reply Xerox',
#  'The team outstanding job Thanks Carlos',
#  'Took year resolve end satisfied outcome',
#  'Excellent Service',
#  'Lucia handled matter professionally feel showed concern handling We satisfied results help',
#  'Please find take tax present bill They gave us credit previous tax still charging us tax bill',
#  'seen copy person issues every copy job make',
#  'He good job kept communication',
#  'much work get someone service xerox machine purchased asked fill form know need send signed letter All want someone may sent documents computer lot work someone service machine',
#  'overall process order staples probably worst dealt representative knowing parts sending wrong one setting return rep dealt couldnt understand needed return product get missing product like started finally hang call back When called Xerox set return told someone would coming pick wrong product start return wasnt told take shipping department UPS come also told window pick would within next weeks specific time expect picked',
#  'Again seems credits provided inadequate provided credits In technician worked machine two days used color credit inadequate',
#  'Josseline awesome She took time explain entire process even explaining longer needed new customer number created minimal change required It clear Josseline takes work wish others communicated promptly clearly Well done',
#  'Maria still working getting resolved realize time sensitive end',
#  'We charged late fee due accounting dept crediting invoices credits open invoices account credit depts sent late fees debits even though credits invoice charges Very bad accounting dept told send email late fees customer care basically said handle closed case This company worst handling issues They fine phone soon one hand says something hand cant follow never recommend Xerox copy service disappointing',
#  'Great job Keep good work',
#  'quote attached sent sale rep need contact',
#  'Lynne Jones said could take weeks resolve took',
#  'Please complete form return us required The questions really apply This office complete form sent Our form supplies us information need complete vendor file',
#  'response time short',
#  'Everything company last year two nothing problem Most people answer phone ok send staples back label provided like everything done company last year two problem Was told would receive email info got email return label printed used UPS picked package getting credit Another company tried fighting We cant get auto replenishment supplies call order would think asking run around get charged got new machines fighting months Have machine hate jams time wont fix get going need service It times day every time turn around working something company coming They stay get contract none We know return resold sure dont know else long return label sent wits end They ones spoke lady ones read number box enclosed came staples So pleased service NO',
#  'Good job',
#  'It resolve satisfaction system didnt allow representative send buyout representative didnt want',
#  'You copy customer response The form letter states could early termination charges ETCs would apply This confusing customer causes issues statement doesnt apply',
#  'Ive already given details earlier willing answer questions need information resolve consulted contacted information incorrect billed something didnt order agree due shipping error part Xerox Corporation This reason bill disputed however address handled',
#  'still defective staples informed',
#  'You provide direct contact number direct email address contact XEROX Request issued link unable use link We reached Xerox status received email resolved working day',
#  'Please delete outstanding invoice Xerox customer service said would occur told Xerox customer service August invoice would deleted payment received July July payment sent July resent August The late charge invoice deleted Please delete',
#  'This issue going months cant even talk anybody Everything The tax exemption certificate customer along certificate resale supplied issue Xerox purchase order',
#  'New order credit easy use We lose client cant get act together terrible service',
#  'big corporate take responsibility job help customer instead passing buck Without customer business This second time issue told contact somebody else solve problem dont like people keep passing issue back customer get desk The correct response would say contact right person discuss get back',
#  'This request address corrected When spoke gentleman updated request say Suite number needed stay In addition address incorrect It Health Services Dr Ste Susan Martin',
#  'none forwarded advised',
#  'After spent much time phone different representatives take long period weeks send email telling covered receive software update get resolved shuffled dept dept hour representative telling something different told would contacted May weeks date original call resolution received email day two telling contract service needed Software update There explanation option offered allow get update machine contact local sales see get resolution Xerox system much help Very disappointing time consuming still software St Church phone cell would appreciate confirmation actually read care satisfied customer service',
#  'Havent heard back anyone Still waiting hear back rep anyone handles matter This resolved waiting hear back rep resolve issue The emails receiving confirmation emails received conversation hasnt even established',
#  'handled satisfactory timeframe promised wish turn around time quicker',
#  'The technician within hours extremely professional efficient knowledgeable',
#  'The request credit completed requested Not sure charged fee purchase order issued Thank',
#  'Id like start saying directed purchase wrong supplies technical support supply line happened wouldnt go whole process However last representative spoke extremely understanding didnt try act like honestly terms customer service They really went beyond help get situation thorough directions whole process going work Our UPS guy show prior us getting instructions return came back next day well Thanks',
#  'emails general Customer Service address resolution Most na basis answer get invoices looking',
#  'need find get refund returning supplies',
#  'No It address change location machine taken care',
#  'NO',
#  'Never even spoke Carlos',
#  'Fermin absolutely wonderful quick please Thank',
#  'ALEJANDRO professional prompt It clear Fermin full knowledge process request completely much appreciate Thank',
#  'Allan Estrada professional customer service skills',
#  'Fast',
#  'Great Customer Service Thank',
#  'When call wait forever cut received letter still showing late fees There six invoices mine explained They remove invoices left late fees balance due send another letter every time call one answers',
#  'Your prompt assistance correcting invoice greatly appreciated',
#  'At time inquiry rep new SR channel additional fees Contract requested approved team Rep addressed ASM give complete details ASM unaware contract cancelled error Xerox within days required per Service need inspection Rep closed inquiry stating inspection needed Sales Rep cost inspection This redone requested inspection second inquiry logged thus costing channel another fee inquiry',
#  'Thank handling request timely manner',
#  'We without made timely manner inquiry close result',
#  'My phone call sent several departments got correct one got right department gentleman professional',
#  'GREAT CUSTOMER SERVICE',
#  'We would like thank support Very much Thanks',
#  'please correct new mailing address Cook Road LA New address given representative Cook Road Road',
#  'thank',
#  'Dont know sure yet quoted price buyout told different price sent check price first quoted see resolved',
#  'surveys stop customers dont time employees',
#  'It year since quarterly billings machine incorrect getting good issue still happy call every quarter get resolved Please look case resolve',
#  'This may one worst experiences trying six months get information Xerox NOT auto renew one contracts Ive hoops multiple times finally got confirmation August contract would renew would NOT charged early termination fees since Im cancelling contract renewal received bill early termination fee person phone says cant anything Ive tried emailing person assured would extra fee received auto reply fixed',
#  'done timely Thank',
#  'For reason never received invoice last month therefore sending payment late charge church seems pretty severe pleased hope change address',
#  'Xerox handled issued rather',
#  'nice employee Xerox',
#  'dont think ever received response If sent email account',
#  'The representative efficient matter handled time frame promised seems long time Also keep problem every month keep disputing bill would like corrected go issue every month',
#  'requested original invoice tax purposes received January invoice payment',
# ...
#  'none',
#  'Great working Nelly',
#  'Just want make sure name gets changed properly Thank Betty When called said put San Francisco PO City You put please change Francisco',
#  'requested quarterly invoicing If could billed matching quarters least regular yearly quarters would worked ie etc know contract says requested quarterly many times years everyone says ok still bills monthly Thank assistance',
#  'How satisfied No one responded inquiries Jose sent email offered answer questions Well left four voicemails sent two emails including one You believe inquiries answered My fire Jose manager They customer service',
#  'The shipping address changed account Supplies needed would like online want make sure going right address',
#  'Irma Maria Our Xerox machine difficult get told pay lease fees need speak St Thomas rep get settled told needed call local Xerox office tried phone seem working need know get touch St Thomas Xerox',
#  'The issue resolved satisfaction',
#  'THE WAS NOT HAD TO TO TO GET THE CORRECT HE DID NOT KNOW ANYTHING HE DID NOT KNOW ANYTHING',
#  'This second request need credit invalid revenue billed beyond contract expiration date still closing without solution For second time mentioned CUSTOMER IS BILLED DATE clearly says beyond contract expiration date also note close contact David Smith Laura Barrera understand request Down see copy request Hello It government contracts auto renew Puerto Rico On CN outstanding balance invalid revenue therefore cannot accommodated All invoices covered government contract paid The customer cannot pay extended invoices We need credit invalid revenue billed beyond contract expiration date renewal valid CN NAME INVOICE SN SO BILL Please contact David Smith Laura Barrera understand request',
#  'He told contact rep tried calling put hold minutes hung tried emailing response',
#  'feel though Xerox doesnt listen help situation ever almost years dealt account Still almost years nobody provide said contract keeps stated The University whole contract Xerox department automatic without talking department directly getting told renewal letter sent us Xerox provided letter sent realized sent University Center deals invoices contracts Our issue resolved Carlos close matter goes prove separate Xerox',
#  'It took long resolve matter still done confirm amount able get Xerox referred back agent',
#  'still waiting contact Xerox Coupa form contained email Ive sent usacustomercarexeroxcom Please review email click link Coupa Portal',
#  'thank Allan',
#  'He said late wouldnt take consideration signed automatic payment therefore didnt make December payment assumed would automatic He said limit ACH said didnt realize He said past history showed good history would talk manager credit invoice It still credited The late charge still account credit account took ACH late charge applied current invoice told late charge would credited Thank',
#  'dont think giving clear information happens lease ends My question directly answered wanted know anything else required us returning copier know letter charge All told would completed end March',
#  'Good job',
#  'understand billing credit amounts forwarded spreadsheet amounts Ive left voice mails',
#  'issue resolved call still open',
#  'went beyond provide requested thank Hector',
#  'clear',
#  'It took longer felt get information',
#  'need correct invoice made pick Xerox copier response time issue still unresolved Was told contact local agent response couldnt help us call Xerox Customer Service emailed information response',
#  'Can fix problem My online account show payments made',
#  'honestly think going resolved due company Completely actually allow corporate offices make decision proceed would higher however since requested requests replied matter days But understand big complex company Im glad received something may first',
#  'speaking Pat Quinn State dissatisfied Xerox dealing issues Pat Quinn came along felt like met issues gone mean stated Pat wonderful got problems solved communication spot',
#  'Its hard answer questions dont know issue resolved assuming email supposed say issue resolved therefore ticket closed idea issue resolved closure email received provided information It looks like email response didnt get updated info Here received ReService Request Dear Thank contacting us regarding Form Customer Number Serial Number Type steps taken resolve inquiry dispute details find Type items attached invoice copy contract PO etc',
#  'Requested buyout quote Was provided Client looking purchase FMV leases devices',
#  'Thank Maria Jose She resolved problem wasnt receiving paper invoice month made change would receiving month She also promptly sent copy months invoice requested Excellent service',
#  'purchased At time life machine years Xerox offered lifetime warranty That warranty included full repairs replacement machine long owned machine That warranty total cost paid machine full years ago longer Finally months office Xerox honored agreement replaced broken machine current one would like copy contract extended lifetime warrant machine case thing happens',
#  'please provide information requested originally response provided customer effort receive payment invoices VERY Inquiry rep closed request without full request needed OF SERVICE added invoices per customers request could make payment The Inquiry rep made comment SERVICE closed request Apparently language STILL need information requested originally',
#  'communicated well service He knowledgeable polite',
#  'With Xerox general took months get issue resolved With Customer Care took month resolve issues invoices This included speaking different Reps The issue finally resolved Bani',
#  'Our agency name corrected billing information',
#  'resolved far know time unable access site says updates done Customer needs added site invoices site Information provided received email return saying provide enough information',
#  'Extremely efficient service',
#  'Thank quick response',
#  'additional comments',
#  'Communication immediate issue still outstanding still receiving invoices old mailing address',
#  'We still sure credit processed',
#  'thank',
#  'Thanks',
#  'Thanks email name closure letter vs name inquiry logged',
#  'spent time working banking feel',
#  'Extremely Satisfied',
#  'Issue resolved quickly thanks',
#  'still received invoices never account mailed available online received follow call supervisor requested discuss',
#  'The person spoke said name David Not sure actual person spoke helpful',
#  'none',
#  'quick resolution',
#  'Susan Wofford continually provides efficient service inquires processes This specific issue resolved least week sooner ETA satisfied',
#  'Have received requested invoices',
#  'Good turnaround time',
#  'entirely long get statement via email',
#  'Nope still without final resolution time call back wait hold get corrected called update mailing address sent confirmation showed Idaho Water Science Center called back explained work Idaho Water Science Center It Department Office Secretary He stated would make adjustment got confirmation issue resolved still shows Idaho Water Science Center That incorrect That would mean work USGS NOT work USGS Idaho Water Science Center department level level Still corrected',
#  'Id like mention Cesar matter also want commitment help',
#  'Let control types situations Moving serial customer another hold ups system allow move without assignment The ownership company clear day move customer completed requested problem',
#  'Thank handling situation The rep Xerox good explaining situation resolving problem Scott handled promptly Thanks',
#  'No',
#  'My situation resolved still need contacted My question even addressed',
#  'appreciated sense urgency much',
#  'No one called speak still missing boxes worth',
#  'WOULD PHONE CALL FROM SOMEONE IN MANAGEMENT TO RESOLVE THIS AS AS In April NEVER received invoice mail charged late fee non payment As soon made aware paying April bill paid promptly May In meantime spoke Xerox agent Brenda gave waiver paying late fee The late fee still account different invoice number customer service people pay closed dispute This dispute closed receive waiver promised via emails exchanged Brenda We customers since knowledge first time missed payment WE NEVER RECEIVED THE INVOICE IN THE IN THE FIRST Absolutely church treated poorly many years customer Have dealt many companies received invoice treated far situation even updated account late payments happen future',
#  'There experience The seems told wait paying invoice charged late fee Our Color Press whole week The technicians wonderful used two cases paper figure problem also believe credited enough impressions None books printed entire week usable',
#  'The account supply shipping address changed UPS keeps returning supplies church open days week noticed install address service would directed also changed The physical location equipment changed billing address They remain MO This original request sent need get shipping supplies address changed account Baptist Church MO Attn There someone church days week supplies returned since one sign The address install billing remain In meantime supplies supply people sent toner another wrong address able shipment thru UPS',
#  'none',
#  'This problem warrant survey It request current tax exempt cert',
#  'Great job',
#  'He went extra mile assist kept getting transferred one department another took time get need',
#  'told send email stating source invoices got credited late charges need credited well get account cleared Daniel Herrera DanielHerreraxeroxcom You turned around told collections representatives dispute late charges Please contact Daniel Herrera DanielHerreraxeroxcom dispute invoice Getting billing problem caused Xerox huge waste time',
#  'This fast Thanks',
#  'going far long log several requests need connect customer going around circles account trying resolve three invoices need connect customer person billing talk live email working',
#  'appreciate prompt response understand personal email looking forward receiving resolution mail',
#  'She extremely helpful new address issue',
#  'issue resolved quickly keep good work',
#  'Luisa great',
#  'VERY dissatisfied called request buyout printers received NOTHING received NO NOTHING Where This',
#  'Thank prompt attention matter',
#  'service great',
#  'My complaint Estuardo Kathleen Kathleen Im rating The credit late fee initiated received collection call Kathleen Xerox never late fee assessed never received call Im partially satisfied finally credited',
#  'The request asked processed correctly',
#  'know process took long sending emails call yesterday create inform takes business days Take consideration least billing side ask create customer numbers likely need immediately complete billing day requesting since guys create limit amount Customer numbers call force use emails instead take long fulfill requests think much help lot sense amount time fulfill request know process took long sending emails call yesterday create inform takes business days Take consideration least billing side ask create customer numbers likely need immediately complete billing day requesting since guys create limit amount Customer numbers call force use emails instead take long fulfill requests think much help lot sense amount time fulfill request',
#  'heard anyone Just logged charges still heard anyone regarding request requesting late fees written account long time customer Xerox office make payments',
#  'WAS CUSTOMER SERVICE AFTER MY WITH CUSTOMER SERVICE WAS VERY WITH THE CUSTOMER SERVICE WOULD BE MY CALL IF FOR ANYTHING IN THE WAS NO RESOLUTION WAS TOLD THE SALES REP HAD TO ADDRESS THE ISSUE AM THE SALES REP',
#  'sure phone representative complete task email confirmation etc It still remains though issue resolved It almost one month address account still wrong',
#  'The issue completely resolved Cindy helpful made great toward solving problem She provided lots helpful information',
#  'thank quick response',
#  'quick',
#  'Very pleasant deal',
#  'Could open email sent get buyout',
#  'pushed another rep unable get touch Also dont know name Mary came one business name',
#  'Mary excellent',
#  'Now Ive invoiced twice My regular billing received another invoice dated',
#  'sad service Glad away still confused give since big corporation always right us little guys arent never ever business xerox let others know went way get someone speak go collection Very sad Poor customer service You love department You',
#  'TO CONTACT ME TO RESOLVE THIS ISSUE AND AMOUNT XEROX INK FROM MARKETPLACE NEWEGG ARE ALL NEWEGG INK IS UNDER WITH XEROX AND TO CONTACT YOU YOU DONT YOUR AS WAS TOLD TO BACK TO THE MARKETPLACE THIS',
#  'Could hear voice phone Great experience',
#  'Requested copy signed agreement receive',
#  'It resolved quickly without issue pleased',
#  'made error sent glad caught completed asked would wrong thank',
#  'The Rep dealt extremely helpful My satisfaction way issue resolved length time took carrier pick equipment This created customer issue never occurred',
#  'order correctly sent wrong request',
#  'The account mess due errors',
#  'Lisa Curtis always professional sense urgency necessary escalated inquiries She appreciated much',
#  'We think twice renewing contract Our auto replenishment toner waste container auto When needed change waste container none available Xerox charged us shipping additional expense The machine service days busy',
#  'This simple change address Xerox turned major issue',
#  'getting called error They applied half bill returned warrant back We issued new check went March',
#  'No The request handled quickly appreciate',
#  'Thanks',
#  'fixed',
#  'clear person processing request understands complete request The equipment Xerox said needs handled Xerox leave message transferred around calling clarify Still sure Xerox aware longer using machines',
#  'request done timely correctly',
#  'difficult',
#  'need set auto pay credit card',
#  'Thanks',
#  'We receive January invoice click charges base charge equipment called Xerox want make late payment surprised find Xerox unable email invoice copies We wait duplicate invoice issued mailed adding time already late payment',
#  'Erwin made process smooth efficient',
#  'unable apply credit invoice removed invoice Cust SR',
#  'Thank incorrect CN work research Have nice day',
#  'impressed Elena resolve ensure issue fixed correctly Good asking second level questions prevent future',
#  'David Mancil incredible job sorting resolving issue dealing He must spent great deal time effort problem Thanks much',
#  'requested copy contract serial number received nothing closure notification',
#  'No needed copy current lease received within time told would receive',
#  'NO',
#  'Cesar professional helped expedite transaction',
#  'surprised simple request get list equipment leased Xerox yet complete The Xerox rep via local company unable provide information customer service rep spoke via Xerox invoice unable help request submitted via email yet complete',
#  'understand bill expect payment explain charges customer direct third party This third request seem email even read closing SR',
#  'Im trying set Xerox receive ACH payments In order need Xeroxs banking details Company physical signature received signed form request',
#  'need get processed sure taking long customer wanting unit picked ive tried cancelling numerous times cant get anyone talk',
#  'would really like issue resolved The issue resolved',
#  'need email letter saying erroneous something dollar bill sent withdrawn please closed settled Xerox final agreement payment payment full things Xerox related machine Ive yet hear Xerox odd dollar bill sent later incorrect withdrawn',
#  'reached someone else next day helpful felt like understood saying The person named invoice much use never picks phone My communication understood well',
#  'support ownership constantly please contact number instead along Took almost weeks get support printer completely The rep onsite great resolved issue time took get point painful',
#  'Xerox reaching',
#  'none',
#  ...]

# %%
train_docs = records
train_docs
# Out:
# ['The issue resolved correctly It took research end still billed incorrectly',
#  'Just one order changed billing billing changed without authorization main entity nothing customer service person way billing managed',
#  'Susan provides efficient timely service',
#  'It reps fault nothing It hands fix issues Xerox yet completed fixing invoice issues started June',
#  'The request update bill address completed correctly',
#  'see prior comment Can split difference since readings taken guys notes really use machine It Xerox clicks charging It states Xerox reading machine moved facility Xerox continued fact testing etc get us set We could use machine print due printing correctly issues We used another print We finally July pm get correct etc press We started printing afternoon That reading clicks done pm starting number end month July sign sheet adjust log sheet states starting number end month For large color know number previous machine number written Can split difference charge',
#  'never received quote',
#  'hate Xerox dealing emails phone call menu hell giant turn want use another company This whole thing giant problem needed sent provided another way arrived given send back sent back needed one No one ever able explain billed many ordered give refund',
#  'Overall positive experience',
#  'trying resolve issue since February hence final question sent emails spoken multiple individuals Ms Ronal person took ownership investigated situation resolved accurately It pleasure deal',
#  'AND TO WITH THANK YOU',
#  'like know last bill week billing billing department messed Your billing department messed',
#  'The first representative spoke polite helpful The last amazing That situation billing Xerox concerns customer credit cause concern That situation still active another level upsetting However last representative Sarah de efficient job cleaning long standing mess Her follow well',
#  'unprofessional person Need talk someone position Please provide contact',
#  'Your company terrible already wasted much time providing details',
#  'The update completed Please review requested The serial number new customer number sent The update completed Please review email',
#  'someone else called help whats ever This unhelpful company dealt business',
#  'see previous comments Xerox endless paperwork years change ownership WorkCentre And never seems get accomplished even though told time accomplished The invoice repairs keeps getting sent previous owner machine long business late charges invoice never sent When call phone number provided Xerox representatives bill phone number doesnt actually work This response got changing ownership makes absolutely sense cant get anyone tell supposed mean per email conversation address cannot changed account two different legal however ownership change completed past effective That',
#  'wish equipment wasnt good Im really tired dealing horrible customer service company feel like check every bill dealings Xerox made wonder company run bunch My inquiry regarding getting sales tax invoices service agreements click charges came back said charge sales tax mandatory service agreements Ill check perhaps somebody Xerox explain leases NOT charged sales tax service agreements',
#  '',
#  'still waiting report need report important receive',
#  'would preferred response day ok Without instructions sent would never located add account information easy find Thank',
#  'Initially believe issue addressed correctly Your representative contacted made sure issue resolved She even sent screen changes assure correct Very happy effort get resolved',
#  'No one even contacted addressed issue sent email case closed',
#  'Great Job',
#  'No',
#  'It took days longer problem resolved',
#  'The person spoke professional The problem Xerox policies Ive always able order part last two years sudden cant get without going techs Once person spoke helpful limited She nice professional',
#  'Please previous comment We sent letter asking terms buy lease quote buy equipment We sent second request yet get response This service weve Xerox reason want machine gone',
#  'Great Support Service provided',
#  'Thanks',
#  'enough said You folks never service contract question lady ext assured taken care would get bills inquiries Then get phone call January asking meter reads Get act together stop hoping wont pay attention paperwork send Im guessing hope something owe money',
#  'Terri excellent resolving inquiries',
#  'thanks getting resolved quickly',
#  'My request pushed sales rep responsibility customer number agreement support',
#  'Terri extremely helpful understanding Xerox issues',
#  'Resolved quickly',
#  'logged inquiry The closure notification included one invoice resolved There two invoices needing credits In addition credit invoices applied open invoices',
#  'great service quick resolution',
#  'copy Purchase Order requested All communication done via',
#  'Would like faster turn around time submitting requests Jose David still working request sure great job',
#  'Billing nearly impossible understand got run around billing explained told one thing many customer got one else story changed changed end call TWICE Second person spoke pretty much told first person spoke idea talking way confidence team basically told job wrong paying invoices based Invoice Customer serial number machine Which far know NO AP Specialist would pay invoice based serial numbers Billing makes absolutely sense get feeling even reps spoke understand billing got ran around much asked dispute late fee told would speak yet department decided would dispute line This first time EXACT problem Xerox billing run around Xerox reps trying gain understanding obviously broken process billing',
#  'No',
#  'promptly provided copy credit invoice',
#  'It looks like double charges account taxed non taxed invoices used different numbers need tax credit memo original invoice new invoice revised price',
#  'Thank much addressing request expeditious manner',
#  'Still waiting The toner cartridge purchased online supply store defective After much time multiple calls finally advised solution would charge would credit card After two weeks credit yet appeared still waiting',
#  'The issue resolved Xerox customer service difficult work',
#  'Im impressed request accepted completed less hours Keep good work',
#  'It appears issues sales rep xerox',
#  'We trying inform equipment two want make sure paying one equipment',
#  'Xerox invoicing us early termination fee purchased new machine service Xerox still No one provide type contract refers term agreed charge wont removed account',
#  'The representatives nice hard time getting information needed It certainly timely manner No email answers No phone calls We local dealer given buyout quote see considered closed received response We receive resolution information sent email matter saying received answer inquiry information The go local Xerox dealer ask',
#  'sr closed removed',
#  'My request handled quickly efficiently',
#  'Fast efficient',
#  'Appreciate help supporting Thankyou',
#  'called correct told needed call different called told call original Your reps take bit time understand concern passing buck',
#  'appreciate speedy response resolution received inquiry',
#  'The inquiry customer claim National Park Service order staples The inquiry closed claiming serial number connected account exempt billing supplies issue involved The customer claiming another Xerox customer get invoice issued credit',
#  'condescending responses There seems severe communicate representatives Guatemala way talk anyone cant give simple explanation requests proper procedure put request new customer numbers request ignored Now told',
#  'This contract state The contract provided reference issue In dont believe contract referenced since rep stated billed monthly charge annual maintenance fee',
#  'English speak English take asked speak clearly',
#  'Regarding email communication rep addressed Sarah Fisher name Sarah Everything else fine',
#  'Credit processed week Inquiry ETA pleased Thank',
#  'Please remove sales use tax account orders placed Sales tax removed account even sending Form',
#  'never submitted account isnt mine',
#  'Have requested corrections twice still corrected long get problem solved Requested correct invoices corrected',
#  'appreciated received',
#  'Barbara Lang professional polite Great Customer Services skills',
#  'We sent paperwork back per request case closed phone call good customer service All signed returned clue Xerox',
#  'engaged incorrect dept forwarded proper dept',
#  'Closure Notification Service Request mailed customer stating assignment completed By customer understand able provide invoices new customer name Another inquiry open credit rebill new customer name new SR done date promised customer wait If going close SR tell customer one part process done provide new SR part This process customer',
#  'Luisa great helpful The amount time spent fix issue hours still resolved Xerox order unable stop order You sent UPS pickup items credited us back',
#  'appreciate reaching clarification worked inquiry Thanks fine job every time',
#  'believe correction still made Xerox',
#  'still havent received shipping label return staples told would receive within days still havent seen email department',
#  'extremely helpful went beyond help us We picked phone',
#  'The representative job issue resolved The customer service agent nice handled request professionally She stated request processed resolved However issue resolved',
#  'Please thank Jose quick response',
#  'problems handling credit account concerns regarding cancelation contract We received letter stating service contract expire thought would receive something continue maintenance Xerox copier',
#  'quick turnaround',
#  'Your prompt attention assistance always greatly appreciated',
#  'My CN returned within hours sending request Thanks much',
#  'Took call never received call back promised names one invoice',
#  'My issue resolved tried call representative call would go emailed representative asking issue corrected requested change shipping address metered supplies Our install address changed shipping',
#  'Thank',
#  'seem recall response',
#  'please quickly problem resolved considering caused problem',
#  'No information provided',
#  'No issue settled receive reply',
#  'Lynne great got invoices needed fiscal year end June She',
#  'Great work Allan always requests appreciate support',
#  'reference correct PO get invoices Accounts Xerox wants paid AP pay invoices dont exist system First far know involved phone call AGUILAR AGUILAR called looking status February invoices called back spoke provided list invoices question email returned request copies invoices Rhodes system payment also future forward Rhodes Pharmaceuticals requests payment Rhodes Pharmaceuticals last issue every time call placed Xerox different individual deals call follow call original individual called cant reached although nice AND hard hear everyone Xerox Is everyone asked phone No happy Xerox willing forward invoices payment happy Xerox continues reference incorrect POs invoices causes delay payment',
#  'billing address update completed correctly',
#  'Still seeking information originally requested received closure notification absolutely information resolution question',
#  'appreciate expeditious response',
#  'Problem still response issue',
#  'We without fully copier month first weeks one Xerox seemed even care working copier found today downtime credit amounts',
#  'customer issue asked able It made customer difference case greatly appreciated',
#  'please get sales use tax issue exempt City Trying place order still sales use tax showing order place order issue resolved',
#  'This issue resolved The person helped get credit started however received replacement part We need contact Xerox help us defective print Format Printer',
#  'impressed Mr Morales took time help first time calling sure needing questions ask Im new put position',
#  'When customer cancellation contract take month pick equipment try charge extra month rent machine used awaiting Just clarify recent response inquiry concerning July invoice copier contract Xerox June contacted representative David June inform would renewing contract requested please machine picked June This June July stated email Your company pick machine July sent numerous emails reached representative time period June thru July trying get someone Xerox come remove machine This copier sitting hallway nearly month waiting someone Xerox come pick This fault everything supposed submitting cancellation request end contract June Xerox one feet picking machine To tell invoice month July valid agency month company decided pick equipment end contract June unacceptable unprofessional The cancellation request made June machine ready removal time As much want say owe month July impossible since contract expired cancellation request June Just Xerox took time picking machine justify trying tell customer owe month service valid since contract expired June machine awaiting pick make sure Procurement Group understands Xerox contract expiration dates instead prefer extend contract machine picked regardless client submitting cancellation requests end contracts attempts someone Xerox come pick equipment We going pay month Xerox took time picking copier effort charging us another month rent Invoice amount billing period July thru July needs cancelled new corrected invoice resubmitted amount final copy count end June Sincerely Officer III',
#  'FIX YOUR My name misspelled since Xerox system set acknowledge emails sent NOT received never got answer Susan took care today DID name several times giving information since ALWAYS known name NOT spelled people think',
#  'You never solved problem My request closed nobody ever contacted resolve matter',
#  'Thankyou',
#  'Both rep keep sending information get resolved took months Im satisfied results',
#  'Be kind clients offer alternatives In way think clients Good afternoon We San Juan serious complaint management case As client needed help Xerox offer alternatives us concern would able business Xerox',
#  'When service rep responded give name contact would pass message replacement person took position tired getting passed one answer Xerox customer service noted passed issue person took That beginning December yet hear response anyone',
#  'someone call kept getting email hold lease sending PO hear someone',
#  'Thank',
#  'Please email send communications Javier Carlos Thank The main issue needed addressed incorrect monthly base charge August getting final revised bill removed machine August Xerox Carlos addressed excess rigging charges meter reads recent dispute inquiry still waiting get resolved',
#  'Nothing done The representative understand complaint',
#  'Super fast Thank',
#  'Thanks',
#  'courteous professional handling inquiry regarding credit balance',
#  'thought Susan helpful appreciated services We small customer means dont always resources focus service contracts like',
#  'new CN Thanks Manuel responsive able give good customer County quickly There several customers tool able find one purchase order really appreciated fact got one quickly Thanks',
#  'first called tell behind paying invoice person talked many many company told insurance least times copies sent',
#  'It wasnt resolved Im still waiting receive invoices asked invoices mailed address mailed July It August yet receive doubt really sent Now call Xerox request copies emailed Why cant emailed every month without making special request really dont understand This Xerox needs move age',
#  'didnt get clear answer issue apply work home couldnt apply call phone couldnt get anybody help getting website trying apply job couldnt apply online would take password',
#  'still received signed work agreement',
#  'THE ISSUE HAS NOT BEEN RESOLVED requested shipping address updated still happened When log metered supplies account shipping address shows address placed call get changed',
#  'The person got info situation wrong reach clarification closed inquiry Totally waste time',
#  'would appreciate future invoices sent Business Administration Ave Suite San Juan Puerto Rico Attn Jose Rodriguez',
#  'We received invoice Xerox month March received letter January telling us contract would renewed disputed charge Xerox website received email saying cancel agreement therefore automatically renewed months',
#  'The techs great This issue caused management Xerox cost sourcing cheaper parts must get reliability back otherwise need look alternatives two Both poor uptime last months The technician coming onsite great believe parts like getting Xerox defective downtime us feel bad techs Xerox appears sourcing cheaper parts breaking high rate maybe resulting log service calls machine nearly months believe Xerox know problem wont recall parts cost money Xerox problems result customer uptime currently impact directly leave Xerox another better reliability fixed soon',
#  'none time',
#  'No',
#  'reps good sent cancellation twice already still get billed unit pay part',
#  'Susan great work requires information provides detail needed always available help clarify questions might',
#  'asked buyout quote contract got run around person responding Apparently system sent blank email format didnt record notes When forwarded email brought attention nothing told sent information rep responded stated email rude response',
#  'Good afternoon The main issue resolved incorrect increase Although invoices keep coming PO instead This one thing fix left Thanks',
#  'The process needs changed The report states invoice serial number Customer Number Obviously would thats whats system It still doesnt belong It would make sense sales representative consulted He confirmed account belong Upon reviewing account able determine invoice correctly generated customer number mentioned The equipment located AVE FL RM The account belong ever contacted representative get resolved',
#  'JOB real quick This urgent matter sent email priority request resolved Thanks much',
#  'local sales contact great job supporting us',
#  'Cesar prompt responses patient us waiting signatures The process took awhile waiting signatures pleased handled us',
#  'needed know sales tax rate charged know part contract maintenance need supplies tax charged invoices question request James Daniel responded needed call someone else find information moment call requested call Monday January',
#  'Appreciate quick response resolution',
#  'Lisa excellent job resolving issue',
#  'Kathy awesome',
#  'Thank everything David',
#  'Luisa professional courteous',
#  'Please cancel metered account effective immediately longer afford getting new machine Thanks Dennis Please cancel metered account effective immediately longer afford getting new machine Thanks Dennis',
#  'think credit file also non clear invoices credit late charges bill Please clear invoices',
#  'pleased received requested copies outstanding invoices within hour call',
#  'Excellent Thank',
#  'She called regarding open invoices account requested copies invoices sent tell needed research called try explain one invoices billing months appeared paid months No one ever waiting return call',
#  'needed address changed occurred timely efficient manner However order name account changed redirected customer service cut several times There seems closed loop sends customers circles customer service line',
#  'dont know two DUNS numbers assigned customer Im disappointed received response Two DUNS assigned customer one needed It delayed order severely Ive tried email Customer Care DUNS Resolution Team Ive copied Ana Barrios get resolved yet hear anything My Order continues delayed',
#  'Ericka awesome She handled everything perfectly',
#  'Very needed problem fixed Tuesday called problem didnt get taken care',
#  'Great customer service',
#  'get right',
#  'He courteous helpful',
#  'Receiving Invoices timely matter would great normally receive credit card charged thats stopped automatic payments',
#  'All received email stating sr closed nothing tell worked',
#  'Still resolved changing name group taking physical ownership machine leave name',
#  'spoken via phone several different representatives asking issue resolved avail It looks like name changed one copiers We copier needs name corrected also Also go Supplies page Is possible copiers input supplies hand asked done happened yet',
#  'Really fast',
#  'handle problem quickly great job wish problems company invoices would handle quickly',
#  'received email stating address change completed equipment serial When received invoice dated install address updated The problem wrong address taxes accurately',
#  'The rep spoke extremely helpful fixed every part problems dealing',
#  'dont understand takes longer pull invoices Managed Services Accounts If requesting regular basis access need pull quickly It takes much time customers usually upset us pull information Now longer wait get right information asked invoices specific serial number March April May received summary invoices months serial numbers associate So cant use send takes long get first place Now waste time trying get need Totally frustrating',
#  'Jossy extremely thorough accurate resolutions simply best Glad team Jossy',
#  'It supply issue church days week UPS returning supplies Hopefully supply shipping address changed service billing',
#  'Could please respond status inquiry first heard nothing else printer picked Thanks Carol Road fax',
#  'prefer use online ordering phone communication timeconsuming frustrating system doesnt allow information Shipping billing addresses needed changed sent notice showing changes log old address still spelled',
#  'thank much creating customer number customer order supplies State',
#  'little money obviously important Xerox customer relations The information provided shows fact machines installed date state You therefore error charging lease time period There obviously communication Image Xerox But fault You year relationship good customer couple dollars sense You provided resolution zero',
#  'Please come pick machine You get handing back department ignoring Please come pick machine ASAP',
#  'The issue pass many owned managed',
#  'hung It took three calls pay bill The first one lady said used live She hung The call disconnect finally call got someone service great used work Xerox years would recommend anyone getting Xerox machine',
#  'The address different information provided',
#  'requested copy contract agreement get The request closed task completed resubmit',
#  'didnt reply',
#  'It STILL taken care still charges account attached PO machine department months call email request charges moved appropriate customer even provided information person created PO person works University another location another department way tried get Xerox paid outstanding invoices longer worth time want follow several requests help',
#  'pleasure work',
#  'Allan great work thanks support',
#  'After months dealing wish could resolved thought issue closed yet getting phone calls pertaining Each time assured taking care',
#  'lease machine replace newer model It took little Xerox pick old machine new one installed',
#  'The original order started around It either mailed Xerox wrong address always receive toner address mail carrier made told would wait situation investigated could reorder It could take days In meantime staples machine Why could place order offered pay investigated lost order Terrible idea sense made us want recommend company anyone else Finally order mailed',
#  'Thank You address change request The escalation promptly resolved',
#  'Issue hasnt resolved yet',
#  '',
#  'There resolution situation',
#  'No',
#  'Not customer friendly systems Asked addresses invoices told able system',
#  'We want pay remaining rent remaining lease term return copier There mention buyout fee contract wish purchase machine As told persons spoke pay lump sum rent return copier Instead offer apparently pay buyout fee purchase copier If prefer simply store machine pay rent monthly pay lump sum return copier',
#  'This FIRST time spoke someone first language English truly repeat information number times someone around My original request never fulfilled thus today This also telephone system didnt feedback US speak customer service rep within US would delays issues communication',
#  'The XNAC team wonderful always prompt respond enjoy working',
#  'Thanks Gabriela',
#  'submit requests get invoices requested Marvin one took ownership made sure received invoices requested He courteous professional',
#  'None service great',
#  'billing even though machine already Xerox Not sure rebilling took long Would like received credit invoice dispute accounting period',
#  'My issue equipment shown log trying add results serial numbers confirmed The response send list serial numbers supplied originally address question',
#  'wait weeks redirected perhaps way screen requests delays customer reps fault rather process tks Mark customer moved another state point couldnt account deemed lost The customer operation state service trying year status changed engaged team waited weeks told managed services account try fault processes feel free contact want details Mark Customer Relations Representative Customer Xerox Corporation Street Suite ext',
#  'nothing done ignored request',
#  'The rep promptly handled updating address Great service',
#  'You done nothing say meter readings correct meter readings higher month ago In readings STILL',
#  'Extremely fast turn around Thank',
#  'needed CN today urgent order helpful responsive',
#  'Very please outcome',
#  'She prompt professional',
#  'additional comments',
#  'Lynne great thank',
#  'professional',
#  'No',
#  'requesting address change time still isnt changed Xeroxcom',
#  'No requested refund overnight shipping charges boxes toner since wrong toner shipped us followed instructions service rep toner boxes returned via Xerox call tag provided billing dept reference numbers given resolve matter The resolution request tell none ever happened small matter become one pursue file complaint',
#  'satisfied answer received Smith Printing Office Supply Inc Direct Pay paying charged Thank You Smith Smith Printing Office Supply Inc',
#  'still waiting information information provided',
#  'think USA Cust care little ability caused wasted hours time hope gets better Xerox Sales CARE Thank contacting us regarding cancellation request Serial Number Inland Color Please note machines part active lease contracts reached expiration dates We unable cancel maintenance part agreement THIS IS AND NOT OF PLEASE CANCEL THIS WITH ETCs',
#  'Since weve owned machine every time Ive contacted number customer support told NOT would billed maintenance No one ever mentioned one year maintenance service mentioned Mark When told told contact local sales rep However since machine communication sales rep nonexistent tried times Carlos local sales rep never received response When would call number couldnt answer questions would try direct local sales rep It took year put contact someone told sales reps longer Xerox Every time told Mark response back get local sales rep nonexistent Why customer jump hoops figure whats going',
#  'Be specific asked certain machine located took several days someone get back tell located address bill sent That much need know department',
#  'Yes All well',
#  'Was told contract ends also told lease seem right option cancel contract least buyout',
#  'The communication Xerox extremely disappointing requested summary payments made invoices last months never received anything set payment via website never notified payments going got new invoices explanation After phone calls several hours still receive information requested It frustrating working Xerox may renew lease',
#  'got lot information already billed need know billed items sheet',
#  'No Im taken back company still around horrible way company dealing situation think lady dealt nice professional told thank day owe money copiers sitting hallway almost months That wouldnt pick hassle come pick copiers If questions please call Im bothered company far able situation',
#  'The customer service representative spoke spent hour half phone automated menu reach human That incredibly frustrating needed invoices different account numbers automated wasnt working needed talk person wish zero speak representative option',
#  'The issue took way long resolve My one phone days took one phone call weeks',
#  'We charged late fee check delayed mail The representative said could reverse late fee The invoice paid late invoice billed incorrectly twice waited weeks finally get correct invoice Just yesterday received click charge invoice September That invoice issued late took days get us It ok Xerox feet billing correcting mistakes customers pay late Every request make takes minimum weeks get resolved longer Your customer service horrible policies This something discussed every time talk Xerox machine',
#  'For An issue got solved quickly got call someone info email done',
#  'Id like know network controller issue resolved The technician called asked questions problem explained problem She asked still said moment She said since looked like resolved didnt need come call happened would come waited complete survey see machine problems Im trying print every time send job go machine says The job doesnt print This happened times row morning Why network controller Is something fixed set right doesnt happen',
#  'nice Xerox used Xerox phone system mess Was told could call employee reviewed bill telephone part business model billed machine sitting unused weeks Xerox package machine shipment Moving came pick Not fault Xerox Machine could shipped Feb get picked weeks first removed',
#  'turn case local Xerox rep work another Corp Xerox rep resolve receive written email say invoice pay think case still unresolved worked local Xerox rep Corp Xerox rep The price per copy black color reversed',
#  'Silvia provided good service completed request short time performance outstanding',
#  'Thank quick resolution excellent communication throughout This sensitive customer issue quickly resolved',
#  'gave representative Customer number name read back address correctly received NOT account The email received invoices requested company Santa CA Rocks',
#  'The communication offered poorly worded unsure whether XEROX picking package Glad worked',
#  'She finally resolved issue',
#  'Jane pleasure work Amazing requests timely Thank',
#  'none',
#  '',
#  'transferred multiple times customer service representatives',
#  'issues answered resolved issues invoices paid recurring payment instructions',
#  'This fast thanks',
#  'The rep respond explained incorrect spending minutes time highly paid resources Xerox work around issue',
#  'No The helpdesk fantastic job needed call continue process didnt time No fault helpdesk',
#  'The buyout quote confusing needed contact someone Xerox clarify amount paid It would better provide list dates amounts ie paid etc',
#  'Great service',
#  'This horrible year',
#  'completed timely thank',
#  'still waiting correct information',
#  'The handling issue done timely matter',
#  'How guys close account without emailing us final answer whats going case',
#  'would happy copy emails sent try get issue resolved The rep didnt even try resolve issue submitting cancellation paperwork The rep didnt ask send wants start whole new request Xerox needs serious help customer service department This going since October one seems working',
#  'We asking address change since Thanks addressing FOUR YEARS',
#  'really appreciate extra email letting know working Without might call Thank',
#  'Please let technician know use black testing machine instead color since Xerox prints price color black Thanks',
#  'It took long simple request',
#  'David great job',
#  'Sergio friendly However spelled first name wrong didnt tell ended update address wanted update sent Closure Notification Service Request thought update made would confusing So think maybe irritated didnt want anything asked remove line address never heard back done We Center everyone refers Center huge Student Center building lots offices stores connected everyone calls Student Center So updating address wanted remove CENTER RM OF CENTER next line STUDENT SUCCESS enough find us without CENTER RM confusing situation My building called Student Center Sergio said line long So asked delete CENTER RM STUDENT SUCCESS He never let know resolved',
#  'The Sales rep left without solving issue without providing new sale rep contact Im still sure sales rep Ive trying return copier SN PO since June cant get anyone help service one Xerox picked machine still invoice end June need machine picked need credit invoices inv Thanks',
#  'The first adjustment done incorrectly redone',
#  'My request asking removal extended invoice April retention unit purchase agreement signed customer Feb closing notification talking removal unit still lease agreement also CBR processed retention order status received answer yet',
#  'Great job',
#  'We production facility customers If get bad product need replaced nearly month wait acceptable performance',
#  'resolved Was waiting error fixed next billing received billing issue unresolved',
#  'See comments anything add incident This issue resolved placed emergency order previous order received half The toners color machine missing So called agreed Xerox send expedited order one set toners premium freight charge since Xerox would overnight package us NEVER got order called week later order explained never got order We toner stores point advised take issue FedEx Xerox send another order free charge place order compensate stores point They told us received order contact billing department reverse premium freight charge since never got order FedEx investigation driver apparently order said location left door since said place closed show delivery made pm Tuesday Keep mind Office NEVER closed pm Tuesday The FedEx case manager agreed order They provided case number Xerox could file claim missing order FedEx compensate loss In mean time received replacement order replacement order lost The toner MACHINE Since placed order every toner eventually compensate stores hopefully run toner That order received We contacted billing department advised upon delivery toner dispute premium freight charge since never got order Now Xerox telling us reverse charge got report FedEx saying order delivered somewhere despite explaining details multiple representatives including billing department advised Xerox This experience absolute disaster start process We may refer incident corporate office point',
#  'We appreciate complete response issue',
#  'requested invoice emailed allow payment timely manner It mailed The invoice received mail first time requested invoice emailed get paid time The invoice sent mail',
#  'Amanda great Thank much',
#  'new machine already replaced one year due problems required numerous service calls since replaced months ago On top errors made billing cannot seem get anyone properly help Customer service tells issue resolved theres credit account get past due invoices billing department And one responds correspondence My experience Xerox terrible There ongoing issue regarding inaccurate charge Xerox billing errors inadequate follow emailed clarification questions several times gotten response',
#  'Thank taking care',
#  'The issue resolved case closed No one ever got back called sent email letting know need call back discuss never got call back',
#  'Very appreciative action steps Field would need update Customer Tax exemption',
#  'request met thanks',
#  'The representative everything complete request understand party involved resolution process bit Everything Xerox part spot',
#  'documents provided incorrect accurate portion entire contract intentional disconnect call Ms immediate supervisor Mr supposed follow would like customer care rep US contact',
#  '',
#  'Please resolve issue remove late fees called multiple times emailed issue still resolved',
#  'Thanks',
#  'received invoices day',
#  'In years printing never service better',
#  'Thanks',
#  'Fast response like gets orders processed much faster',
#  'Erwin extremely helpful Thank Erwin',
#  'Being fourth representative spoke issue still resolve keep getting run around would say representative helpful Being fourth representative spoke issue still resolve keep getting run around would say representative helpful',
#  'Not sure You sending survey getting work done All asking received request fix issue received note stating got information getting email issue resolved As Xerox representative getting customer sign order year two year process At times feel Xerox takes work sales professional serious billing requirements needs client addressed fully With better',
#  'Im still sure took year Xerox reach us account past due printer location year We still receiving invoices even though contract We dont even printer anymore We want sure billed anymore sent invoices Weve paid bill date',
#  'Who needs contacted regarding credit We needed credit amount charged charged',
#  'On sent documentation Josseline Moreno company name changed ownership changed ALL need mailing address changed moved new office location This email appears asking exact information AGAIN Im gone beyond get fixed get point forwarding order expire longer get maybe pay attention telling Thanks',
#  'requesting immediate Xerox address billing resolution contracts As response Xerox address question generally mark issue addressing question As Government Officer hope never need make another Xerox',
#  'The Xerox Representative fine job clearly none fault My Agreement Xerox clearly states either party provides notice termination least days expiration initial renew automatically monthtomonth basis terms provided written notification Agreement please make sure noted account Xerox notified regardless soon system actually log',
#  'issue provided resale cert completed paperwork lease delivery equipment receive response Press contact leaving voicemail asking resolve called number invoice given issue number waited surprised took long simply contact let know copy resale cert way way much',
#  'The printer work consistently last one We charged training fee Communication poor Danielle',
#  'Thank',
#  'No',
#  'impressed receive document quickly Dan Gilland also followed request made sure received He professional helpful',
#  'invoice charged xerox paying whole issues please check sales person',
#  'Our issue resolved still unable gain invoices account Xerox website Xerox responsive',
#  'You wrong person',
#  'put anyone could error please correct Thank waited says FINANCIAL Maybe error communicating please invoices previously read FCU read new FINANCIAL FCU Thank',
#  'Thank Team',
#  'sure process Xerox lady worked take level The customer wants way purchase billable supplies online using internal purchase dont wish use credit cards online Can help',
#  'requested answer question Can pay lease machine picked received purchase quote answer question',
#  'know request satisfied The machine replaced two months working expectations expect charged lease fee heard billing issue resolved',
#  'issue solved del solved Juan',
#  'The ticket still open There remains discrepancy reply Xerox',
#  'The team outstanding job Thanks Carlos',
#  'Took year resolve end satisfied outcome',
#  'Excellent Service',
#  'Lucia handled matter professionally feel showed concern handling We satisfied results help',
#  'Please find take tax present bill They gave us credit previous tax still charging us tax bill',
#  'seen copy person issues every copy job make',
#  'He good job kept communication',
#  'much work get someone service xerox machine purchased asked fill form know need send signed letter All want someone may sent documents computer lot work someone service machine',
#  'overall process order staples probably worst dealt representative knowing parts sending wrong one setting return rep dealt couldnt understand needed return product get missing product like started finally hang call back When called Xerox set return told someone would coming pick wrong product start return wasnt told take shipping department UPS come also told window pick would within next weeks specific time expect picked',
#  'Again seems credits provided inadequate provided credits In technician worked machine two days used color credit inadequate',
#  'Josseline awesome She took time explain entire process even explaining longer needed new customer number created minimal change required It clear Josseline takes work wish others communicated promptly clearly Well done',
#  'Maria still working getting resolved realize time sensitive end',
#  'We charged late fee due accounting dept crediting invoices credits open invoices account credit depts sent late fees debits even though credits invoice charges Very bad accounting dept told send email late fees customer care basically said handle closed case This company worst handling issues They fine phone soon one hand says something hand cant follow never recommend Xerox copy service disappointing',
#  'Great job Keep good work',
#  'quote attached sent sale rep need contact',
#  'Lynne Jones said could take weeks resolve took',
#  'Please complete form return us required The questions really apply This office complete form sent Our form supplies us information need complete vendor file',
#  'response time short',
#  'Everything company last year two nothing problem Most people answer phone ok send staples back label provided like everything done company last year two problem Was told would receive email info got email return label printed used UPS picked package getting credit Another company tried fighting We cant get auto replenishment supplies call order would think asking run around get charged got new machines fighting months Have machine hate jams time wont fix get going need service It times day every time turn around working something company coming They stay get contract none We know return resold sure dont know else long return label sent wits end They ones spoke lady ones read number box enclosed came staples So pleased service NO',
#  'Good job',
#  'It resolve satisfaction system didnt allow representative send buyout representative didnt want',
#  'You copy customer response The form letter states could early termination charges ETCs would apply This confusing customer causes issues statement doesnt apply',
#  'Ive already given details earlier willing answer questions need information resolve consulted contacted information incorrect billed something didnt order agree due shipping error part Xerox Corporation This reason bill disputed however address handled',
#  'still defective staples informed',
#  'You provide direct contact number direct email address contact XEROX Request issued link unable use link We reached Xerox status received email resolved working day',
#  'Please delete outstanding invoice Xerox customer service said would occur told Xerox customer service August invoice would deleted payment received July July payment sent July resent August The late charge invoice deleted Please delete',
#  'This issue going months cant even talk anybody Everything The tax exemption certificate customer along certificate resale supplied issue Xerox purchase order',
#  'New order credit easy use We lose client cant get act together terrible service',
#  'big corporate take responsibility job help customer instead passing buck Without customer business This second time issue told contact somebody else solve problem dont like people keep passing issue back customer get desk The correct response would say contact right person discuss get back',
#  'This request address corrected When spoke gentleman updated request say Suite number needed stay In addition address incorrect It Health Services Dr Ste Susan Martin',
#  'none forwarded advised',
#  'After spent much time phone different representatives take long period weeks send email telling covered receive software update get resolved shuffled dept dept hour representative telling something different told would contacted May weeks date original call resolution received email day two telling contract service needed Software update There explanation option offered allow get update machine contact local sales see get resolution Xerox system much help Very disappointing time consuming still software St Church phone cell would appreciate confirmation actually read care satisfied customer service',
#  'Havent heard back anyone Still waiting hear back rep anyone handles matter This resolved waiting hear back rep resolve issue The emails receiving confirmation emails received conversation hasnt even established',
#  'handled satisfactory timeframe promised wish turn around time quicker',
#  'The technician within hours extremely professional efficient knowledgeable',
#  'The request credit completed requested Not sure charged fee purchase order issued Thank',
#  'Id like start saying directed purchase wrong supplies technical support supply line happened wouldnt go whole process However last representative spoke extremely understanding didnt try act like honestly terms customer service They really went beyond help get situation thorough directions whole process going work Our UPS guy show prior us getting instructions return came back next day well Thanks',
#  'emails general Customer Service address resolution Most na basis answer get invoices looking',
#  'need find get refund returning supplies',
#  'No It address change location machine taken care',
#  'NO',
#  'Never even spoke Carlos',
#  'Fermin absolutely wonderful quick please Thank',
#  'ALEJANDRO professional prompt It clear Fermin full knowledge process request completely much appreciate Thank',
#  'Allan Estrada professional customer service skills',
#  'Fast',
#  'Great Customer Service Thank',
#  'When call wait forever cut received letter still showing late fees There six invoices mine explained They remove invoices left late fees balance due send another letter every time call one answers',
#  'Your prompt assistance correcting invoice greatly appreciated',
#  'At time inquiry rep new SR channel additional fees Contract requested approved team Rep addressed ASM give complete details ASM unaware contract cancelled error Xerox within days required per Service need inspection Rep closed inquiry stating inspection needed Sales Rep cost inspection This redone requested inspection second inquiry logged thus costing channel another fee inquiry',
#  'Thank handling request timely manner',
#  'We without made timely manner inquiry close result',
#  'My phone call sent several departments got correct one got right department gentleman professional',
#  'GREAT CUSTOMER SERVICE',
#  'We would like thank support Very much Thanks',
#  'please correct new mailing address Cook Road LA New address given representative Cook Road Road',
#  'thank',
#  'Dont know sure yet quoted price buyout told different price sent check price first quoted see resolved',
#  'surveys stop customers dont time employees',
#  'It year since quarterly billings machine incorrect getting good issue still happy call every quarter get resolved Please look case resolve',
#  'This may one worst experiences trying six months get information Xerox NOT auto renew one contracts Ive hoops multiple times finally got confirmation August contract would renew would NOT charged early termination fees since Im cancelling contract renewal received bill early termination fee person phone says cant anything Ive tried emailing person assured would extra fee received auto reply fixed',
#  'done timely Thank',
#  'For reason never received invoice last month therefore sending payment late charge church seems pretty severe pleased hope change address',
#  'Xerox handled issued rather',
#  'nice employee Xerox',
#  'dont think ever received response If sent email account',
#  'The representative efficient matter handled time frame promised seems long time Also keep problem every month keep disputing bill would like corrected go issue every month',
#  'requested original invoice tax purposes received January invoice payment',
# ...
#  'none',
#  'Great working Nelly',
#  'Just want make sure name gets changed properly Thank Betty When called said put San Francisco PO City You put please change Francisco',
#  'requested quarterly invoicing If could billed matching quarters least regular yearly quarters would worked ie etc know contract says requested quarterly many times years everyone says ok still bills monthly Thank assistance',
#  'How satisfied No one responded inquiries Jose sent email offered answer questions Well left four voicemails sent two emails including one You believe inquiries answered My fire Jose manager They customer service',
#  'The shipping address changed account Supplies needed would like online want make sure going right address',
#  'Irma Maria Our Xerox machine difficult get told pay lease fees need speak St Thomas rep get settled told needed call local Xerox office tried phone seem working need know get touch St Thomas Xerox',
#  'The issue resolved satisfaction',
#  'THE WAS NOT HAD TO TO TO GET THE CORRECT HE DID NOT KNOW ANYTHING HE DID NOT KNOW ANYTHING',
#  'This second request need credit invalid revenue billed beyond contract expiration date still closing without solution For second time mentioned CUSTOMER IS BILLED DATE clearly says beyond contract expiration date also note close contact David Smith Laura Barrera understand request Down see copy request Hello It government contracts auto renew Puerto Rico On CN outstanding balance invalid revenue therefore cannot accommodated All invoices covered government contract paid The customer cannot pay extended invoices We need credit invalid revenue billed beyond contract expiration date renewal valid CN NAME INVOICE SN SO BILL Please contact David Smith Laura Barrera understand request',
#  'He told contact rep tried calling put hold minutes hung tried emailing response',
#  'feel though Xerox doesnt listen help situation ever almost years dealt account Still almost years nobody provide said contract keeps stated The University whole contract Xerox department automatic without talking department directly getting told renewal letter sent us Xerox provided letter sent realized sent University Center deals invoices contracts Our issue resolved Carlos close matter goes prove separate Xerox',
#  'It took long resolve matter still done confirm amount able get Xerox referred back agent',
#  'still waiting contact Xerox Coupa form contained email Ive sent usacustomercarexeroxcom Please review email click link Coupa Portal',
#  'thank Allan',
#  'He said late wouldnt take consideration signed automatic payment therefore didnt make December payment assumed would automatic He said limit ACH said didnt realize He said past history showed good history would talk manager credit invoice It still credited The late charge still account credit account took ACH late charge applied current invoice told late charge would credited Thank',
#  'dont think giving clear information happens lease ends My question directly answered wanted know anything else required us returning copier know letter charge All told would completed end March',
#  'Good job',
#  'understand billing credit amounts forwarded spreadsheet amounts Ive left voice mails',
#  'issue resolved call still open',
#  'went beyond provide requested thank Hector',
#  'clear',
#  'It took longer felt get information',
#  'need correct invoice made pick Xerox copier response time issue still unresolved Was told contact local agent response couldnt help us call Xerox Customer Service emailed information response',
#  'Can fix problem My online account show payments made',
#  'honestly think going resolved due company Completely actually allow corporate offices make decision proceed would higher however since requested requests replied matter days But understand big complex company Im glad received something may first',
#  'speaking Pat Quinn State dissatisfied Xerox dealing issues Pat Quinn came along felt like met issues gone mean stated Pat wonderful got problems solved communication spot',
#  'Its hard answer questions dont know issue resolved assuming email supposed say issue resolved therefore ticket closed idea issue resolved closure email received provided information It looks like email response didnt get updated info Here received ReService Request Dear Thank contacting us regarding Form Customer Number Serial Number Type steps taken resolve inquiry dispute details find Type items attached invoice copy contract PO etc',
#  'Requested buyout quote Was provided Client looking purchase FMV leases devices',
#  'Thank Maria Jose She resolved problem wasnt receiving paper invoice month made change would receiving month She also promptly sent copy months invoice requested Excellent service',
#  'purchased At time life machine years Xerox offered lifetime warranty That warranty included full repairs replacement machine long owned machine That warranty total cost paid machine full years ago longer Finally months office Xerox honored agreement replaced broken machine current one would like copy contract extended lifetime warrant machine case thing happens',
#  'please provide information requested originally response provided customer effort receive payment invoices VERY Inquiry rep closed request without full request needed OF SERVICE added invoices per customers request could make payment The Inquiry rep made comment SERVICE closed request Apparently language STILL need information requested originally',
#  'communicated well service He knowledgeable polite',
#  'With Xerox general took months get issue resolved With Customer Care took month resolve issues invoices This included speaking different Reps The issue finally resolved Bani',
#  'Our agency name corrected billing information',
#  'resolved far know time unable access site says updates done Customer needs added site invoices site Information provided received email return saying provide enough information',
#  'Extremely efficient service',
#  'Thank quick response',
#  'additional comments',
#  'Communication immediate issue still outstanding still receiving invoices old mailing address',
#  'We still sure credit processed',
#  'thank',
#  'Thanks',
#  'Thanks email name closure letter vs name inquiry logged',
#  'spent time working banking feel',
#  'Extremely Satisfied',
#  'Issue resolved quickly thanks',
#  'still received invoices never account mailed available online received follow call supervisor requested discuss',
#  'The person spoke said name David Not sure actual person spoke helpful',
#  'none',
#  'quick resolution',
#  'Susan Wofford continually provides efficient service inquires processes This specific issue resolved least week sooner ETA satisfied',
#  'Have received requested invoices',
#  'Good turnaround time',
#  'entirely long get statement via email',
#  'Nope still without final resolution time call back wait hold get corrected called update mailing address sent confirmation showed Idaho Water Science Center called back explained work Idaho Water Science Center It Department Office Secretary He stated would make adjustment got confirmation issue resolved still shows Idaho Water Science Center That incorrect That would mean work USGS NOT work USGS Idaho Water Science Center department level level Still corrected',
#  'Id like mention Cesar matter also want commitment help',
#  'Let control types situations Moving serial customer another hold ups system allow move without assignment The ownership company clear day move customer completed requested problem',
#  'Thank handling situation The rep Xerox good explaining situation resolving problem Scott handled promptly Thanks',
#  'No',
#  'My situation resolved still need contacted My question even addressed',
#  'appreciated sense urgency much',
#  'No one called speak still missing boxes worth',
#  'WOULD PHONE CALL FROM SOMEONE IN MANAGEMENT TO RESOLVE THIS AS AS In April NEVER received invoice mail charged late fee non payment As soon made aware paying April bill paid promptly May In meantime spoke Xerox agent Brenda gave waiver paying late fee The late fee still account different invoice number customer service people pay closed dispute This dispute closed receive waiver promised via emails exchanged Brenda We customers since knowledge first time missed payment WE NEVER RECEIVED THE INVOICE IN THE IN THE FIRST Absolutely church treated poorly many years customer Have dealt many companies received invoice treated far situation even updated account late payments happen future',
#  'There experience The seems told wait paying invoice charged late fee Our Color Press whole week The technicians wonderful used two cases paper figure problem also believe credited enough impressions None books printed entire week usable',
#  'The account supply shipping address changed UPS keeps returning supplies church open days week noticed install address service would directed also changed The physical location equipment changed billing address They remain MO This original request sent need get shipping supplies address changed account Baptist Church MO Attn There someone church days week supplies returned since one sign The address install billing remain In meantime supplies supply people sent toner another wrong address able shipment thru UPS',
#  'none',
#  'This problem warrant survey It request current tax exempt cert',
#  'Great job',
#  'He went extra mile assist kept getting transferred one department another took time get need',
#  'told send email stating source invoices got credited late charges need credited well get account cleared Daniel Herrera DanielHerreraxeroxcom You turned around told collections representatives dispute late charges Please contact Daniel Herrera DanielHerreraxeroxcom dispute invoice Getting billing problem caused Xerox huge waste time',
#  'This fast Thanks',
#  'going far long log several requests need connect customer going around circles account trying resolve three invoices need connect customer person billing talk live email working',
#  'appreciate prompt response understand personal email looking forward receiving resolution mail',
#  'She extremely helpful new address issue',
#  'issue resolved quickly keep good work',
#  'Luisa great',
#  'VERY dissatisfied called request buyout printers received NOTHING received NO NOTHING Where This',
#  'Thank prompt attention matter',
#  'service great',
#  'My complaint Estuardo Kathleen Kathleen Im rating The credit late fee initiated received collection call Kathleen Xerox never late fee assessed never received call Im partially satisfied finally credited',
#  'The request asked processed correctly',
#  'know process took long sending emails call yesterday create inform takes business days Take consideration least billing side ask create customer numbers likely need immediately complete billing day requesting since guys create limit amount Customer numbers call force use emails instead take long fulfill requests think much help lot sense amount time fulfill request know process took long sending emails call yesterday create inform takes business days Take consideration least billing side ask create customer numbers likely need immediately complete billing day requesting since guys create limit amount Customer numbers call force use emails instead take long fulfill requests think much help lot sense amount time fulfill request',
#  'heard anyone Just logged charges still heard anyone regarding request requesting late fees written account long time customer Xerox office make payments',
#  'WAS CUSTOMER SERVICE AFTER MY WITH CUSTOMER SERVICE WAS VERY WITH THE CUSTOMER SERVICE WOULD BE MY CALL IF FOR ANYTHING IN THE WAS NO RESOLUTION WAS TOLD THE SALES REP HAD TO ADDRESS THE ISSUE AM THE SALES REP',
#  'sure phone representative complete task email confirmation etc It still remains though issue resolved It almost one month address account still wrong',
#  'The issue completely resolved Cindy helpful made great toward solving problem She provided lots helpful information',
#  'thank quick response',
#  'quick',
#  'Very pleasant deal',
#  'Could open email sent get buyout',
#  'pushed another rep unable get touch Also dont know name Mary came one business name',
#  'Mary excellent',
#  'Now Ive invoiced twice My regular billing received another invoice dated',
#  'sad service Glad away still confused give since big corporation always right us little guys arent never ever business xerox let others know went way get someone speak go collection Very sad Poor customer service You love department You',
#  'TO CONTACT ME TO RESOLVE THIS ISSUE AND AMOUNT XEROX INK FROM MARKETPLACE NEWEGG ARE ALL NEWEGG INK IS UNDER WITH XEROX AND TO CONTACT YOU YOU DONT YOUR AS WAS TOLD TO BACK TO THE MARKETPLACE THIS',
#  'Could hear voice phone Great experience',
#  'Requested copy signed agreement receive',
#  'It resolved quickly without issue pleased',
#  'made error sent glad caught completed asked would wrong thank',
#  'The Rep dealt extremely helpful My satisfaction way issue resolved length time took carrier pick equipment This created customer issue never occurred',
#  'order correctly sent wrong request',
#  'The account mess due errors',
#  'Lisa Curtis always professional sense urgency necessary escalated inquiries She appreciated much',
#  'We think twice renewing contract Our auto replenishment toner waste container auto When needed change waste container none available Xerox charged us shipping additional expense The machine service days busy',
#  'This simple change address Xerox turned major issue',
#  'getting called error They applied half bill returned warrant back We issued new check went March',
#  'No The request handled quickly appreciate',
#  'Thanks',
#  'fixed',
#  'clear person processing request understands complete request The equipment Xerox said needs handled Xerox leave message transferred around calling clarify Still sure Xerox aware longer using machines',
#  'request done timely correctly',
#  'difficult',
#  'need set auto pay credit card',
#  'Thanks',
#  'We receive January invoice click charges base charge equipment called Xerox want make late payment surprised find Xerox unable email invoice copies We wait duplicate invoice issued mailed adding time already late payment',
#  'Erwin made process smooth efficient',
#  'unable apply credit invoice removed invoice Cust SR',
#  'Thank incorrect CN work research Have nice day',
#  'impressed Elena resolve ensure issue fixed correctly Good asking second level questions prevent future',
#  'David Mancil incredible job sorting resolving issue dealing He must spent great deal time effort problem Thanks much',
#  'requested copy contract serial number received nothing closure notification',
#  'No needed copy current lease received within time told would receive',
#  'NO',
#  'Cesar professional helped expedite transaction',
#  'surprised simple request get list equipment leased Xerox yet complete The Xerox rep via local company unable provide information customer service rep spoke via Xerox invoice unable help request submitted via email yet complete',
#  'understand bill expect payment explain charges customer direct third party This third request seem email even read closing SR',
#  'Im trying set Xerox receive ACH payments In order need Xeroxs banking details Company physical signature received signed form request',
#  'need get processed sure taking long customer wanting unit picked ive tried cancelling numerous times cant get anyone talk',
#  'would really like issue resolved The issue resolved',
#  'need email letter saying erroneous something dollar bill sent withdrawn please closed settled Xerox final agreement payment payment full things Xerox related machine Ive yet hear Xerox odd dollar bill sent later incorrect withdrawn',
#  'reached someone else next day helpful felt like understood saying The person named invoice much use never picks phone My communication understood well',
#  'support ownership constantly please contact number instead along Took almost weeks get support printer completely The rep onsite great resolved issue time took get point painful',
#  'Xerox reaching',
#  'none',
#  ...]

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from numpy import array

# %%
# create the tokenizer
tokenizer = Tokenizer()
# fit the tokenizer on the documents
tokenizer.fit_on_texts(train_docs)

# %%
# sequence encode
encoded_docs = tokenizer.texts_to_sequences(train_docs)

# %%
# pad sequences
max_length = max([len(s.split()) for s in train_docs])
Xtrain = pad_sequences(encoded_docs, maxlen=max_length, padding='post')

# %%
Xtrain.shape
# Out:
# (1620, 252)

# %%
test_docs = list()
for i in range(len(testx_outer)):
    tokens = clean_doc_emb(testx_outer["Full_Comments"].iloc[i], vocab)
    test_docs.append(tokens)

# %%
encoded_docs_test = tokenizer.texts_to_sequences(test_docs)
# pad sequences
Xtest = pad_sequences(encoded_docs_test, maxlen=max_length, padding='post')

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Embedding
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.layers import LSTM
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from numpy import array

# %%
vocab_size = len(tokenizer.word_index) + 1

# %% [markdown]
# ## Pre Trained Model

# %%
# load embedding as a dict
def load_embedding(filename):
    # load embedding into memory, skip first line
    file = open(filename,'r',encoding="utf8")
    lines = file.readlines()
    file.close()
    # create a map of words to vectors
    embedding = dict()
    for line in lines:
        parts = line.split()
        # key is string word, value is numpy array for vector
        embedding[parts[0]] = asarray(parts[1:], dtype='float32')
    return embedding

# %%
def get_weight_matrix(embedding, vocab):
    # total vocabulary size plus 0 for unknown words
    vocab_size = len(vocab) + 1
    # define weight matrix dimensions with all 0
    weight_matrix = zeros((vocab_size, 100))
    # step vocab, store vectors using the Tokenizer's integer mapping
    for word, i in vocab.items():
        vector = embedding.get(word)
        if vector is not None:
            weight_matrix[i] = vector
    return weight_matrix

# %%
os.chdir("C:\\Machine Learning\\Hackathons\\Sample Data\\NLP\\Sentiment-Analysis\\txt_sentoken\\")

# %%
from numpy import asarray
from numpy import zeros

# %%
# Out:
# 2402

# %%
# load embedding from file
raw_embedding = load_embedding('glove.6B.100d.txt')
# get vectors in the right order
embedding_vectors = get_weight_matrix(raw_embedding, tokenizer.word_index)
# create the embedding layer
embedding_layer = Embedding(vocab_size, 100, weights=[embedding_vectors], input_length=max_length, trainable=False)

# %%
embedding_layer.get_weights()[0].shape
# Out:
# (2080, 100)

# %%
from keras.layers import LSTM,Bidirectional,Dropout, RNN, GRU

# %%
Xtrain.shape
# Out:
# (1620, 252)

# %% [markdown]
# ### Choosing the right amount of nodes and layers
# There is no final, definite, rule of thumb on how many nodes (or hidden neurons) or how many layers one should choose, and very often a trial and error approach will give you the best results for your individual problem. The most common framework for this is most likely the k-fold cross-validation. However, even for a testing procedure, we need to choose some (k) numbers of nodes.
# The following formula may give you a starting point:
#
#   N_s/(N_i+N_o)
#
# Nᵢ is the number of input neurons, Nₒ the number of output neurons, Nₛ the number of samples in the training data, and α represents a scaling factor that is usually between 2 and 10. We can calculate 8 different numbers to feed into our validation procedure and find the optimal model, based on the resulting validation loss.
# If the problem is simple and time an issue, there are various other rules of thumbs to determine the number of nodes, which are mostly simply based on the input and output neurons. We have to keep in mind that, while easy to use, they will rarely yield the optimal result. Here is just one example, which we will use for this basic model:
#
# 2/3*(N_i+N_o)

# %%
# define model
model = Sequential()
model.add(embedding_layer)
#model.add(Conv1D(filters=128, kernel_size=5, activation='relu'))
#model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(units= 128,input_shape=(None,252,100)))
model.add(Dropout(0.5))
#model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 252, 100)          208000
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 128)               117248
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 325,377
# Trainable params: 117,377
# Non-trainable params: 208,000
# _________________________________________________________________
# None

# %%
# compile network
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit network
model.fit(Xtrain, trainy_outer, epochs=14, verbose=2)
# evaluate
loss, acc = model.evaluate(Xtest, testy_outer, verbose=0)
print('Test Accuracy: {} and loss is {}' .format(acc*100,loss))
# Out:
# Epoch 1/14
#  - 16s - loss: 0.6938 - acc: 0.4969
# Epoch 2/14
#  - 14s - loss: 0.6929 - acc: 0.5111
# Epoch 3/14
#  - 13s - loss: 0.6933 - acc: 0.5031
# Epoch 4/14
#  - 15s - loss: 0.6931 - acc: 0.4858
# Epoch 5/14
#  - 14s - loss: 0.6926 - acc: 0.5123
# Epoch 6/14
#  - 14s - loss: 0.6928 - acc: 0.5105
# Epoch 7/14
#  - 14s - loss: 0.6931 - acc: 0.4975
# Epoch 8/14
#  - 15s - loss: 0.6927 - acc: 0.5130
# Epoch 9/14
#  - 15s - loss: 0.6991 - acc: 0.5185
# Epoch 10/14
#  - 14s - loss: 0.6926 - acc: 0.5111
# Epoch 11/14
#  - 14s - loss: 0.6931 - acc: 0.5074
# Epoch 12/14
#  - 14s - loss: 0.6924 - acc: 0.5074
# Epoch 13/14
#  - 15s - loss: 0.6929 - acc: 0.5025
# Epoch 14/14
#  - 15s - loss: 0.6923 - acc: 0.5117
# Test Accuracy: 50.935251747103905 and loss is 0.6929755888396888

# %% [markdown]
# Test Accuracy: 83.45323731573366 and loss is 0.5199229238273428 LSTM
# Test Accuracy: 85.17985602076963 and loss is 0.4345971986544218 GRU
# Test Accuracy: 82.01438839487034 and loss is 0.5317774833106309 GRU
# Test Accuracy: 81.43884886082985 and loss is 0.5419978845891334

# %%
import matplotlib.pyplot as plt

# %%
history = model.fit(Xtrain, trainy_outer, validation_split=0.25, epochs=4, verbose=2)
# Out:
# Train on 1215 samples, validate on 405 samples
# Epoch 1/4
#  - 19s - loss: 0.0271 - acc: 0.9918 - val_loss: 0.3411 - val_acc: 0.9111
# Epoch 2/4
#  - 18s - loss: 0.0252 - acc: 0.9942 - val_loss: 0.3923 - val_acc: 0.9037
# Epoch 3/4
#  - 17s - loss: 0.0234 - acc: 0.9918 - val_loss: 0.4053 - val_acc: 0.9062
# Epoch 4/4
#  - 17s - loss: 0.0225 - acc: 0.9942 - val_loss: 0.4087 - val_acc: 0.9037

# %%
# Plot training & validation accuracy values
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
y_predict = model.predict(Xtest)
y_predict[:10]

# %%
y_predict[y_predict>=.5] = 1
y_predict[y_predict<.5] = 0

# %%
y_predict.shape

# %%
#final_comp =  pd.DataFrame(list(testy_outer), columns=["Actual"],)
#print(final_comp.shape)
y_predict =   pd.DataFrame(y_predict, columns=["Predicted"],)
print(y_predict.shape)
#print(testx_outer.shape)
y_predict.head(10)

# %%
test_temp = testx_outer
test_temp.shape, testx_outer.shape

# %%
temp = test_temp
temp.reset_index(inplace=True,drop=True)
#temp.head()
act_vs_pred =pd.concat([ temp,y_predict], axis=1,)

# %%
#act_vs_pred.drop(columns=["index"],inplace=True)

# %%
act_vs_pred

# %%
from sklearn.metrics import confusion_matrix

# %%
mat = confusion_matrix(act_vs_pred["Customer_SAT_Score"], act_vs_pred["Predicted"])

# %%
mat = pd.DataFrame(data=mat, columns=["Actual Positive","Actual Negative"],
                   index = ["Predicted Positive","Predicted Negative"])

# %%
mat

# %%
t = act_vs_pred.copy()

# %%
t.head(3)

# %%
t["Mismatch"] =  False

# %%
t.loc[t["Customer_SAT_Score"]!= t["Predicted"],"Mismatch"] = True

# %%
t

# %%
t.loc[9]

# %% [markdown]
# ## Sequencing Modeling

# %% [raw]
# # define model
# lstm_out = 200
# model = Sequential()
# model.add(Embedding(vocab_size, 100, input_length=max_length))
# model.add(LSTM(lstm_out, dropout_U = 0.2, dropout_W = 0.2))
# #model.add(Conv1D(filters=32, kernel_size=8, activation='relu'))
# #model.add(MaxPooling1D(pool_size=2))
# #model.add(Flatten())
# #model.add(Dense(50, activation='relu'))
# model.add(Dense(1, activation='softmax'))
# print(model.summary())
# model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# # fit network
# model.fit(Xtrain, trainy_outer, epochs=5, verbose=2)
# loss, acc = model.evaluate(Xtest, testy_outer, verbose=0)
# print('Test Accuracy: {} and loss is {}' .format(acc*100,loss))
