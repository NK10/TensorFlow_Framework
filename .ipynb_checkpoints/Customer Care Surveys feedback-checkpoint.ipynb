# %%
import numpy as np
import nltk as nl
from gensim.models import Word2Vec
import pandas as pd
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\utils.py:1212: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
surveys = pd.read_excel("C:\\Machine Learning\\Hackathons\\Xerox\\2018 WR NES_original.XLSX",header=0,sheet_name="Sheet1")

# %%
surveys.head()
# Out:
#     Month  RespondentID  CollectorID           StartDate             EndDate  \
# 0  201812    5576030682     39775725 2018-12-31 14:41:01 2018-12-31 14:42:00
# 1  201812    5576022669     39775725 2018-12-31 13:44:56 2018-12-31 13:45:46
# 2  201812    5576020478     39775725 2018-12-31 13:29:57 2018-12-31 13:30:27
# 3  201812    5576019968     39775725 2018-12-31 13:26:31 2018-12-31 13:27:04
# 4  201812    5576006009     39775725 2018-12-31 11:59:21 2018-12-31 11:59:33
#
#         IP Address  Email Address  First Name  LastName  Custom Data   ...    \
# 0       13.13.16.1            NaN         NaN       NaN          NaN   ...
# 1  174.231.167.188            NaN         NaN       NaN          NaN   ...
# 2      13.8.125.11            NaN         NaN       NaN          NaN   ...
# 3     69.34.106.10            NaN         NaN       NaN          NaN   ...
# 4       13.13.16.1            NaN         NaN       NaN          NaN   ...
#
# ...

# %%
surveys_comments = pd.DataFrame({"SR#":surveys["SR#"],
                                 "Comments":surveys["Do you have any other details you want to share regarding the ha"],
                                 "Additional_Comments":surveys["Please provide details#"],
                                 "Full_Comments":surveys["Full_Comments"],
                                 "Customer_SAT_Score":surveys["How satisfied are you with the way your issue was resolved?"]})

# %%
surveys_comments.head(6)
# Out:
#               SR#                                           Comments  \
# 0  1-101526171125  Many thanks for understanding this issue and r...
# 1  1-101542609016                                                NaN
# 2  1-101320199441                   Thank you for everything David!
# 3  1-101385815880                                                NaN
# 4  1-101527669071                                                NaN
# 5  1-101571535327  We have been a customer of yours for many many...
#
#                                  Additional_Comments  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  No one wants to resolve this issue.  Everyone ...
#
#                                        Full_Comments  Customer_SAT_Score
# ...

# %%
surveys_comments["Full_Comments"] = (surveys_comments["Comments"].fillna("") + " " + surveys_comments["Additional_Comments"].fillna(""))

# %%
surveys_comments.head(6)
# Out:
#               SR#                                           Comments  \
# 0  1-101526171125  Many thanks for understanding this issue and r...
# 1  1-101542609016                                                NaN
# 2  1-101320199441                   Thank you for everything David!
# 3  1-101385815880                                                NaN
# 4  1-101527669071                                                NaN
# 5  1-101571535327  We have been a customer of yours for many many...
#
#                                  Additional_Comments  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  No one wants to resolve this issue.  Everyone ...
#
#                                        Full_Comments  Customer_SAT_Score
# ...

# %%
surveys_comments.drop(index=(surveys_comments[surveys_comments["Comments"].isna() & surveys_comments["Additional_Comments"].isna()]).index,inplace = True)

# %%
surveys_comments
# Out:
#                  SR#                                           Comments  \
# 0     1-101526171125  Many thanks for understanding this issue and r...
# 2     1-101320199441                   Thank you for everything David!
# 5     1-101571535327  We have been a customer of yours for many many...
# 14    1-101428425708  It doesn't feel like a person helped me at all...
# 16    1-101292413714                                               none
# 30    1-101247040823  My original issue was handled in a timely mann...
# 32    1-101379044780                                                NaN
# 34    1-101415299897                                                NaN
# 35    1-101344352092                                                NaN
# 36    1-101366582438  The rep always acts with the most respect and ...
# 42    1-101405808489  I know there was an inquiry, I have yet to see...
# 43    1-101306319761                                                NaN
# ...

# %%
comments =  surveys_comments["Full_Comments"]

# %%
comments.head()
# Out:
# 0     Many thanks for understanding this issue and r...
# 2                     Thank you for everything David!
# 5     We have been a customer of yours for many many...
# 14    It doesn't feel like a person helped me at all...
# 16                                                none
# Name: Full_Comments, dtype: object

# %%
def normalize_document(doc):
    import re 
    stop_words = nl.corpus.stopwords.words('english')

    # lower case and remove special characters\whitespaces
    doc = re.sub(r'[^a-zA-Z\s]', '', doc, re.I|re.A)
    doc = doc.lower()
    doc = doc.strip()
    # tokenize document
    tokens = wpt.tokenize(doc)
    # filter stopwords out of document
    filtered_tokens = [token for token in tokens if token not in stop_words]
    # re-create document from filtered tokens
    doc = ' '.join(filtered_tokens)
    return doc

normalize_corpus = np.vectorize(normalize_document)

# %%
com = normalize_corpus(comments)

# %%
com[:5]
# Out:
# array(['many thanks understanding issue resolving',
#        'thank everything david',
#        'customer many many years technology needs changed thus request end contract keep dodging relatively small adjustment request owed special request making doesnt seem way respect long time customer please look without passing buck next rep line one wants resolve issue everyone keeps passing buck',
#        'doesnt feel like person helped felt like automated response needed information recurring bill paying receive answer instead pointed log website review bills website portal',
#        'none'], dtype='<U1956')

# %%
from gensim.models import word2vec

# tokenize sentences in corpus
wpt = nl.WordPunctTokenizer()
tokenized_corpus = [wpt.tokenize(document) for document in com]

# Set values for various parameters
feature_size = 100    # Word vector dimensionality  
window_context = 5          # Context window size                                                                                    
min_word_count = 1   # Minimum word count                        
sample = 1e-3   # Downsample setting for frequent words

w2v_model = word2vec.Word2Vec(tokenized_corpus, size=feature_size, 
                          window=window_context, min_count=min_word_count,
                          sample=sample, iter=10000)

# %%
w2v_model.wv.most_similar("resolution")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('reward', 0.34629517793655396),
#  ('cmd', 0.31671470403671265),
#  ('idr', 0.3053647577762604),
#  ('overhaul', 0.2829977869987488),
#  ('correspondence', 0.2674768567085266),
#  ('minutes', 0.2589515149593353),
#  ('implemented', 0.25333136320114136),
#  ('ultra', 0.2522784471511841),
#  ('comment', 0.25223058462142944),
#  ('result', 0.24926292896270752)]

# %%
    w2v_model.wv.get_vector("response")
# Out:
# array([-2.4636135 ,  3.8561828 ,  0.4098244 ,  1.6172179 ,  6.6084623 ,
#        -2.2550435 ,  1.4037638 ,  0.0165432 ,  3.0734017 , -2.6361504 ,
#         7.004967  , -2.045348  , -4.1266594 ,  1.5817024 , -1.0558608 ,
#        -5.172765  ,  2.501365  ,  5.7888894 ,  4.7436175 , -2.5449505 ,
#         4.4837155 ,  2.5787303 , -1.4340526 , 11.215362  , -6.3610067 ,
#         7.5324936 ,  0.3555451 ,  1.9133604 ,  2.2444685 ,  3.048622  ,
#         3.577033  ,  0.23171636, -3.452501  , -4.02221   ,  4.073982  ,
#        -3.0824203 , -2.6735363 , -5.440753  , -1.6835266 , -2.3404624 ,
#        10.826158  ,  1.1011691 ,  2.2784252 , 11.763571  , -1.2891304 ,
#        -4.517003  , -4.7625537 ,  3.1194649 , -4.402824  ,  1.9762893 ,
#        -4.1791186 , -2.451445  ,  5.32727   ,  2.7474663 , -1.8754742 ,
#        -2.27669   ,  0.8883389 ,  1.1580752 , -6.329598  ,  1.0191135 ,
#        -3.4755745 , -4.851327  , -6.8694944 ,  0.7132982 , -3.2906945 ,
# ...

# %%
[('men', 0.6036182641983032),
 ('visit', 0.5310729742050171),
 ('literally', 0.5127371549606323),
 ('lotterys', 0.5024996399879456),
 ('copierprinterfax', 0.4924047291278839),
 ('technician', 0.4814442992210388),
 ('slowly', 0.4784594476222992),
 ('counters', 0.4783889651298523),
 ('newer', 0.4756646454334259),
 ('quinn', 0.47521066665649414)]

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def tsne_plot(model):
    "Creates and TSNE model and plots it"
    labels = []
    tokens = []

    for word in model.wv.vocab:
        tokens.append(model[word])
        labels.append(word)
    
    tsne_model = TSNE(perplexity=40, n_components=2, init='pca', n_iter=250, random_state=23)
    new_values = tsne_model.fit_transform(tokens)

    x = []
    y = []
    for value in new_values:
        x.append(value[0])
        y.append(value[1])
        
    plt.figure(figsize=(42, 42)) 
    for i in range(len(x)):
        plt.scatter(x[i],y[i])
        plt.annotate(labels[i],
                     xy=(x[i], y[i]),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')
    plt.show()

# %%
tsne_plot(w2v_model)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   import sys

# %%
com_copy  = com.copy()

# %%
com_copy
# Out:
# array(['many thanks understanding issue resolving',
#        'thank everything david',
#        'customer many many years technology needs changed thus request end contract keep dodging relatively small adjustment request owed special request making doesnt seem way respect long time customer please look without passing buck next rep line one wants resolve issue everyone keeps passing buck',
#        ...,
#        'took months communication via phone kept sending address change notice bright orange piece paper payment think guys need work lean manufacturing conversation would save time money',
#        'resolution accurate', 'appreciate rapid complete response issue'],
#       dtype='<U1956')

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer,TfidfTransformer

# %%
count_vec = CountVectorizer(input="C:\\Machine Learning\\Hackathons\\Xerox\\2018 WR NES_original.XLSX",
                            strip_accents = "ascii",stop_words = "english"
                           )

#count_occurs = count_vec.fit_transform([com_copy])

# %%
count_vec
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8',
#         input='C:\\Machine Learning\\Hackathons\\Xerox\\2018 WR NES_original.XLSX',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words='english',
#         strip_accents='ascii', token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
count_vec.stop_words_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-220-0fbf034dea9a> in <module>()
# ----> 1 count_vec.stop_words_
#
# AttributeError: 'CountVectorizer' object has no attribute 'stop_words_'

# %%
>>> corpus = [
...     'This is the first document.',
...     'This is the second second document.',
...     'And the third one.',
...     'Is this the first document?',
... ]
>>> X = CountVectorizer.fit_transform(corpus)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-222-531cfd0f496c> in <module>()
#       5     'Is this the first document?',
#       6 ]
# ----> 7 X = CountVectorizer.fit_transform(corpus)
#
# TypeError: fit_transform() missing 1 required positional argument: 'raw_documents'
