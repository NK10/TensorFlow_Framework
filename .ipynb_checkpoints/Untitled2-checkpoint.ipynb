# %% [markdown]
# Before classify every problem as machine learning and think it as a magic bullet. Always take a step back and understand if this require a machine learning or not. Basic rule of thumb is to see if the problem you are trying to solve has predefined steps and require a definite calculation and if that is the case then its better to code it explicitly rather using machine learning.
#
# If the process has some degree of undertainity and require historical data to find patterns than it may be use case for machine learning.
#
#
#
# High Level the machine learning the project is divided into 7 steps:
#
# <b>
# 1) understaning project requirements: This is one of the critical step, as in this we clarify what the business requirement is
# 2) Data preparation
# 3) Data understanding
# 4) Model building
# 5) Model evaluation
# 6) Deployment of the model
# 7) Monitoring
#  </b>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Understanding

# %%
retaildata = pd.read_csv("C:\\Users\\USX28939\\Downloads\\sales_data_sample.csv",encoding = 'unicode_escape')

# %%
retaildata.shape
# Out:
# (2823, 25)

# %%
retaildata.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
retaildata.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
retaildata.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %%
retaildata.dtypes
# Out:
# ORDERNUMBER           int64
# QUANTITYORDERED       int64
# PRICEEACH           float64
# ORDERLINENUMBER       int64
# SALES               float64
# ORDERDATE            object
# STATUS               object
# QTR_ID                int64
# MONTH_ID              int64
# YEAR_ID               int64
# PRODUCTLINE          object
# MSRP                  int64
# PRODUCTCODE          object
# CUSTOMERNAME         object
# PHONE                object
# ADDRESSLINE1         object
# ADDRESSLINE2         object
# CITY                 object
# STATE                object
# POSTALCODE           object
# COUNTRY              object
# TERRITORY            object
# CONTACTLASTNAME      object
# CONTACTFIRSTNAME     object
# DEALSIZE             object
# dtype: object

# %%
retaildata.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2818    False
# 2819    False
# 2820    False
# 2821    False
# 2822    False
# Length: 2823, dtype: bool

# %%
retaildata.nunique().sort_values(ascending = False)
# Out:
# SALES               2763
# PRICEEACH           1016
# ORDERNUMBER          307
# ORDERDATE            252
# PRODUCTCODE          109
# CUSTOMERNAME          92
# ADDRESSLINE1          92
# PHONE                 91
# MSRP                  80
# CONTACTLASTNAME       77
# POSTALCODE            73
# CITY                  73
# CONTACTFIRSTNAME      72
# QUANTITYORDERED       58
# COUNTRY               19
# ORDERLINENUMBER       18
# STATE                 16
# MONTH_ID              12
# ADDRESSLINE2           9
# PRODUCTLINE            7
# STATUS                 6
# QTR_ID                 4
# YEAR_ID                3
# TERRITORY              3
# DEALSIZE               3
# dtype: int64

# %%
retaildata["ORDERDATE"]
# Out:
# 0        2/24/2003 0:00
# 1         5/7/2003 0:00
# 2         7/1/2003 0:00
# 3        8/25/2003 0:00
# 4       10/10/2003 0:00
#              ...
# 2818     12/2/2004 0:00
# 2819     1/31/2005 0:00
# 2820      3/1/2005 0:00
# 2821     3/28/2005 0:00
# 2822      5/6/2005 0:00
# Name: ORDERDATE, Length: 2823, dtype: object

# %%
metadata = pd.DataFrame({"Col":retaildata.columns,"Dtypes":retaildata.dtypes,"NUnique":retaildata.nunique(),
                        "NullCount":retaildata.isnull().sum()})

# %%
retaildata["ORDERDATE"]= pd.to_datetime(retaildata.ORDERDATE)

# %%
metadata
# Out:
#                                Col   Dtypes  NUnique  NullCount
# ORDERNUMBER            ORDERNUMBER    int64      307          0
# QUANTITYORDERED    QUANTITYORDERED    int64       58          0
# PRICEEACH                PRICEEACH  float64     1016          0
# ORDERLINENUMBER    ORDERLINENUMBER    int64       18          0
# SALES                        SALES  float64     2763          0
# ORDERDATE                ORDERDATE   object      252          0
# STATUS                      STATUS   object        6          0
# QTR_ID                      QTR_ID    int64        4          0
# MONTH_ID                  MONTH_ID    int64       12          0
# YEAR_ID                    YEAR_ID    int64        3          0
# PRODUCTLINE            PRODUCTLINE   object        7          0
# MSRP                          MSRP    int64       80          0
# PRODUCTCODE            PRODUCTCODE   object      109          0
# CUSTOMERNAME          CUSTOMERNAME   object       92          0
# ...

# %%
retaildata["MONTH"] =pd.DatetimeIndex(retaildata["ORDERDATE"]).month
retaildata["YEAR"] =pd.DatetimeIndex(retaildata["ORDERDATE"]).year
retaildata["QTR"] =pd.DatetimeIndex(retaildata["ORDERDATE"]).quarter

# %%
retaildata.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#    ORDERDATE   STATUS  PRODUCTLINE  MSRP PRODUCTCODE  ... STATE POSTALCODE  \
# 0 2003-02-24  Shipped  Motorcycles    95    S10_1678  ...    NY      10022
# 1 2003-05-07  Shipped  Motorcycles    95    S10_1678  ...   NaN      51100
# 2 2003-07-01  Shipped  Motorcycles    95    S10_1678  ...   NaN      75508
# 3 2003-08-25  Shipped  Motorcycles    95    S10_1678  ...    CA      90003
# 4 2003-10-10  Shipped  Motorcycles    95    S10_1678  ...    CA        NaN
#
#   COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE MONTH  YEAR QTR
# ...

# %%
retaildata.drop(["QTR_ID","MONTH_ID","YEAR_ID"], inplace = True, axis = 1)

# %%
retaildata.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'PRODUCTLINE', 'MSRP', 'PRODUCTCODE',
#        'CUSTOMERNAME', 'PHONE', 'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY',
#        'STATE', 'POSTALCODE', 'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME',
#        'CONTACTFIRSTNAME', 'DEALSIZE', 'MONTH', 'YEAR', 'QTR'],
#       dtype='object')

# %%
col = ['PRICEEACH',        'SALES', 'ORDERDATE', 'STATUS', 'PRODUCTLINE', 'MSRP', 'PRODUCTCODE',
       'CUSTOMERNAME', 'PHONE', 'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY',
       'STATE', 'POSTALCODE', 'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME',
       'CONTACTFIRSTNAME', 'DEALSIZE', 'MONTH', 'YEAR', 'QTR'],]
